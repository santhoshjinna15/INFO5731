# %% [markdown]
# <a href="https://colab.research.google.com/github/santhoshjinna15/INFO5731/blob/main/INFO5731_Assignment_Three.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Three**
#
# In this assignment, you are required to conduct information extraction, semantic analysis based on **the dataset you collected from assignment two**. You may use scipy and numpy package in this assignment.

# %% [markdown]
# # **Question 1: Understand N-gram**

# %% [markdown]
# (45 points). Write a python program to conduct N-gram analysis based on the dataset in your assignment two:
#
# (1) Count the frequency of all the N-grams (N=3).
#
# (2) Calculate the probabilities for all the bigrams in the dataset by using the fomular count(w2 w1) / count(w2). For example, count(really like) / count(really) = 1 / 3 = 0.33.
#
# (3) Extract all the **noun phrases** and calculate the relative probabilities of each review in terms of other reviews (abstracts, or tweets) by using the fomular frequency (noun phrase) / max frequency (noun phrase) on the whole dataset. Print out the result in a table with column name the all the noun phrases and row name as all the 100 reviews (abstracts, or tweets).

# %%
# Write your code here

# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install selenium
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:7 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:10 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [49.4 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:13 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Ign:14 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages
# Get:14 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [603 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:16 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:17 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [333 kB]
# Get:19 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,398 kB]
# Get:20 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [1,995 kB]
# Get:21 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,746 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,425 kB]
# Get:23 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [894 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [363 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,165 kB]
# Fetched 12.2 MB in 4s (2,941 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 49 not upgraded.
# Need to get 83.2 MB of archives.
# After this operation, 282 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 89.0.4389.82-0ubuntu0.18.04.1 [1,127 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser amd64 89.0.4389.82-0ubuntu0.18.04.1 [73.6 MB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser-l10n all 89.0.4389.82-0ubuntu0.18.04.1 [3,800 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-chromedriver amd64 89.0.4389.82-0ubuntu0.18.04.1 [4,697 kB]
# Fetched 83.2 MB in 6s (14.8 MB/s)
# Selecting previously unselected package chromium-codecs-ffmpeg-extra.
# (Reading database ... 160975 files and directories currently installed.)
# Preparing to unpack .../chromium-codecs-ffmpeg-extra_89.0.4389.82-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-codecs-ffmpeg-extra (89.0.4389.82-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser.
# Preparing to unpack .../chromium-browser_89.0.4389.82-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-browser (89.0.4389.82-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser-l10n.
# Preparing to unpack .../chromium-browser-l10n_89.0.4389.82-0ubuntu0.18.04.1_all.deb ...
# Unpacking chromium-browser-l10n (89.0.4389.82-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_89.0.4389.82-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-chromedriver (89.0.4389.82-0ubuntu0.18.04.1) ...
# Setting up chromium-codecs-ffmpeg-extra (89.0.4389.82-0ubuntu0.18.04.1) ...
# Setting up chromium-browser (89.0.4389.82-0ubuntu0.18.04.1) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-chromedriver (89.0.4389.82-0ubuntu0.18.04.1) ...
# Setting up chromium-browser-l10n (89.0.4389.82-0ubuntu0.18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file
# Collecting selenium
#   Downloading https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl (904kB)
#      |████████████████████████████████| 911kB 7.4MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from selenium) (1.24.3)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0

# %%
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('-headless')
options.add_argument('-no-sandbox')
options.add_argument('-disable-dev-shm-usage')

# %%
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.common.by import By
import pandas as pd
import time

driver = webdriver.Chrome('chromedriver',options=options)
link = 'https://www.imdb.com/title/tt7286456/reviews?ref_=tt_urv'
title_array = []
review_array = []
driver.get(link)
for num in range(3):
  driver.find_element_by_class_name("ipl-load-more__button").click()
  time.sleep(5)
  list_Of_title = driver.find_elements(By.CLASS_NAME, "title")
  list_Of_reviews = driver.find_elements(By.CLASS_NAME, "text")
for ele, sub_ele in zip(list_Of_title, list_Of_reviews):
      title_array.append((ele.text).replace('\n',''))
      review_array.append(sub_ele.text)
title_review = pd.DataFrame(list(zip(title_array, review_array)), columns =['Title', 'Review'])
print("Length of data frame is {0}".format(len(title_review)))
title_review
# Out:
# Length of data frame is 100
#                                                 Title                                             Review
# 0   Outstanding movie with a haunting performance ...  Every once in a while a movie comes, that trul...
# 1                      Only certain people can relate  This is a movie that only those who have felt ...
# 2                            Perfect in every aspect.  Truly a masterpiece, The Best Hollywood film o...
# 3                                       MASTERPIECE 😍  Joaquin Phoenix gives a tour de force performa...
# 4                                    The Hype is real  Most of the time movies are anticipated like t...
# ..                                                ...                                                ...
# 95                                        What a joke  Heath great in dark Knight, even liked Jared L...
# 96         Glad I didn't waste my money on this movie  I was very excited about this movie when it ca...
# 97                          Derivative and Uninspired  There is doing an homage and then there is bor...
# 98                               Better if didn't saw  Disturbing. Just got out of the movie. My humo...
# 99                        Hats off to Joaquin phoenix  What a legendary character and what a legendar...
#
# [100 rows x 2 columns]

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
#     Downloading collection 'all'
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package alpino to /root/nltk_data...
#        |   Unzipping corpora/alpino.zip.
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Unzipping corpora/biocreative_ppi.zip.
#        | Downloading package brown to /root/nltk_data...
#        |   Unzipping corpora/brown.zip.
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Unzipping corpora/brown_tei.zip.
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Unzipping corpora/cess_cat.zip.
#        | Downloading package cess_esp to /root/nltk_data...
#        |   Unzipping corpora/cess_esp.zip.
#        | Downloading package chat80 to /root/nltk_data...
#        |   Unzipping corpora/chat80.zip.
#        | Downloading package city_database to /root/nltk_data...
#        |   Unzipping corpora/city_database.zip.
#        | Downloading package cmudict to /root/nltk_data...
#        |   Unzipping corpora/cmudict.zip.
#        | Downloading package comparative_sentences to
#        |     /root/nltk_data...
#        |   Unzipping corpora/comparative_sentences.zip.
#        | Downloading package comtrans to /root/nltk_data...
#        | Downloading package conll2000 to /root/nltk_data...
#        |   Unzipping corpora/conll2000.zip.
#        | Downloading package conll2002 to /root/nltk_data...
#        |   Unzipping corpora/conll2002.zip.
#        | Downloading package conll2007 to /root/nltk_data...
#        | Downloading package crubadan to /root/nltk_data...
#        |   Unzipping corpora/crubadan.zip.
#        | Downloading package dependency_treebank to /root/nltk_data...
#        |   Unzipping corpora/dependency_treebank.zip.
#        | Downloading package dolch to /root/nltk_data...
#        |   Unzipping corpora/dolch.zip.
#        | Downloading package europarl_raw to /root/nltk_data...
#        |   Unzipping corpora/europarl_raw.zip.
#        | Downloading package floresta to /root/nltk_data...
#        |   Unzipping corpora/floresta.zip.
#        | Downloading package framenet_v15 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v15.zip.
#        | Downloading package framenet_v17 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v17.zip.
#        | Downloading package gazetteers to /root/nltk_data...
#        |   Unzipping corpora/gazetteers.zip.
#        | Downloading package genesis to /root/nltk_data...
#        |   Unzipping corpora/genesis.zip.
#        | Downloading package gutenberg to /root/nltk_data...
#        |   Unzipping corpora/gutenberg.zip.
#        | Downloading package ieer to /root/nltk_data...
#        |   Unzipping corpora/ieer.zip.
#        | Downloading package inaugural to /root/nltk_data...
#        |   Unzipping corpora/inaugural.zip.
#        | Downloading package indian to /root/nltk_data...
#        |   Unzipping corpora/indian.zip.
#        | Downloading package jeita to /root/nltk_data...
#        | Downloading package kimmo to /root/nltk_data...
#        |   Unzipping corpora/kimmo.zip.
#        | Downloading package knbc to /root/nltk_data...
#        | Downloading package lin_thesaurus to /root/nltk_data...
#        |   Unzipping corpora/lin_thesaurus.zip.
#        | Downloading package mac_morpho to /root/nltk_data...
#        |   Unzipping corpora/mac_morpho.zip.
#        | Downloading package machado to /root/nltk_data...
#        | Downloading package masc_tagged to /root/nltk_data...
#        | Downloading package moses_sample to /root/nltk_data...
#        |   Unzipping models/moses_sample.zip.
#        | Downloading package movie_reviews to /root/nltk_data...
#        |   Unzipping corpora/movie_reviews.zip.
#        | Downloading package names to /root/nltk_data...
#        |   Unzipping corpora/names.zip.
#        | Downloading package nombank.1.0 to /root/nltk_data...
#        | Downloading package nps_chat to /root/nltk_data...
#        |   Unzipping corpora/nps_chat.zip.
#        | Downloading package omw to /root/nltk_data...
#        |   Unzipping corpora/omw.zip.
#        | Downloading package opinion_lexicon to /root/nltk_data...
#        |   Unzipping corpora/opinion_lexicon.zip.
#        | Downloading package paradigms to /root/nltk_data...
#        |   Unzipping corpora/paradigms.zip.
#        | Downloading package pil to /root/nltk_data...
#        |   Unzipping corpora/pil.zip.
#        | Downloading package pl196x to /root/nltk_data...
#        |   Unzipping corpora/pl196x.zip.
#        | Downloading package ppattach to /root/nltk_data...
#        |   Unzipping corpora/ppattach.zip.
#        | Downloading package problem_reports to /root/nltk_data...
#        |   Unzipping corpora/problem_reports.zip.
#        | Downloading package propbank to /root/nltk_data...
#        | Downloading package ptb to /root/nltk_data...
#        |   Unzipping corpora/ptb.zip.
#        | Downloading package product_reviews_1 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_1.zip.
#        | Downloading package product_reviews_2 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_2.zip.
#        | Downloading package pros_cons to /root/nltk_data...
#        |   Unzipping corpora/pros_cons.zip.
#        | Downloading package qc to /root/nltk_data...
#        |   Unzipping corpora/qc.zip.
#        | Downloading package reuters to /root/nltk_data...
#        | Downloading package rte to /root/nltk_data...
#        |   Unzipping corpora/rte.zip.
#        | Downloading package semcor to /root/nltk_data...
#        | Downloading package senseval to /root/nltk_data...
#        |   Unzipping corpora/senseval.zip.
#        | Downloading package sentiwordnet to /root/nltk_data...
#        |   Unzipping corpora/sentiwordnet.zip.
#        | Downloading package sentence_polarity to /root/nltk_data...
#        |   Unzipping corpora/sentence_polarity.zip.
#        | Downloading package shakespeare to /root/nltk_data...
#        |   Unzipping corpora/shakespeare.zip.
#        | Downloading package sinica_treebank to /root/nltk_data...
#        |   Unzipping corpora/sinica_treebank.zip.
#        | Downloading package smultron to /root/nltk_data...
#        |   Unzipping corpora/smultron.zip.
#        | Downloading package state_union to /root/nltk_data...
#        |   Unzipping corpora/state_union.zip.
#        | Downloading package stopwords to /root/nltk_data...
#        |   Unzipping corpora/stopwords.zip.
#        | Downloading package subjectivity to /root/nltk_data...
#        |   Unzipping corpora/subjectivity.zip.
#        | Downloading package swadesh to /root/nltk_data...
#        |   Unzipping corpora/swadesh.zip.
#        | Downloading package switchboard to /root/nltk_data...
#        |   Unzipping corpora/switchboard.zip.
#        | Downloading package timit to /root/nltk_data...
#        |   Unzipping corpora/timit.zip.
#        | Downloading package toolbox to /root/nltk_data...
#        |   Unzipping corpora/toolbox.zip.
#        | Downloading package treebank to /root/nltk_data...
#        |   Unzipping corpora/treebank.zip.
#        | Downloading package twitter_samples to /root/nltk_data...
#        |   Unzipping corpora/twitter_samples.zip.
#        | Downloading package udhr to /root/nltk_data...
#        |   Unzipping corpora/udhr.zip.
#        | Downloading package udhr2 to /root/nltk_data...
#        |   Unzipping corpora/udhr2.zip.
#        | Downloading package unicode_samples to /root/nltk_data...
#        |   Unzipping corpora/unicode_samples.zip.
#        | Downloading package universal_treebanks_v20 to
#        |     /root/nltk_data...
#        | Downloading package verbnet to /root/nltk_data...
#        |   Unzipping corpora/verbnet.zip.
#        | Downloading package verbnet3 to /root/nltk_data...
#        |   Unzipping corpora/verbnet3.zip.
#        | Downloading package webtext to /root/nltk_data...
#        |   Unzipping corpora/webtext.zip.
#        | Downloading package wordnet to /root/nltk_data...
#        |   Unzipping corpora/wordnet.zip.
#        | Downloading package wordnet_ic to /root/nltk_data...
#        |   Unzipping corpora/wordnet_ic.zip.
#        | Downloading package words to /root/nltk_data...
#        |   Unzipping corpora/words.zip.
#        | Downloading package ycoe to /root/nltk_data...
#        |   Unzipping corpora/ycoe.zip.
#        | Downloading package rslp to /root/nltk_data...
#        |   Unzipping stemmers/rslp.zip.
#        | Downloading package maxent_treebank_pos_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
#        | Downloading package universal_tagset to /root/nltk_data...
#        |   Unzipping taggers/universal_tagset.zip.
#        | Downloading package maxent_ne_chunker to /root/nltk_data...
#        |   Unzipping chunkers/maxent_ne_chunker.zip.
#        | Downloading package punkt to /root/nltk_data...
#        |   Unzipping tokenizers/punkt.zip.
#        | Downloading package book_grammars to /root/nltk_data...
#        |   Unzipping grammars/book_grammars.zip.
#        | Downloading package sample_grammars to /root/nltk_data...
#        |   Unzipping grammars/sample_grammars.zip.
#        | Downloading package spanish_grammars to /root/nltk_data...
#        |   Unzipping grammars/spanish_grammars.zip.
#        | Downloading package basque_grammars to /root/nltk_data...
#        |   Unzipping grammars/basque_grammars.zip.
#        | Downloading package large_grammars to /root/nltk_data...
#        |   Unzipping grammars/large_grammars.zip.
#        | Downloading package tagsets to /root/nltk_data...
#        |   Unzipping help/tagsets.zip.
#        | Downloading package snowball_data to /root/nltk_data...
#        | Downloading package bllip_wsj_no_aux to /root/nltk_data...
#        |   Unzipping models/bllip_wsj_no_aux.zip.
#        | Downloading package word2vec_sample to /root/nltk_data...
#        |   Unzipping models/word2vec_sample.zip.
#        | Downloading package panlex_swadesh to /root/nltk_data...
#        | Downloading package mte_teip5 to /root/nltk_data...
#        |   Unzipping corpora/mte_teip5.zip.
#        | Downloading package averaged_perceptron_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger.zip.
#        | Downloading package averaged_perceptron_tagger_ru to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger_ru.zip.
#        | Downloading package perluniprops to /root/nltk_data...
#        |   Unzipping misc/perluniprops.zip.
#        | Downloading package nonbreaking_prefixes to
#        |     /root/nltk_data...
#        |   Unzipping corpora/nonbreaking_prefixes.zip.
#        | Downloading package vader_lexicon to /root/nltk_data...
#        | Downloading package porter_test to /root/nltk_data...
#        |   Unzipping stemmers/porter_test.zip.
#        | Downloading package wmt15_eval to /root/nltk_data...
#        |   Unzipping models/wmt15_eval.zip.
#        | Downloading package mwa_ppdb to /root/nltk_data...
#        |   Unzipping misc/mwa_ppdb.zip.
#        |
#      Done downloading collection all
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %% [markdown]
# Data Cleaning
#
# Converting to Lower Case

# %%
title_review['Lower Case'] = title_review['Review'].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %% [markdown]
# Removal of Punctuation

# %%
title_review['Removal of Punctuation'] = title_review['Lower Case'].str.replace('[^\w\s]','')

# %% [markdown]
# Removal of Special Characters

# %%
import re
title_review['Removal of Special Characters'] = title_review['Removal of Punctuation'].apply(lambda x: ''.join(re.sub(r"[^a-zA-Z0-9]+", ' ', charctr) for charctr in x ))

# %% [markdown]
# Removal of Stop words

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
title_review['Stopwords Removal'] = title_review['Removal of Punctuation'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

# %% [markdown]
# Spelling Correction

# %%
from textblob import TextBlob
title_review['Spelling Correction'] = title_review['Stopwords Removal'].apply(lambda x: str(TextBlob(x).correct()))

# %% [markdown]
# Tokenization

# %%
import nltk
nltk.download('punkt')
title_review['Tokenization'] = title_review['Spelling Correction'].apply(lambda x: TextBlob(x).words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# Stemming

# %%
from nltk.stem import PorterStemmer
st = PorterStemmer()
title_review['After Stemming'] = title_review['Tokenization'].apply(lambda x: " ".join([st.stem(word) for word in x]))

# %% [markdown]
# Lemmatization

# %%
from textblob import Word
import nltk
nltk.download('wordnet')

title_review['After Lemmatization'] = title_review['After Stemming'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
title_review.to_csv('/content/sample_data/reviwes.csv',index=False)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# 1.1 - Trigrams

# %%
import itertools
import collections
from nltk import ngrams
from nltk.tokenize import word_tokenize

words_sentence = []
for sentence in title_review['After Lemmatization']:
  words_sentence.append(word_tokenize(sentence))
aftercleaning = [x for x in words_sentence if x != []]
iterations = list(itertools.chain.from_iterable(aftercleaning))

# %%
tri_grams = nltk.trigrams(iterations)
frequency_dist = nltk.FreqDist(tri_grams)
frequency_dist
# Out:
# FreqDist({('everi', 'movi', 'come'): 1,
#           ('movi', 'come', 'truli'): 1,
#           ('come', 'truli', 'make'): 1,
#           ('truli', 'make', 'impact'): 1,
#           ('make', 'impact', 'joaquin'): 1,
#           ('impact', 'joaquin', 'perform'): 1,
#           ('joaquin', 'perform', 'scenographi'): 1,
#           ('perform', 'scenographi', 'brillianc'): 1,
#           ('scenographi', 'brillianc', 'grotesqu'): 1,
#           ('brillianc', 'grotesqu', 'hunt'): 1,
#           ('grotesqu', 'hunt', 'cring'): 1,
#           ('hunt', 'cring', 'hard'): 1,
#           ('cring', 'hard', 'watch'): 1,
#           ('hard', 'watch', 'time'): 1,
#           ('watch', 'time', 'mesmer'): 1,
#           ('time', 'mesmer', 'wont'): 1,
#           ('mesmer', 'wont', 'blink'): 1,
#           ('wont', 'blink', 'eye'): 1,
#           ('blink', 'eye', 'watch'): 1,
#           ('eye', 'watch', 'tragic'): 1,
#           ('watch', 'tragic', 'serious'): 1,
#           ('tragic', 'serious', 'funni'): 1,
#           ('serious', 'funni', 'moment'): 1,
#           ('funni', 'moment', 'emot'): 1,
#           ('moment', 'emot', 'rollercoast'): 1,
#           ('emot', 'rollercoast', 'sometim'): 1,
#           ('rollercoast', 'sometim', 'multipl'): 1,
#           ('sometim', 'multipl', 'emot'): 1,
#           ('multipl', 'emot', 'pop'): 1,
#           ('emot', 'pop', 'time'): 1,
#           ('pop', 'time', 'far'): 1,
#           ('time', 'far', 'typic'): 1,
#           ('far', 'typic', 'actionriddl'): 1,
#           ('typic', 'actionriddl', 'predict'): 1,
#           ('actionriddl', 'predict', 'superhero'): 1,
#           ('predict', 'superhero', 'movi'): 1,
#           ('superhero', 'movi', 'proper'): 1,
#           ('movi', 'proper', 'psycholog'): 1,
#           ('proper', 'psycholog', 'thrillerdrama'): 1,
#           ('psycholog', 'thrillerdrama', 'singl'): 1,
#           ('thrillerdrama', 'singl', 'best'): 1,
#           ('singl', 'best', 'charact'): 1,
#           ('best', 'charact', 'develop'): 1,
#           ('charact', 'develop', 'ever'): 1,
#           ('develop', 'ever', 'seen'): 1,
#           ('ever', 'seen', 'movi'): 2,
#           ('seen', 'movi', 'felt'): 1,
#           ('movi', 'felt', 'alon'): 1,
#           ('felt', 'alon', 'isol'): 1,
#           ('alon', 'isol', 'truli'): 1,
#           ('isol', 'truli', 'relat'): 1,
#           ('truli', 'relat', 'understand'): 1,
#           ('relat', 'understand', 'motiv'): 1,
#           ('understand', 'motiv', 'feel'): 1,
#           ('motiv', 'feel', 'sorri'): 1,
#           ('feel', 'sorri', 'charact'): 1,
#           ('sorri', 'charact', 'lot'): 1,
#           ('charact', 'lot', 'peopl'): 1,
#           ('lot', 'peopl', 'see'): 1,
#           ('peopl', 'see', 'movi'): 1,
#           ('see', 'movi', 'think'): 1,
#           ('movi', 'think', 'encourag'): 1,
#           ('think', 'encourag', 'violenc'): 1,
#           ('encourag', 'violenc', 'truli'): 1,
#           ('violenc', 'truli', 'movi'): 1,
#           ('truli', 'movi', 'encourag'): 1,
#           ('movi', 'encourag', 'everi'): 1,
#           ('encourag', 'everi', 'one'): 1,
#           ('everi', 'one', 'u'): 1,
#           ('one', 'u', 'becom'): 1,
#           ('u', 'becom', 'better'): 1,
#           ('becom', 'better', 'person'): 1,
#           ('better', 'person', 'treat'): 1,
#           ('person', 'treat', 'everyon'): 1,
#           ('treat', 'everyon', 'respect'): 1,
#           ('everyon', 'respect', 'make'): 1,
#           ('respect', 'make', 'feel'): 1,
#           ('make', 'feel', 'like'): 1,
#           ('feel', 'like', 'belong'): 1,
#           ('like', 'belong', 'world'): 1,
#           ('belong', 'world', 'instead'): 1,
#           ('world', 'instead', 'make'): 1,
#           ('instead', 'make', 'feel'): 1,
#           ('make', 'feel', 'isol'): 1,
#           ('feel', 'isol', 'truli'): 1,
#           ('isol', 'truli', 'masterpiec'): 1,
#           ('truli', 'masterpiec', 'best'): 1,
#           ('masterpiec', 'best', 'hollywood'): 1,
#           ('best', 'hollywood', 'film'): 1,
#           ('hollywood', 'film', '2019'): 1,
#           ('film', '2019', 'one'): 1,
#           ('2019', 'one', 'best'): 1,
#           ('one', 'best', 'film'): 1,
#           ('best', 'film', 'decad'): 1,
#           ('film', 'decad', 'truli'): 1,
#           ('decad', 'truli', 'best'): 1,
#           ('truli', 'best', 'film'): 1,
#           ('best', 'film', 'bring'): 1,
#           ('film', 'bring', 'comic'): 1,
#           ('bring', 'comic', 'book'): 1,
#           ('comic', 'book', 'willingli'): 1,
#           ('book', 'willingli', 'realist'): 1,
#           ('willingli', 'realist', 'real'): 1,
#           ('realist', 'real', 'if'): 1,
#           ('real', 'if', 'remark'): 1,
#           ('if', 'remark', 'direct'): 1,
#           ('remark', 'direct', 'cinematographi'): 1,
#           ('direct', 'cinematographi', 'music'): 1,
#           ('cinematographi', 'music', 'act'): 1,
#           ('music', 'act', 'peopl'): 1,
#           ('act', 'peopl', 'surpris'): 1,
#           ('peopl', 'surpris', 'find'): 1,
#           ('surpris', 'find', 'disturb'): 1,
#           ('find', 'disturb', 'violent'): 1,
#           ('disturb', 'violent', 'necess'): 1,
#           ('violent', 'necess', 'messag'): 1,
#           ('necess', 'messag', 'societi'): 1,
#           ('messag', 'societi', 'reflect'): 1,
#           ('societi', 'reflect', 'underappreciatedunrecognizedbulli'): 1,
#           ('reflect', 'underappreciatedunrecognizedbulli', 'peopl'): 1,
#           ('underappreciatedunrecognizedbulli', 'peopl', 'prove'): 1,
#           ('peopl', 'prove', 'someth'): 1,
#           ('prove', 'someth', 'way'): 1,
#           ('someth', 'way', 'show'): 1,
#           ('way', 'show', 'class'): 1,
#           ('show', 'class', 'differ'): 1,
#           ('class', 'differ', 'corrupt'): 1,
#           ('differ', 'corrupt', 'rich'): 1,
#           ('corrupt', 'rich', 'talent'): 1,
#           ('rich', 'talent', 'rule'): 1,
#           ('talent', 'rule', 'other'): 1,
#           ('rule', 'other', 'around'): 1,
#           ('other', 'around', 'exagger'): 1,
#           ('around', 'exagger', 'that'): 1,
#           ('exagger', 'that', 'make'): 1,
#           ('that', 'make', 'differ'): 1,
#           ('make', 'differ', 'believ'): 1,
#           ('differ', 'believ', 'could'): 1,
#           ('believ', 'could', 'multipl'): 1,
#           ('could', 'multipl', 'joke'): 1,
#           ('multipl', 'joke', 'live'): 1,
#           ('joke', 'live', 'societi'): 1,
#           ('live', 'societi', 'could'): 1,
#           ('societi', 'could', 'shake'): 1,
#           ('could', 'shake', 'around'): 1,
#           ('shake', 'around', 'much'): 1,
#           ('around', 'much', 'bitter'): 1,
#           ('much', 'bitter', 'way'): 1,
#           ('bitter', 'way', 'film'): 1,
#           ('way', 'film', 'show'): 1,
#           ('film', 'show', 'make'): 1,
#           ('show', 'make', 'peopl'): 1,
#           ('make', 'peopl', 'comfort'): 1,
#           ('peopl', 'comfort', 'peopl'): 1,
#           ('comfort', 'peopl', 'consid'): 1,
#           ('peopl', 'consid', 'wake'): 1,
#           ('consid', 'wake', 'call'): 1,
#           ('wake', 'call', 'messag'): 1,
#           ('call', 'messag', 'first'): 1,
#           ('messag', 'first', 'film'): 1,
#           ('first', 'film', 'perfect'): 1,
#           ('film', 'perfect', 'film'): 1,
#           ('perfect', 'film', 'joaquin'): 1,
#           ('film', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'give'): 2,
#           ('phoenix', 'give', 'tour'): 1,
#           ('give', 'tour', 'de'): 1,
#           ('tour', 'de', 'forc'): 1,
#           ('de', 'forc', 'perform'): 1,
#           ('forc', 'perform', 'fearless'): 1,
#           ('perform', 'fearless', 'stun'): 1,
#           ('fearless', 'stun', 'emot'): 1,
#           ('stun', 'emot', 'depth'): 1,
#           ('emot', 'depth', 'physic'): 1,
#           ('depth', 'physic', 'imposs'): 1,
#           ('physic', 'imposs', 'talk'): 1,
#           ('imposs', 'talk', 'without'): 1,
#           ('talk', 'without', 'referenc'): 1,
#           ('without', 'referenc', 'heath'): 1,
#           ('referenc', 'heath', 'ledger'): 1,
#           ('heath', 'ledger', 'oscarwin'): 1,
#           ('ledger', 'oscarwin', 'perform'): 1,
#           ('oscarwin', 'perform', 'dark'): 1,
#           ('perform', 'dark', 'knight'): 1,
#           ('dark', 'knight', 'wide'): 1,
#           ('knight', 'wide', 'consid'): 1,
#           ('wide', 'consid', 'definit'): 1,
#           ('consid', 'definit', 'liveact'): 1,
#           ('definit', 'liveact', 'portray'): 1,
#           ('liveact', 'portray', 'joke'): 1,
#           ('portray', 'joke', 'let'): 1,
#           ('joke', 'let', 'talk'): 1,
#           ('let', 'talk', 'fact'): 1,
#           ('talk', 'fact', 'everyon'): 1,
#           ('fact', 'everyon', 'go'): 1,
#           ('everyon', 'go', 'stun'): 1,
#           ('go', 'stun', 'phoenix'): 1,
#           ('stun', 'phoenix', 'accomplish'): 1,
#           ('phoenix', 'accomplish', 'mani'): 1,
#           ('accomplish', 'mani', 'thought'): 1,
#           ('mani', 'thought', 'imposs'): 1,
#           ('thought', 'imposs', 'portray'): 1,
#           ('imposs', 'portray', 'match'): 1,
#           ('portray', 'match', 'potenti'): 1,
#           ('match', 'potenti', 'exce'): 1,
#           ('potenti', 'exce', 'dark'): 1,
#           ('exce', 'dark', 'knight'): 1,
#           ('dark', 'knight', 'clown'): 1,
#           ('knight', 'clown', 'princ'): 1,
#           ('clown', 'princ', 'crime'): 3,
#           ('princ', 'crime', 'time'): 1,
#           ('crime', 'time', 'move'): 1,
#           ('time', 'move', 'anticip'): 1,
#           ('move', 'anticip', 'like'): 1,
#           ('anticip', 'like', 'end'): 1,
#           ('like', 'end', 'fall'): 1,
#           ('end', 'fall', 'short'): 1,
#           ('fall', 'short', 'way'): 1,
#           ('short', 'way', 'short'): 1,
#           ('way', 'short', 'joke'): 1,
#           ('short', 'joke', 'first'): 1,
#           ('joke', 'first', 'time'): 1,
#           ('first', 'time', 'happi'): 1,
#           ('time', 'happi', 'hope'): 1,
#           ('happi', 'hope', 'plea'): 1,
#           ('hope', 'plea', 'ignor'): 1,
#           ('plea', 'ignor', 'complaint'): 1,
#           ('ignor', 'complaint', 'pernici'): 1,
#           ('complaint', 'pernici', 'violenc'): 1,
#           ('pernici', 'violenc', 'embarrass'): 1,
#           ('violenc', 'embarrass', 'say'): 1,
#           ('embarrass', 'say', 'least'): 1,
#           ('say', 'least', 'haven'): 1,
#           ('least', 'haven', 'seen'): 1,
#           ('haven', 'seen', 'comic'): 1,
#           ('seen', 'comic', 'movi'): 1,
#           ('comic', 'movi', 'real'): 1,
#           ('movi', 'real', 'ever'): 1,
#           ('real', 'ever', 'deserv'): 1,
#           ('ever', 'deserv', 'better'): 1,
#           ('deserv', 'better', 'class'): 1,
#           ('better', 'class', 'crimin'): 1,
#           ('class', 'crimin', 'phillip'): 1,
#           ('crimin', 'phillip', 'phoenix'): 1,
#           ('phillip', 'phoenix', 'deliv'): 1,
#           ('phoenix', 'deliv', 'dark'): 1,
#           ('deliv', 'dark', 'joke'): 1,
#           ('dark', 'joke', 'dark'): 1,
#           ('joke', 'dark', 'fall'): 1,
#           ('dark', 'fall', 'love'): 1,
#           ('fall', 'love', 'villain'): 1,
#           ('love', 'villain', 'bad'): 1,
#           ('villain', 'bad', 'gun'): 1,
#           ('bad', 'gun', 'alway'): 1,
#           ('gun', 'alway', 'romant'): 1,
#           ('alway', 'romant', 'anyway'): 1,
#           ('romant', 'anyway', 'let'): 1,
#           ('anyway', 'let', 'start'): 1,
#           ('let', 'start', 'say'): 1,
#           ('start', 'say', 'joaquin'): 1,
#           ('say', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'doesn'): 2,
#           ('phoenix', 'doesn', 'get'): 1,
#           ('doesn', 'get', 'oscar'): 1,
#           ('get', 'oscar', 'movi'): 1,
#           ('oscar', 'movi', 'scar'): 1,
#           ('movi', 'scar', 'cancel'): 1,
#           ('scar', 'cancel', 'phoenix'): 1,
#           ('cancel', 'phoenix', 'amaz'): 1,
#           ('phoenix', 'amaz', 'might'): 1,
#           ('amaz', 'might', 'heard'): 1,
#           ('might', 'heard', 'everi'): 1,
#           ('heard', 'everi', 'review'): 1,
#           ('everi', 'review', 'ever'): 1,
#           ('review', 'ever', 'told'): 1,
#           ('ever', 'told', 'phillip'): 1,
#           ('told', 'phillip', 'best'): 1,
#           ('phillip', 'best', 'stori'): 1,
#           ('best', 'stori', 'line'): 1,
#           ('stori', 'line', 'take'): 1,
#           ('line', 'take', 'visual'): 1,
#           ('take', 'visual', 'breathtak'): 1,
#           ('visual', 'breathtak', 'score'): 1,
#           ('breathtak', 'score', 'org'): 1,
#           ('score', 'org', 'score'): 1,
#           ('org', 'score', 'everi'): 1,
#           ('score', 'everi', 'time'): 1,
#           ('everi', 'time', 'score'): 1,
#           ('time', 'score', 'came'): 1,
#           ('score', 'came', 'felt'): 1,
#           ('came', 'felt', 'uncomfort'): 1,
#           ('felt', 'uncomfort', 'like'): 1,
#           ('uncomfort', 'like', 'someth'): 1,
#           ('like', 'someth', 'horribl'): 1,
#           ('someth', 'horribl', 'happen'): 1,
#           ('horribl', 'happen', 'great'): 1,
#           ('happen', 'great', 'inspir'): 1,
#           ('great', 'inspir', 'taxi'): 1,
#           ('inspir', 'taxi', 'driver'): 2,
#           ('taxi', 'driver', 'king'): 2,
#           ('driver', 'king', 'comedi'): 2,
#           ('king', 'comedi', 'add'): 1,
#           ('comedi', 'add', 'much'): 1,
#           ('add', 'much', 'movi'): 1,
#           ('much', 'movi', 'got'): 1,
#           ('movi', 'got', 'honest'): 1,
#           ('got', 'honest', 'scene'): 1,
#           ('honest', 'scene', 'violent'): 1,
#           ('scene', 'violent', 'disturb'): 1,
#           ('violent', 'disturb', 'honestli'): 1,
#           ('disturb', 'honestli', 'expect'): 1,
#           ('honestli', 'expect', 'wayyyi'): 1,
#           ('expect', 'wayyyi', 'violent'): 1,
#           ('wayyyi', 'violent', 'controversi'): 1,
#           ('violent', 'controversi', 'go'): 1,
#           ('controversi', 'go', 'overal'): 1,
#           ('go', 'overal', 'movi'): 1,
#           ('overal', 'movi', 'great'): 1,
#           ('movi', 'great', 'come'): 1,
#           ('great', 'come', 'oscar'): 1,
#           ('come', 'oscar', 'season'): 1,
#           ('oscar', 'season', 'need'): 1,
#           ('season', 'need', 'nomin'): 1,
#           ('need', 'nomin', 'best'): 1,
#           ('nomin', 'best', 'pictur'): 1,
#           ('best', 'pictur', 'screenplay'): 1,
#           ('pictur', 'screenplay', 'cinematographi'): 1,
#           ('screenplay', 'cinematographi', 'actor'): 1,
#           ('cinematographi', 'actor', 'score'): 1,
#           ('actor', 'score', 'director'): 1,
#           ('score', 'director', 'get'): 1,
#           ('director', 'get', 'peopl'): 1,
#           ('get', 'peopl', 'hate'): 1,
#           ('peopl', 'hate', 'polit'): 1,
#           ('hate', 'polit', 'messag'): 1,
#           ('polit', 'messag', 'peopl'): 1,
#           ('messag', 'peopl', 'think'): 1,
#           ('peopl', 'think', 'need'): 1,
#           ('think', 'need', 'get'): 1,
#           ('need', 'get', 'empti'): 1,
#           ('get', 'empti', 'arthur'): 1,
#           ('empti', 'arthur', 'mad'): 1,
#           ('arthur', 'mad', 'come'): 1,
#           ('mad', 'come', 'point'): 1,
#           ('come', 'point', 'never'): 1,
#           ('point', 'never', 'enjoy'): 1,
#           ('never', 'enjoy', 'masterpiec'): 1,
#           ('enjoy', 'masterpiec', 'joaquin'): 1,
#           ('masterpiec', 'joaquin', 'phoenix'): 2,
#           ('joaquin', 'phoenix', 'told'): 1,
#           ('phoenix', 'told', 'phillip'): 1,
#           ('told', 'phillip', 'overdid'): 1,
#           ('phillip', 'overdid', 'movi'): 1,
#           ('overdid', 'movi', 'actingmus'): 1,
#           ('movi', 'actingmus', 'cinematographi'): 1,
#           ('actingmus', 'cinematographi', 'amaz'): 1,
#           ('cinematographi', 'amaz', 'plea'): 1,
#           ('amaz', 'plea', 'enjoy'): 1,
#           ('plea', 'enjoy', 'movi'): 1,
#           ('enjoy', 'movi', 'without'): 1,
#           ('movi', 'without', 'overthink'): 1,
#           ('without', 'overthink', 'seen'): 1,
#           ('overthink', 'seen', 'joke'): 1,
#           ('seen', 'joke', 'yesterday'): 1,
#           ('joke', 'yesterday', 'venic'): 1,
#           ('yesterday', 'venic', 'earli'): 1,
#           ('venic', 'earli', 'inflat'): 1,
#           ('earli', 'inflat', 'screen'): 1,
#           ('inflat', 'screen', 'troubl'): 1,
#           ('screen', 'troubl', 'audit'): 1,
#           ('troubl', 'audit', 'lead'): 1,
#           ('audit', 'lead', 'nearhour'): 1,
#           ('lead', 'nearhour', 'delay'): 1,
#           ('nearhour', 'delay', 'definit'): 1,
#           ('delay', 'definit', 'worth'): 1,
#           ('definit', 'worth', 'joke'): 1,
#           ('worth', 'joke', 'deserv'): 1,
#           ('joke', 'deserv', 'present'): 1,
#           ('deserv', 'present', 'venic'): 1,
#           ('present', 'venic', 'film'): 1,
#           ('venic', 'film', 'festiv'): 1,
#           ('film', 'festiv', 'event'): 1,
#           ('festiv', 'event', 'regard'): 1,
#           ('event', 'regard', 'cinema'): 1,
#           ('regard', 'cinema', 'form'): 1,
#           ('cinema', 'form', 'art'): 1,
#           ('form', 'art', 'film'): 1,
#           ('art', 'film', 'far'): 1,
#           ('film', 'far', 'blockbust'): 1,
#           ('far', 'blockbust', 'mere'): 1,
#           ('blockbust', 'mere', 'entertain'): 1,
#           ('mere', 'entertain', 'movi'): 1,
#           ('entertain', 'movi', 'film'): 1,
#           ('movi', 'film', 'gene'): 1,
#           ('film', 'gene', 'focus'): 1,
#           ('gene', 'focus', 'psychic'): 1,
#           ('focus', 'psychic', 'main'): 1,
#           ('psychic', 'main', 'charact'): 1,
#           ('main', 'charact', 'slowli'): 1,
#           ('charact', 'slowli', 'crumbl'): 1,
#           ('slowli', 'crumbl', 'pressur'): 1,
#           ('crumbl', 'pressur', 'societi'): 1,
#           ('pressur', 'societi', 'thu'): 1,
#           ('societi', 'thu', 'joaquin'): 1,
#           ('thu', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'wonder'): 1,
#           ('phoenix', 'wonder', 'perform'): 1,
#           ('wonder', 'perform', 'earn'): 1,
#           ('perform', 'earn', 'almost'): 1,
#           ('earn', 'almost', 'sure'): 1,
#           ('almost', 'sure', 'nomin'): 1,
#           ('sure', 'nomin', 'scar'): 1,
#           ('nomin', 'scar', 'least'): 1,
#           ('scar', 'least', 'take'): 1,
#           ('least', 'take', 'joke'): 1,
#           ('take', 'joke', 'differ'): 1,
#           ('joke', 'differ', 'ledger'): 1,
#           ('differ', 'ledger', 'id'): 1,
#           ('ledger', 'id', 'say'): 1,
#           ('id', 'say', 'equal'): 1,
#           ('say', 'equal', 'good'): 1,
#           ('equal', 'good', 'main'): 1,
#           ('good', 'main', 'differ'): 1,
#           ('main', 'differ', 'might'): 1,
#           ('differ', 'might', 'ledger'): 1,
#           ('might', 'ledger', 'joke'): 1,
#           ('ledger', 'joke', 'ration'): 1,
#           ('joke', 'ration', 'act'): 1,
#           ('ration', 'act', 'insan'): 1,
#           ('act', 'insan', 'phoenix'): 1,
#           ('insan', 'phoenix', 'insan'): 1,
#           ('phoenix', 'insan', 'root'): 1,
#           ('insan', 'root', 'despit'): 1,
#           ('root', 'despit', 'movi'): 1,
#           ('despit', 'movi', 'superhero'): 1,
#           ('movi', 'superhero', 'villain'): 1,
#           ('superhero', 'villain', 'joke'): 1,
#           ('villain', 'joke', 'much'): 1,
#           ('joke', 'much', 'superior'): 1,
#           ('much', 'superior', 'move'): 1,
#           ('superior', 'move', 'gene'): 1,
#           ('move', 'gene', 'id'): 1,
#           ('gene', 'id', 'exclud'): 1,
#           ('id', 'exclud', 'dark'): 1,
#           ('exclud', 'dark', 'knight'): 1,
#           ('dark', 'knight', 'trilog'): 1,
#           ('knight', 'trilog', 'joke'): 1,
#           ('trilog', 'joke', 'easili'): 1,
#           ('joke', 'easili', 'good'): 1,
#           ('easili', 'good', 'plan'): 1,
#           ('good', 'plan', 'move'): 1,
#           ('plan', 'move', 'least'): 1,
#           ('move', 'least', 'close'): 1,
#           ('least', 'close', 'smallscal'): 1,
#           ('close', 'smallscal', 'film'): 1,
#           ('smallscal', 'film', 'distinct'): 1,
#           ('film', 'distinct', 'style'): 1,
#           ('distinct', 'style', 'cinematographi'): 1,
#           ('style', 'cinematographi', 'can'): 1,
#           ('cinematographi', 'can', 'not'): 1,
#           ('can', 'not', 'appreci'): 1,
#           ('not', 'appreci', 'set'): 1,
#           ('appreci', 'set', 'cinephil'): 1,
#           ('set', 'cinephil', 'refer'): 1,
#           ('cinephil', 'refer', 'howev'): 1,
#           ('refer', 'howev', 'feel'): 1,
#           ('howev', 'feel', 'forc'): 1,
#           ('feel', 'forc', 'overlay'): 1,
#           ('forc', 'overlay', 'oppress'): 1,
#           ('overlay', 'oppress', 'notabl'): 1,
#           ('oppress', 'notabl', 'similar'): 1,
#           ('notabl', 'similar', 'scorses'): 1,
#           ('similar', 'scorses', 'taxi'): 1,
#           ('scorses', 'taxi', 'driver'): 1,
#           ('king', 'comedi', 'also'): 1,
#           ('comedi', 'also', 'chain'): 1,
#           ('also', 'chain', 'modern'): 1,
#           ('chain', 'modern', 'time'): 1,
#           ('modern', 'time', 'somewhat'): 1,
#           ('time', 'somewhat', 'refer'): 1,
#           ('somewhat', 'refer', 'eager'): 1,
#           ('refer', 'eager', 'see'): 1,
#           ('eager', 'see', 'noncomed'): 1,
#           ('see', 'noncomed', 'effort'): 1,
#           ('noncomed', 'effort', 'told'): 1,
#           ('effort', 'told', 'phillip'): 1,
#           ('told', 'phillip', 'movi'): 1,
#           ('phillip', 'movi', 'far'): 1,
#           ('movi', 'far', 'probabl'): 1,
#           ('far', 'probabl', 'best'): 1,
#           ('probabl', 'best', '2019'): 1,
#           ('best', '2019', 'worst'): 1,
#           ('2019', 'worst', 'contest'): 1,
#           ('worst', 'contest', 'far'): 1,
#           ('contest', 'far', 'door'): 1,
#           ('far', 'door', 'gloria'): 1,
#           ('door', 'gloria', 'upon'): 1,
#           ('gloria', 'upon', 'time'): 1,
#           ('upon', 'time', 'hollywood'): 2,
#           ('time', 'hollywood', 'convinc'): 1,
#           ('hollywood', 'convinc', 'sad'): 1,
#           ('convinc', 'sad', 'joaquin'): 1,
#           ('sad', 'joaquin', 'miss'): 1,
#           ('joaquin', 'miss', 'oscar'): 1,
#           ('miss', 'oscar', 'gladiat'): 1,
#           ('oscar', 'gladiat', 'compel'): 1,
#           ('gladiat', 'compel', 'villain'): 1,
#           ('compel', 'villain', 'quit'): 1,
#           ('villain', 'quit', 'confid'): 1,
#           ('quit', 'confid', 'win'): 1,
#           ('confid', 'win', 'joke'): 1,
#           ('win', 'joke', 'damn'): 1,
#           ('joke', 'damn', 'movi'): 1,
#           ('damn', 'movi', 'keep'): 1,
#           ('movi', 'keep', 'u'): 1,
#           ('keep', 'u', 'toe'): 1,
#           ('u', 'toe', 'time'): 1,
#           ('toe', 'time', 'predict'): 1,
#           ('time', 'predict', 'storylin'): 1,
#           ('predict', 'storylin', 'realli'): 1,
#           ('storylin', 'realli', 'deep'): 1,
#           ('realli', 'deep', 'interest'): 1,
#           ('deep', 'interest', 'plot'): 1,
#           ('interest', 'plot', 'forget'): 1,
#           ('plot', 'forget', 'mention'): 1,
#           ('forget', 'mention', 'act'): 1,
#           ('mention', 'act', 'damn'): 1,
#           ('act', 'damn', 'no'): 1,
#           ('damn', 'no', 'joaquin'): 1,
#           ('no', 'joaquin', 'teach'): 1,
#           ('joaquin', 'teach', 'u'): 1,
#           ('teach', 'u', 'realli'): 1,
#           ('u', 'realli', '5'): 1,
#           ('realli', '5', 'star'): 1,
#           ('5', 'star', 'act'): 1,
#           ('star', 'act', 'enjoy'): 1,
#           ('act', 'enjoy', 'movi'): 1,
#           ('enjoy', 'movi', 'get'): 1,
#           ('movi', 'get', 'wine'): 1,
#           ('get', 'wine', 'hand'): 1,
#           ('wine', 'hand', 'close'): 1,
#           ('hand', 'close', 'curtain'): 1,
#           ('close', 'curtain', 'turn'): 1,
#           ('curtain', 'turn', 'or'): 1,
#           ('turn', 'or', 'cellphon'): 1,
#           ('or', 'cellphon', 'put'): 1,
#           ('cellphon', 'put', 'disturb'): 1,
#           ('put', 'disturb', 'sign'): 1,
#           ('disturb', 'sign', 'or'): 1,
#           ('sign', 'or', 'door'): 1,
#           ('or', 'door', 'best'): 1,
#           ('door', 'best', 'dark'): 1,
#           ('best', 'dark', 'thrill'): 1,
#           ('dark', 'thrill', 'suspens'): 1,
#           ('thrill', 'suspens', 'movi'): 1,
#           ('suspens', 'movi', 'get'): 1,
#           ('movi', 'get', 'experi'): 1,
#           ('get', 'experi', 'movi'): 1,
#           ('experi', 'movi', 'caus'): 1,
#           ('movi', 'caus', 'audienc'): 1,
#           ('caus', 'audienc', 'consid'): 1,
#           ('audienc', 'consid', 'mani'): 1,
#           ('consid', 'mani', 'topic'): 1,
#           ('mani', 'topic', 'moral'): 1,
#           ('topic', 'moral', 'particularli'): 1,
#           ('moral', 'particularli', 'poor'): 1,
#           ('particularli', 'poor', 'choic'): 1,
#           ('poor', 'choic', 'made'): 1,
#           ('choic', 'made', 'joke'): 1,
#           ('made', 'joke', 'joke'): 1,
#           ('joke', 'joke', 'reliabl'): 1,
#           ('joke', 'reliabl', 'movi'): 1,
#           ('reliabl', 'movi', 'antagonist'): 1,
#           ('movi', 'antagonist', 'usual'): 1,
#           ('antagonist', 'usual', 'think'): 1,
#           ('usual', 'think', 'give'): 1,
#           ('think', 'give', 'realist'): 1,
#           ('give', 'realist', 'view'): 1,
#           ('realist', 'view', 'bad'): 1,
#           ('view', 'bad', 'peopl'): 1,
#           ('bad', 'peopl', 'usual'): 1,
#           ('peopl', 'usual', '100'): 1,
#           ('usual', '100', 'bad'): 1,
#           ('100', 'bad', 'way'): 1,
#           ('bad', 'way', 'societi'): 1,
#           ('way', 'societi', 'often'): 1,
#           ('societi', 'often', 'judg'): 1,
#           ('often', 'judg', 'import'): 1,
#           ('judg', 'import', 'know'): 1,
#           ('import', 'know', 'sympath'): 1,
#           ('know', 'sympath', 'joke'): 1,
#           ('sympath', 'joke', 'toward'): 1,
#           ('joke', 'toward', 'begin'): 1,
#           ('toward', 'begin', 'movi'): 1,
#           ('begin', 'movi', 'need'): 1,
#           ('movi', 'need', 'identifi'): 1,
#           ('need', 'identifi', 'threat'): 1,
#           ('identifi', 'threat', 'begin'): 1,
#           ('threat', 'begin', 'make'): 1,
#           ('begin', 'make', 'certain'): 1,
#           ('make', 'certain', 'bad'): 1,
#           ('certain', 'bad', 'choic'): 1,
#           ('bad', 'choic', 'movi'): 1,
#           ('choic', 'movi', 'suitabl'): 1,
#           ('movi', 'suitabl', 'adult'): 1,
#           ('suitabl', 'adult', 'will'): 1,
#           ('adult', 'will', 'pick'): 1,
#           ('will', 'pick', 'apart'): 1,
#           ('pick', 'apart', 'think'): 1,
#           ('apart', 'think', 'clinic'): 1,
#           ('think', 'clinic', 'isn'): 1,
#           ('clinic', 'isn', 'light'): 1,
#           ('isn', 'light', 'amus'): 1,
#           ('light', 'amus', 'substanc'): 1,
#           ('amus', 'substanc', 'make'): 1,
#           ('substanc', 'make', 'good'): 1,
#           ('make', 'good', 'agent'): 1,
#           ('good', 'agent', 'abl'): 1,
#           ('agent', 'abl', 'ponder'): 1,
#           ('abl', 'ponder', 'underli'): 1,
#           ('ponder', 'underli', 'theme'): 1,
#           ('underli', 'theme', 'hand'): 1,
#           ('theme', 'hand', 'thought'): 1,
#           ('hand', 'thought', 'isn'): 1,
#           ('thought', 'isn', 'best'): 1,
#           ('isn', 'best', 'movi'): 1,
#           ('best', 'movi', 'movi'): 1,
#           ('movi', 'movi', 'affect'): 1,
#           ('movi', 'affect', 'way'): 1,
#           ('affect', 'way', 'make'): 1,
#           ('way', 'make', 'physic'): 1,
#           ('make', 'physic', 'pain'): 1,
#           ('physic', 'pain', 'experi'): 1,
#           ('pain', 'experi', 'good'): 1,
#           ('experi', 'good', 'way'): 1,
#           ('good', 'way', 'act'): 1,
#           ('way', 'act', 'cinematographi'): 1,
#           ('act', 'cinematographi', 'sound'): 1,
#           ('cinematographi', 'sound', 'design'): 1,
#           ('sound', 'design', 'script'): 1,
#           ('design', 'script', 'phenomenon'): 1,
#           ('script', 'phenomenon', 'movi'): 1,
#           ('phenomenon', 'movi', 'triumph'): 1,
#           ('movi', 'triumph', 'joaquin'): 1,
#           ('triumph', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'deserv'): 2,
#           ('phoenix', 'deserv', 'oscar'): 2,
#           ('deserv', 'oscar', 'win'): 1,
#           ('oscar', 'win', 'th'): 1,
#           ('win', 'th', 'need'): 1,
#           ('th', 'need', 'say'): 1,
#           ('need', 'say', 'everyth'): 1,
#           ('say', 'everyth', 'movi'): 1,
#           ('everyth', 'movi', 'wast'): 1,
#           ('movi', 'wast', 'everi'): 1,
#           ('wast', 'everi', 'singl'): 1,
#           ('everi', 'singl', 'way'): 1,
#           ('singl', 'way', 'joke'): 1,
#           ('way', 'joke', 'isn'): 1,
#           ('joke', 'isn', 'awesom'): 1,
#           ('isn', 'awesom', 'comic'): 1,
#           ('awesom', 'comic', 'book'): 1,
#           ('comic', 'book', 'movi'): 2,
#           ('book', 'movi', 'awesom'): 1,
#           ('movi', 'awesom', 'movi'): 1,
#           ('awesom', 'movi', 'period'): 1,
#           ('movi', 'period', 'offer'): 1,
#           ('period', 'offer', 'easi'): 1,
#           ('offer', 'easi', 'answer'): 1,
#           ('easi', 'answer', 'settl'): 1,
#           ('answer', 'settl', 'question'): 1,
#           ('settl', 'question', 'rais'): 1,
#           ('question', 'rais', 'cruel'): 1,
#           ('rais', 'cruel', 'societi'): 1,
#           ('cruel', 'societi', 'declin'): 1,
#           ('societi', 'declin', 'joaquin'): 1,
#           ('declin', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'fulli'): 1,
#           ('phoenix', 'fulli', 'commit'): 1,
#           ('fulli', 'commit', 'perform'): 1,
#           ('commit', 'perform', 'told'): 1,
#           ('perform', 'told', 'phillip'): 1,
#           ('told', 'phillip', 'wast'): 1,
#           ('phillip', 'wast', 'albeit'): 1,
#           ('wast', 'albeit', 'loo'): 1,
#           ('albeit', 'loo', 'invent'): 1,
#           ('loo', 'invent', 'do'): 1,
#           ('invent', 'do', 'sourc'): 1,
#           ('do', 'sourc', 'materi'): 1,
#           ('sourc', 'materi', 'make'): 1,
#           ('materi', 'make', 'joke'): 1,
#           ('make', 'joke', 'film'): 1,
#           ('joke', 'film', 'leav'): 1,
#           ('film', 'leav', 'comic'): 1,
#           ('leav', 'comic', 'book'): 1,
#           ('comic', 'book', 'fan'): 1,
#           ('book', 'fan', 'nonfan'): 1,
#           ('fan', 'nonfan', 'alik'): 1,
#           ('nonfan', 'alik', 'disturb'): 1,
#           ('alik', 'disturb', 'move'): 1,
#           ('disturb', 'move', 'right'): 1,
#           ('move', 'right', 'way'): 1,
#           ('right', 'way', 'stop'): 1,
#           ('way', 'stop', 'watch'): 1,
#           ('stop', 'watch', 'move'): 1,
#           ('watch', 'move', 'joaquin'): 1,
#           ('move', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'award'): 1,
#           ('phoenix', 'award', 'oscar'): 1,
#           ('award', 'oscar', 'tremend'): 1,
#           ('oscar', 'tremend', 'act'): 1,
#           ('tremend', 'act', 'quit'): 1,
#           ('act', 'quit', 'reli'): 1,
#           ('quit', 'reli', 'critic'): 1,
#           ('reli', 'critic', 'review'): 1,
#           ('critic', 'review', 'year'): 1,
#           ('review', 'year', 'ago'): 1,
#           ('year', 'ago', 'notic'): 1,
#           ('ago', 'notic', 'movi'): 1,
#           ('notic', 'movi', 'critic'): 1,
#           ('movi', 'critic', 'rate'): 1,
#           ('critic', 'rate', 'low'): 1,
#           ('rate', 'low', 'viewer'): 1,
#           ('low', 'viewer', 'rate'): 1,
#           ('viewer', 'rate', 'high'): 1,
#           ('rate', 'high', 'said'): 1,
#           ('high', 'said', 'point'): 1,
#           ('said', 'point', 'critic'): 1,
#           ('point', 'critic', 'movi'): 1,
#           ('critic', 'movi', 'oh'): 1,
#           ('movi', 'oh', 'wrong'): 1,
#           ('oh', 'wrong', 'went'): 1,
#           ('wrong', 'went', 'saw'): 1,
#           ('went', 'saw', 'tone'): 1,
#           ('saw', 'tone', 'mon'): 1,
#           ('tone', 'mon', 'went'): 1,
#           ('mon', 'went', 'skeptic'): 1,
#           ('went', 'skeptic', 'w'): 1,
#           ('skeptic', 'w', 'low'): 1,
#           ('w', 'low', 'expect'): 1,
#           ('low', 'expect', 'knew'): 1,
#           ('expect', 'knew', 'expect'): 1,
#           ('knew', 'expect', 'typic'): 1,
#           ('expect', 'typic', 'super'): 1,
#           ('typic', 'super', 'hero'): 1,
#           ('super', 'hero', 'movi'): 1,
#           ('hero', 'movi', 'got'): 1,
#           ('movi', 'got', 'masterpiec'): 1,
#           ('got', 'masterpiec', 'went'): 1,
#           ('masterpiec', 'went', 'expect'): 1,
#           ('went', 'expect', 'sheer'): 1,
#           ('expect', 'sheer', 'boredom'): 1,
#           ('sheer', 'boredom', 'instead'): 1,
#           ('boredom', 'instead', 'edg'): 1,
#           ('instead', 'edg', 'seat'): 1,
#           ('edg', 'seat', 'whole'): 1,
#           ('seat', 'whole', 'time'): 1,
#           ('whole', 'time', 'action'): 1,
#           ('time', 'action', 'edg'): 1,
#           ('action', 'edg', 'seat'): 1,
#           ('edg', 'seat', 'fear'): 1,
#           ('seat', 'fear', 'may'): 1,
#           ('fear', 'may', 'say'): 1,
#           ('may', 'say', 'next'): 1,
#           ('say', 'next', 'edg'): 1,
#           ('next', 'edg', 'seat'): 1,
#           ('edg', 'seat', 'see'): 1,
#           ('seat', 'see', 'charact'): 1,
#           ('see', 'charact', 'evolv'): 1,
#           ('charact', 'evolv', 'know'): 1,
#           ('evolv', 'know', '1'): 1,
#           ('know', '1', 'villain'): 1,
#           ('1', 'villain', 'batman'): 1,
#           ('villain', 'batman', 'beyond'): 1,
#           ('batman', 'beyond', 'geniu'): 1,
#           ('beyond', 'geniu', 'joaquin'): 1,
#           ('geniu', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'true'): 1,
#           ('phoenix', 'true', 'master'): 1,
#           ('true', 'master', 'perfect'): 1,
#           ('master', 'perfect', 'art'): 1,
#           ('perfect', 'art', 'consum'): 1,
#           ('art', 'consum', 'charact'): 1,
#           ('consum', 'charact', 'may'): 1,
#           ('charact', 'may', 'place'): 1,
#           ('may', 'place', 'dont'): 1,
#           ('place', 'dont', 'care'): 1,
#           ('dont', 'care', 'movi'): 1,
#           ('care', 'movi', 'stori'): 1,
#           ('movi', 'stori', 'act'): 1,
#           ('stori', 'act', 'direct'): 1,
#           ('act', 'direct', 'effect'): 1,
#           ('direct', 'effect', 'everyon'): 1,
#           ('effect', 'everyon', 'brought'): 1,
#           ('everyon', 'brought', 'game'): 1,
#           ('brought', 'game', 'up'): 1,
#           ('game', 'up', 'definit'): 1,
#           ('up', 'definit', 'deserv'): 1,
#           ('definit', 'deserv', 'nod'): 1,
#           ('deserv', 'nod', 'win'): 1,
#           ('nod', 'win', 'role'): 1,
#           ('win', 'role', 'comparison'): 1,
#           ('role', 'comparison', 'jack'): 1,
#           ('comparison', 'jack', 'nicholson'): 1,
#           ('jack', 'nicholson', 'heath'): 3,
#           ('nicholson', 'heath', 'ledger'): 3,
#           ('heath', 'ledger', 'actor'): 1,
#           ('ledger', 'actor', 'took'): 1,
#           ('actor', 'took', 'charact'): 1,
#           ('took', 'charact', 'differ'): 1,
#           ('charact', 'differ', 'level'): 1,
#           ('differ', 'level', 'differ'): 1,
#           ('level', 'differ', 'stori'): 1,
#           ('differ', 'stori', 'point'): 1,
#           ('stori', 'point', 'differ'): 1,
#           ('point', 'differ', 'point'): 1,
#           ('differ', 'point', 'time'): 1,
#           ('point', 'time', 'comparison'): 1,
#           ('time', 'comparison', 'would'): 1,
#           ('comparison', 'would', 'feasibl'): 1,
#           ('would', 'feasibl', 'fair'): 1,
#           ('feasibl', 'fair', 'actor'): 1,
#           ('fair', 'actor', 'embrac'): 1,
#           ('actor', 'embrac', 'made'): 1,
#           ('embrac', 'made', 'come'): 1,
#           ('made', 'come', 'life'): 1,
#           ('come', 'life', 'geniu'): 1,
#           ('life', 'geniu', 'way'): 1,
#           ('geniu', 'way', 'thought'): 1,
#           ('way', 'thought', 'film'): 1,
#           ('thought', 'film', 'good'): 1,
#           ('film', 'good', 'dont'): 1,
#           ('good', 'dont', 'get'): 1,
#           ('dont', 'get', 'hope'): 1,
#           ('get', 'hope', 'person'): 1,
#           ('hope', 'person', 'act'): 1,
#           ('person', 'act', 'amaz'): 1,
#           ('act', 'amaz', 'film'): 1,
#           ('amaz', 'film', 'good'): 1,
#           ('film', 'good', 'overal'): 1,
#           ('good', 'overal', 'think'): 1,
#           ('overal', 'think', 'masterpiec'): 1,
#           ('think', 'masterpiec', 'film'): 1,
#           ('masterpiec', 'film', 'year'): 1,
#           ('film', 'year', 'bit'): 1,
#           ('year', 'bit', 'vers'): 1,
#           ('bit', 'vers', 'throughout'): 1,
#           ('vers', 'throughout', 'review'): 1,
#           ('throughout', 'review', 'way'): 1,
#           ('review', 'way', 'dislik'): 1,
#           ('way', 'dislik', 'film'): 1,
#           ('dislik', 'film', 'thought'): 1,
#           ('film', 'thought', 'realli'): 1,
#           ('thought', 'realli', 'good'): 1,
#           ('realli', 'good', 'overhyp'): 1,
#           ('good', 'overhyp', 'feel'): 1,
#           ('overhyp', 'feel', 'though'): 1,
#           ('feel', 'though', 'lot'): 1,
#           ('though', 'lot', '1010'): 1,
#           ('lot', '1010', 'review'): 1,
#           ('1010', 'review', 'pure'): 1,
#           ('review', 'pure', 'base'): 1,
#           ('pure', 'base', 'fact'): 1,
#           ('base', 'fact', 'alreadi'): 1,
#           ('fact', 'alreadi', 'amaz'): 1,
#           ('alreadi', 'amaz', 'review'): 1,
#           ('amaz', 'review', 'peopl'): 1,
#           ('review', 'peopl', 'want'): 1,
#           ('peopl', 'want', 'carri'): 1,
#           ('want', 'carri', 'prais'): 1,
#           ('carri', 'prais', 'joke'): 1,
#           ('prais', 'joke', 'film'): 1,
#           ('joke', 'film', 'releas'): 1,
#           ('film', 'releas', 'random'): 1,
#           ('releas', 'random', 'guy'): 1,
#           ('random', 'guy', 'situat'): 1,
#           ('guy', 'situat', 'dont'): 1,
#           ('situat', 'dont', 'think'): 1,
#           ('dont', 'think', 'review'): 1,
#           ('think', 'review', 'would'): 1,
#           ('review', 'would', 'high'): 1,
#           ('would', 'high', 'mayb'): 1,
#           ('high', 'mayb', 'that'): 1,
#           ('mayb', 'that', 'point'): 1,
#           ('that', 'point', 'realli'): 1,
#           ('point', 'realli', 'understand'): 1,
#           ('realli', 'understand', 'ten'): 1,
#           ('understand', 'ten', 'sure'): 1,
#           ('ten', 'sure', 'good'): 1,
#           ('sure', 'good', 'movi'): 1,
#           ('good', 'movi', 'good'): 1,
#           ('movi', 'good', 'act'): 1,
#           ('good', 'act', 'nice'): 1,
#           ('act', 'nice', 'shoot'): 1,
#           ('nice', 'shoot', 'plot'): 1,
#           ('shoot', 'plot', 'intrigu'): 1,
#           ('plot', 'intrigu', 'time'): 1,
#           ('intrigu', 'time', 'realli'): 1,
#           ('time', 'realli', 'long'): 1,
#           ('realli', 'long', 'somewhat'): 1,
#           ('long', 'somewhat', 'bore'): 1,
#           ('somewhat', 'bore', 'need'): 1,
#           ('bore', 'need', 'doublecheck'): 1,
#           ('need', 'doublecheck', 'gene'): 1,
#           ('doublecheck', 'gene', 'see'): 1,
#           ('gene', 'see', 'drama'): 1,
#           ('see', 'drama', 'crime'): 1,
#           ('drama', 'crime', 'drama'): 1,
#           ('crime', 'drama', 'thrill'): 1,
#           ('drama', 'thrill', 'said'): 1,
#           ('thrill', 'said', 'would'): 1,
#           ('said', 'would', 'put'): 1,
#           ('would', 'put', 'mayb'): 1,
#           ('put', 'mayb', '90'): 1,
#           ('mayb', '90', 'drama'): 1,
#           ('90', 'drama', 'rest'): 1,
#           ('drama', 'rest', 'thrill'): 1,
#           ('rest', 'thrill', 'miss'): 1,
#           ('thrill', 'miss', 'dialogu'): 1,
#           ('miss', 'dialogu', 'depth'): 1,
#           ('dialogu', 'depth', 'substanc'): 1,
#           ('depth', 'substanc', 'plot'): 1,
#           ('substanc', 'plot', 'realli'): 1,
#           ('plot', 'realli', 'somewhat'): 1,
#           ('realli', 'somewhat', 'crazi'): 1,
#           ('somewhat', 'crazi', 'person'): 1,
#           ('crazi', 'person', 'becom'): 1,
#           ('person', 'becom', 'bit'): 1,
#           ('becom', 'bit', 'brazier'): 1,
#           ('bit', 'brazier', 'sure'): 1,
#           ('brazier', 'sure', 'underton'): 1,
#           ('sure', 'underton', 'societi'): 1,
#           ('underton', 'societi', 'system'): 1,
#           ('societi', 'system', 'mean'): 1,
#           ('system', 'mean', 'charact'): 1,
#           ('mean', 'charact', 'peopl'): 1,
#           ('charact', 'peopl', 'bring'): 1,
#           ('peopl', 'bring', 'creat'): 1,
#           ('bring', 'creat', 'evil'): 1,
#           ('creat', 'evil', 'beast'): 1,
#           ('evil', 'beast', 'later'): 1,
#           ('beast', 'later', 'want'): 1,
#           ('later', 'want', 'destroy'): 1,
#           ('want', 'destroy', 'everyth'): 1,
#           ('destroy', 'everyth', 'absolut'): 1,
#           ('everyth', 'absolut', 'think'): 1,
#           ('absolut', 'think', 'intrigu'): 1,
#           ('think', 'intrigu', 'stori'): 1,
#           ('intrigu', 'stori', 'plot'): 1,
#           ('stori', 'plot', 'dialogu'): 1,
#           ('plot', 'dialogu', 'enough'): 1,
#           ('dialogu', 'enough', 'give'): 1,
#           ('enough', 'give', 'ten'): 1,
#           ('give', 'ten', 'worthi'): 1,
#           ('ten', 'worthi', 'watch'): 1,
#           ('worthi', 'watch', 'ye'): 1,
#           ('watch', 'ye', 'amaz'): 1,
#           ('ye', 'amaz', 'went'): 1,
#           ('amaz', 'went', 'film'): 1,
#           ('went', 'film', 'expect'): 1,
#           ('film', 'expect', 'allie'): 1,
#           ('expect', 'allie', 'classic'): 1,
#           ('allie', 'classic', 'base'): 1,
#           ('classic', 'base', 'review'): 1,
#           ('base', 'review', 'read'): 1,
#           ('review', 'read', 'end'): 1,
#           ('read', 'end', 'watch'): 1,
#           ('end', 'watch', 'decent'): 1,
#           ('watch', 'decent', 'film'): 1,
#           ('decent', 'film', 'overal'): 1,
#           ('film', 'overal', 'phoenix'): 1,
#           ('overal', 'phoenix', 'outstand'): 1,
#           ('phoenix', 'outstand', 'definit'): 1,
#           ('outstand', 'definit', 'part'): 1,
#           ('definit', 'part', 'feel'): 1,
#           ('part', 'feel', 'like'): 1,
#           ('feel', 'like', 'you'): 1,
#           ('like', 'you', 'seen'): 1,
#           ('you', 'seen', 'trailer'): 1,
#           ('seen', 'trailer', 'you'): 1,
#           ('trailer', 'you', 'seen'): 1,
#           ('you', 'seen', 'movi'): 1,
#           ('seen', 'movi', 'best'): 1,
#           ('movi', 'best', 'way'): 1,
#           ('best', 'way', 'describ'): 1,
#           ('way', 'describ', 'film'): 1,
#           ('describ', 'film', 'feel'): 1,
#           ('film', 'feel', 'like'): 1,
#           ('feel', 'like', '2'): 1,
#           ('like', '2', 'hour'): 1,
#           ('2', 'hour', 'version'): 1,
#           ('hour', 'version', 'trailer'): 1,
#           ('version', 'trailer', '2'): 1,
#           ('trailer', '2', 'hour'): 1,
#           ('2', 'hour', 'rel'): 1,
#           ('hour', 'rel', 'common'): 1,
#           ('rel', 'common', 'aunti'): 1,
#           ('common', 'aunti', 'felt'): 1,
#           ('aunti', 'felt', 'lot'): 1,
#           ('felt', 'lot', 'longerwhich'): 1,
#           ...})

# %% [markdown]
# 1.2 - Probability of Bi grams

# %%
from collections import Counter
bi_grams = nltk.bigrams(iterations)
frequency_dist = nltk.FreqDist(bi_grams)
bi_grams_dict = dict(frequency_dist)
for word in bi_grams_dict:
  print( str(word) + ':' + str(bi_grams_dict[word] / iterations.count(word[0])))
# Out:
# Streaming output truncated to the last 5000 lines.
# ('anticip', 'like'):1.0
# ('like', 'end'):0.017857142857142856
# ('end', 'fall'):0.09090909090909091
# ('fall', 'short'):0.2
# ('short', 'way'):0.2
# ('way', 'short'):0.03571428571428571
# ('short', 'joke'):0.2
# ('joke', 'first'):0.008
# ('first', 'time'):0.2727272727272727
# ('time', 'happi'):0.06060606060606061
# ('happi', 'hope'):0.25
# ('hope', 'plea'):0.0625
# ('plea', 'ignor'):0.25
# ('ignor', 'complaint'):0.25
# ('complaint', 'pernici'):1.0
# ('pernici', 'violenc'):1.0
# ('violenc', 'embarrass'):0.14285714285714285
# ('embarrass', 'say'):1.0
# ('say', 'least'):0.034482758620689655
# ('least', 'haven'):0.2
# ('haven', 'seen'):1.0
# ('seen', 'comic'):0.043478260869565216
# ('comic', 'movi'):0.14285714285714285
# ('movi', 'real'):0.004975124378109453
# ('real', 'ever'):0.07142857142857142
# ('ever', 'deserv'):0.07692307692307693
# ('deserv', 'better'):0.1
# ('better', 'class'):0.045454545454545456
# ('class', 'crimin'):0.2
# ('crimin', 'phillip'):0.3333333333333333
# ('phillip', 'phoenix'):0.125
# ('phoenix', 'deliv'):0.0392156862745098
# ('deliv', 'dark'):0.5
# ('dark', 'joke'):0.041666666666666664
# ('joke', 'dark'):0.008
# ('dark', 'fall'):0.041666666666666664
# ('fall', 'love'):0.2
# ('love', 'villain'):0.125
# ('villain', 'bad'):0.07692307692307693
# ('bad', 'gun'):0.0625
# ('gun', 'alway'):0.5
# ('alway', 'romant'):0.3333333333333333
# ('romant', 'anyway'):1.0
# ('anyway', 'let'):0.5
# ('let', 'start'):0.16666666666666666
# ('start', 'say'):0.125
# ('say', 'joaquin'):0.034482758620689655
# ('phoenix', 'doesn'):0.0392156862745098
# ('doesn', 'get'):0.1
# ('get', 'oscar'):0.034482758620689655
# ('oscar', 'movi'):0.047619047619047616
# ('movi', 'scar'):0.004975124378109453
# ('scar', 'cancel'):0.16666666666666666
# ('cancel', 'phoenix'):1.0
# ('phoenix', 'amaz'):0.0392156862745098
# ('amaz', 'might'):0.08333333333333333
# ('might', 'heard'):0.16666666666666666
# ('heard', 'everi'):0.5
# ('everi', 'review'):0.14285714285714285
# ('review', 'ever'):0.04
# ('ever', 'told'):0.07692307692307693
# ('told', 'phillip'):0.5833333333333334
# ('phillip', 'best'):0.125
# ('best', 'stori'):0.038461538461538464
# ('stori', 'line'):0.034482758620689655
# ('line', 'take'):0.3333333333333333
# ('take', 'visual'):0.05
# ('visual', 'breathtak'):0.5
# ('breathtak', 'score'):0.5
# ('score', 'org'):0.07692307692307693
# ('org', 'score'):1.0
# ('score', 'everi'):0.07692307692307693
# ('everi', 'time'):0.14285714285714285
# ('time', 'score'):0.030303030303030304
# ('score', 'came'):0.07692307692307693
# ('came', 'felt'):0.2
# ('felt', 'uncomfort'):0.08333333333333333
# ('uncomfort', 'like'):0.25
# ('like', 'someth'):0.017857142857142856
# ('someth', 'horribl'):0.1
# ('horribl', 'happen'):0.5
# ('happen', 'great'):0.0625
# ('great', 'inspir'):0.04
# ('inspir', 'taxi'):0.25
# ('taxi', 'driver'):0.9230769230769231
# ('driver', 'king'):0.16666666666666666
# ('king', 'comedi'):1.0
# ('comedi', 'add'):0.2
# ('add', 'much'):1.0
# ('much', 'movi'):0.125
# ('movi', 'got'):0.009950248756218905
# ('got', 'honest'):0.14285714285714285
# ('honest', 'scene'):1.0
# ('scene', 'violent'):0.09090909090909091
# ('violent', 'disturb'):0.14285714285714285
# ('disturb', 'honestli'):0.1
# ('honestli', 'expect'):1.0
# ('expect', 'wayyyi'):0.06666666666666667
# ('wayyyi', 'violent'):1.0
# ('violent', 'controversi'):0.14285714285714285
# ('controversi', 'go'):0.3333333333333333
# ('go', 'overal'):0.0625
# ('overal', 'movi'):0.16666666666666666
# ('movi', 'great'):0.009950248756218905
# ('great', 'come'):0.04
# ('come', 'oscar'):0.1
# ('oscar', 'season'):0.047619047619047616
# ('season', 'need'):1.0
# ('need', 'nomin'):0.05555555555555555
# ('nomin', 'best'):0.2
# ('best', 'pictur'):0.038461538461538464
# ('pictur', 'screenplay'):1.0
# ('screenplay', 'cinematographi'):0.2
# ('cinematographi', 'actor'):0.08333333333333333
# ('actor', 'score'):0.07692307692307693
# ('score', 'director'):0.07692307692307693
# ('director', 'get'):0.16666666666666666
# ('get', 'peopl'):0.034482758620689655
# ('peopl', 'hate'):0.023809523809523808
# ('hate', 'polit'):0.14285714285714285
# ('polit', 'messag'):1.0
# ('messag', 'peopl'):0.16666666666666666
# ('peopl', 'think'):0.047619047619047616
# ('think', 'need'):0.041666666666666664
# ('need', 'get'):0.16666666666666666
# ('get', 'empti'):0.034482758620689655
# ('empti', 'arthur'):0.25
# ('arthur', 'mad'):0.05555555555555555
# ('mad', 'come'):0.2
# ('come', 'point'):0.1
# ('point', 'never'):0.0625
# ('never', 'enjoy'):0.1111111111111111
# ('enjoy', 'masterpiec'):0.2
# ('masterpiec', 'joaquin'):0.11764705882352941
# ('phoenix', 'told'):0.0196078431372549
# ('phillip', 'overdid'):0.125
# ('overdid', 'movi'):1.0
# ('movi', 'actingmus'):0.004975124378109453
# ('actingmus', 'cinematographi'):1.0
# ('cinematographi', 'amaz'):0.08333333333333333
# ('amaz', 'plea'):0.08333333333333333
# ('plea', 'enjoy'):0.25
# ('enjoy', 'movi'):0.4
# ('movi', 'without'):0.004975124378109453
# ('without', 'overthink'):0.1
# ('overthink', 'seen'):1.0
# ('seen', 'joke'):0.043478260869565216
# ('joke', 'yesterday'):0.008
# ('yesterday', 'venic'):0.5
# ('venic', 'earli'):0.5
# ('earli', 'inflat'):0.5
# ('inflat', 'screen'):1.0
# ('screen', 'troubl'):0.5
# ('troubl', 'audit'):0.25
# ('audit', 'lead'):1.0
# ('lead', 'nearhour'):0.3333333333333333
# ('nearhour', 'delay'):1.0
# ('delay', 'definit'):1.0
# ('definit', 'worth'):0.07692307692307693
# ('worth', 'joke'):0.2
# ('joke', 'deserv'):0.016
# ('deserv', 'present'):0.1
# ('present', 'venic'):0.2
# ('venic', 'film'):0.5
# ('film', 'festiv'):0.014492753623188406
# ('festiv', 'event'):1.0
# ('event', 'regard'):0.5
# ('regard', 'cinema'):0.5
# ('cinema', 'form'):0.16666666666666666
# ('form', 'art'):0.5
# ('art', 'film'):0.14285714285714285
# ('film', 'far'):0.028985507246376812
# ('far', 'blockbust'):0.07142857142857142
# ('blockbust', 'mere'):0.5
# ('mere', 'entertain'):0.5
# ('entertain', 'movi'):0.2
# ('movi', 'film'):0.004975124378109453
# ('film', 'gene'):0.014492753623188406
# ('gene', 'focus'):0.16666666666666666
# ('focus', 'psychic'):0.3333333333333333
# ('psychic', 'main'):0.25
# ('main', 'charact'):0.2
# ('charact', 'slowli'):0.018867924528301886
# ('slowli', 'crumbl'):0.3333333333333333
# ('crumbl', 'pressur'):1.0
# ('pressur', 'societi'):1.0
# ('societi', 'thu'):0.06666666666666667
# ('thu', 'joaquin'):1.0
# ('phoenix', 'wonder'):0.0196078431372549
# ('wonder', 'perform'):0.3333333333333333
# ('perform', 'earn'):0.02857142857142857
# ('earn', 'almost'):0.3333333333333333
# ('almost', 'sure'):0.125
# ('sure', 'nomin'):0.14285714285714285
# ('nomin', 'scar'):0.2
# ('scar', 'least'):0.16666666666666666
# ('least', 'take'):0.2
# ('take', 'joke'):0.1
# ('joke', 'differ'):0.008
# ('differ', 'ledger'):0.06666666666666667
# ('ledger', 'id'):0.05555555555555555
# ('id', 'say'):0.5
# ('say', 'equal'):0.034482758620689655
# ('equal', 'good'):0.3333333333333333
# ('good', 'main'):0.022222222222222223
# ('main', 'differ'):0.2
# ('differ', 'might'):0.06666666666666667
# ('might', 'ledger'):0.16666666666666666
# ('ledger', 'joke'):0.16666666666666666
# ('joke', 'ration'):0.008
# ('ration', 'act'):1.0
# ('act', 'insan'):0.030303030303030304
# ('insan', 'phoenix'):0.16666666666666666
# ('phoenix', 'insan'):0.0196078431372549
# ('insan', 'root'):0.16666666666666666
# ('root', 'despit'):0.25
# ('despit', 'movi'):0.3333333333333333
# ('movi', 'superhero'):0.004975124378109453
# ('superhero', 'villain'):0.09090909090909091
# ('villain', 'joke'):0.15384615384615385
# ('joke', 'much'):0.008
# ('much', 'superior'):0.041666666666666664
# ('superior', 'move'):1.0
# ('move', 'gene'):0.029411764705882353
# ('gene', 'id'):0.16666666666666666
# ('id', 'exclud'):0.25
# ('exclud', 'dark'):1.0
# ('knight', 'trilog'):0.1111111111111111
# ('trilog', 'joke'):1.0
# ('joke', 'easili'):0.008
# ('easili', 'good'):0.25
# ('good', 'plan'):0.022222222222222223
# ('plan', 'move'):0.3333333333333333
# ('move', 'least'):0.029411764705882353
# ('least', 'close'):0.2
# ('close', 'smallscal'):0.16666666666666666
# ('smallscal', 'film'):1.0
# ('film', 'distinct'):0.014492753623188406
# ('distinct', 'style'):1.0
# ('style', 'cinematographi'):0.3333333333333333
# ('cinematographi', 'can'):0.08333333333333333
# ('can', 'not'):0.42857142857142855
# ('not', 'appreci'):0.3333333333333333
# ('appreci', 'set'):0.25
# ('set', 'cinephil'):0.2
# ('cinephil', 'refer'):1.0
# ('refer', 'howev'):0.2
# ('howev', 'feel'):0.5
# ('feel', 'forc'):0.029411764705882353
# ('forc', 'overlay'):0.2
# ('overlay', 'oppress'):0.3333333333333333
# ('oppress', 'notabl'):1.0
# ('notabl', 'similar'):0.5
# ('similar', 'scorses'):0.3333333333333333
# ('scorses', 'taxi'):1.0
# ('comedi', 'also'):0.2
# ('also', 'chain'):0.07142857142857142
# ('chain', 'modern'):1.0
# ('modern', 'time'):0.5
# ('time', 'somewhat'):0.030303030303030304
# ('somewhat', 'refer'):0.25
# ('refer', 'eager'):0.2
# ('eager', 'see'):1.0
# ('see', 'noncomed'):0.04
# ('noncomed', 'effort'):1.0
# ('effort', 'told'):0.5
# ('phillip', 'movi'):0.125
# ('movi', 'far'):0.014925373134328358
# ('far', 'probabl'):0.07142857142857142
# ('probabl', 'best'):1.0
# ('best', '2019'):0.038461538461538464
# ('2019', 'worst'):0.5
# ('worst', 'contest'):0.5
# ('contest', 'far'):1.0
# ('far', 'door'):0.07142857142857142
# ('door', 'gloria'):0.5
# ('gloria', 'upon'):1.0
# ('upon', 'time'):1.0
# ('time', 'hollywood'):0.06060606060606061
# ('hollywood', 'convinc'):0.2
# ('convinc', 'sad'):0.25
# ('sad', 'joaquin'):0.3333333333333333
# ('joaquin', 'miss'):0.022727272727272728
# ('miss', 'oscar'):0.3333333333333333
# ('oscar', 'gladiat'):0.047619047619047616
# ('gladiat', 'compel'):1.0
# ('compel', 'villain'):0.3333333333333333
# ('villain', 'quit'):0.07692307692307693
# ('quit', 'confid'):0.09090909090909091
# ('confid', 'win'):0.3333333333333333
# ('win', 'joke'):0.125
# ('joke', 'damn'):0.008
# ('damn', 'movi'):0.5
# ('movi', 'keep'):0.004975124378109453
# ('keep', 'u'):0.14285714285714285
# ('u', 'toe'):0.125
# ('toe', 'time'):1.0
# ('time', 'predict'):0.030303030303030304
# ('predict', 'storylin'):0.25
# ('storylin', 'realli'):0.3333333333333333
# ('realli', 'deep'):0.041666666666666664
# ('deep', 'interest'):0.2
# ('interest', 'plot'):0.16666666666666666
# ('plot', 'forget'):0.05555555555555555
# ('forget', 'mention'):0.25
# ('mention', 'act'):1.0
# ('act', 'damn'):0.030303030303030304
# ('damn', 'no'):0.5
# ('no', 'joaquin'):0.2
# ('joaquin', 'teach'):0.022727272727272728
# ('teach', 'u'):1.0
# ('u', 'realli'):0.125
# ('realli', '5'):0.041666666666666664
# ('5', 'star'):0.25
# ('star', 'act'):0.25
# ('act', 'enjoy'):0.030303030303030304
# ('movi', 'get'):0.009950248756218905
# ('get', 'wine'):0.034482758620689655
# ('wine', 'hand'):1.0
# ('hand', 'close'):0.14285714285714285
# ('close', 'curtain'):0.16666666666666666
# ('curtain', 'turn'):1.0
# ('turn', 'or'):0.25
# ('or', 'cellphon'):0.5
# ('cellphon', 'put'):1.0
# ('put', 'disturb'):0.08333333333333333
# ('disturb', 'sign'):0.1
# ('sign', 'or'):0.3333333333333333
# ('or', 'door'):0.5
# ('door', 'best'):0.5
# ('best', 'dark'):0.038461538461538464
# ('dark', 'thrill'):0.041666666666666664
# ('thrill', 'suspens'):0.25
# ('suspens', 'movi'):0.5
# ('get', 'experi'):0.034482758620689655
# ('experi', 'movi'):0.25
# ('movi', 'caus'):0.004975124378109453
# ('caus', 'audienc'):0.2
# ('audienc', 'consid'):0.2
# ('consid', 'mani'):0.125
# ('mani', 'topic'):0.03571428571428571
# ('topic', 'moral'):0.5
# ('moral', 'particularli'):1.0
# ('particularli', 'poor'):1.0
# ('poor', 'choic'):0.16666666666666666
# ('choic', 'made'):0.5
# ('made', 'joke'):0.1
# ('joke', 'joke'):0.016
# ('joke', 'reliabl'):0.008
# ('reliabl', 'movi'):1.0
# ('movi', 'antagonist'):0.004975124378109453
# ('antagonist', 'usual'):1.0
# ('usual', 'think'):0.25
# ('think', 'give'):0.041666666666666664
# ('give', 'realist'):0.07142857142857142
# ('realist', 'view'):0.14285714285714285
# ('view', 'bad'):0.5
# ('bad', 'peopl'):0.0625
# ('peopl', 'usual'):0.023809523809523808
# ('usual', '100'):0.25
# ('100', 'bad'):0.5
# ('bad', 'way'):0.0625
# ('way', 'societi'):0.03571428571428571
# ('societi', 'often'):0.06666666666666667
# ('often', 'judg'):0.5
# ('judg', 'import'):1.0
# ('import', 'know'):0.16666666666666666
# ('know', 'sympath'):0.05263157894736842
# ('sympath', 'joke'):0.5
# ('joke', 'toward'):0.008
# ('toward', 'begin'):0.5
# ('begin', 'movi'):0.125
# ('movi', 'need'):0.004975124378109453
# ('need', 'identifi'):0.05555555555555555
# ('identifi', 'threat'):1.0
# ('threat', 'begin'):1.0
# ('begin', 'make'):0.125
# ('make', 'certain'):0.034482758620689655
# ('certain', 'bad'):1.0
# ('bad', 'choic'):0.0625
# ('choic', 'movi'):0.25
# ('movi', 'suitabl'):0.004975124378109453
# ('suitabl', 'adult'):0.3333333333333333
# ('adult', 'will'):0.5
# ('will', 'pick'):1.0
# ('pick', 'apart'):1.0
# ('apart', 'think'):1.0
# ('think', 'clinic'):0.041666666666666664
# ('clinic', 'isn'):1.0
# ('isn', 'light'):0.125
# ('light', 'amus'):0.25
# ('amus', 'substanc'):1.0
# ('substanc', 'make'):0.3333333333333333
# ('make', 'good'):0.034482758620689655
# ('good', 'agent'):0.022222222222222223
# ('agent', 'abl'):1.0
# ('abl', 'ponder'):0.25
# ('ponder', 'underli'):1.0
# ('underli', 'theme'):1.0
# ('theme', 'hand'):0.16666666666666666
# ('hand', 'thought'):0.14285714285714285
# ('thought', 'isn'):0.09090909090909091
# ('isn', 'best'):0.125
# ('best', 'movi'):0.07692307692307693
# ('movi', 'movi'):0.01990049751243781
# ('movi', 'affect'):0.004975124378109453
# ('affect', 'way'):1.0
# ('way', 'make'):0.03571428571428571
# ('make', 'physic'):0.034482758620689655
# ('physic', 'pain'):0.25
# ('pain', 'experi'):0.2
# ('experi', 'good'):0.25
# ('good', 'way'):0.022222222222222223
# ('way', 'act'):0.03571428571428571
# ('act', 'cinematographi'):0.030303030303030304
# ('cinematographi', 'sound'):0.08333333333333333
# ('sound', 'design'):0.3333333333333333
# ('design', 'script'):0.3333333333333333
# ('script', 'phenomenon'):0.3333333333333333
# ('phenomenon', 'movi'):0.3333333333333333
# ('movi', 'triumph'):0.004975124378109453
# ('triumph', 'joaquin'):1.0
# ('phoenix', 'deserv'):0.0392156862745098
# ('deserv', 'oscar'):0.3
# ('oscar', 'win'):0.14285714285714285
# ('win', 'th'):0.125
# ('th', 'need'):1.0
# ('need', 'say'):0.05555555555555555
# ('say', 'everyth'):0.034482758620689655
# ('everyth', 'movi'):0.2
# ('movi', 'wast'):0.004975124378109453
# ('wast', 'everi'):0.2
# ('everi', 'singl'):0.2857142857142857
# ('singl', 'way'):0.25
# ('way', 'joke'):0.03571428571428571
# ('joke', 'isn'):0.008
# ('isn', 'awesom'):0.125
# ('awesom', 'comic'):0.5
# ('book', 'movi'):0.25
# ('movi', 'awesom'):0.004975124378109453
# ('awesom', 'movi'):0.5
# ('movi', 'period'):0.004975124378109453
# ('period', 'offer'):1.0
# ('offer', 'easi'):0.3333333333333333
# ('easi', 'answer'):0.3333333333333333
# ('answer', 'settl'):0.3333333333333333
# ('settl', 'question'):1.0
# ('question', 'rais'):1.0
# ('rais', 'cruel'):1.0
# ('cruel', 'societi'):0.5
# ('societi', 'declin'):0.06666666666666667
# ('declin', 'joaquin'):0.5
# ('phoenix', 'fulli'):0.0196078431372549
# ('fulli', 'commit'):1.0
# ('commit', 'perform'):0.5
# ('perform', 'told'):0.02857142857142857
# ('phillip', 'wast'):0.125
# ('wast', 'albeit'):0.2
# ('albeit', 'loo'):0.5
# ('loo', 'invent'):0.5
# ('invent', 'do'):1.0
# ('do', 'sourc'):0.0625
# ('sourc', 'materi'):1.0
# ('materi', 'make'):0.5
# ('make', 'joke'):0.034482758620689655
# ('joke', 'film'):0.024
# ('film', 'leav'):0.014492753623188406
# ('leav', 'comic'):0.16666666666666666
# ('book', 'fan'):0.125
# ('fan', 'nonfan'):0.5
# ('nonfan', 'alik'):1.0
# ('alik', 'disturb'):1.0
# ('disturb', 'move'):0.1
# ('move', 'right'):0.029411764705882353
# ('right', 'way'):0.14285714285714285
# ('way', 'stop'):0.03571428571428571
# ('stop', 'watch'):0.5
# ('watch', 'move'):0.05263157894736842
# ('move', 'joaquin'):0.029411764705882353
# ('phoenix', 'award'):0.0196078431372549
# ('award', 'oscar'):0.3333333333333333
# ('oscar', 'tremend'):0.047619047619047616
# ('tremend', 'act'):1.0
# ('act', 'quit'):0.030303030303030304
# ('quit', 'reli'):0.09090909090909091
# ('reli', 'critic'):1.0
# ('critic', 'review'):0.14285714285714285
# ('review', 'year'):0.08
# ('year', 'ago'):0.09090909090909091
# ('ago', 'notic'):1.0
# ('notic', 'movi'):0.5
# ('movi', 'critic'):0.004975124378109453
# ('critic', 'rate'):0.14285714285714285
# ('rate', 'low'):0.125
# ('low', 'viewer'):0.3333333333333333
# ('viewer', 'rate'):0.5
# ('rate', 'high'):0.125
# ('high', 'said'):0.09090909090909091
# ('said', 'point'):0.25
# ('point', 'critic'):0.0625
# ('critic', 'movi'):0.14285714285714285
# ('movi', 'oh'):0.004975124378109453
# ('oh', 'wrong'):1.0
# ('wrong', 'went'):0.2
# ('went', 'saw'):0.07692307692307693
# ('saw', 'tone'):0.25
# ('tone', 'mon'):1.0
# ('mon', 'went'):1.0
# ('went', 'skeptic'):0.07692307692307693
# ('skeptic', 'w'):1.0
# ('w', 'low'):1.0
# ('low', 'expect'):0.3333333333333333
# ('expect', 'knew'):0.06666666666666667
# ('knew', 'expect'):0.5
# ('expect', 'typic'):0.13333333333333333
# ('typic', 'super'):0.25
# ('super', 'hero'):0.3333333333333333
# ('hero', 'movi'):0.25
# ('got', 'masterpiec'):0.14285714285714285
# ('masterpiec', 'went'):0.058823529411764705
# ('went', 'expect'):0.07692307692307693
# ('expect', 'sheer'):0.06666666666666667
# ('sheer', 'boredom'):1.0
# ('boredom', 'instead'):1.0
# ('instead', 'edg'):0.16666666666666666
# ('edg', 'seat'):0.6
# ('seat', 'whole'):0.25
# ('whole', 'time'):0.1111111111111111
# ('time', 'action'):0.030303030303030304
# ('action', 'edg'):0.06666666666666667
# ('seat', 'fear'):0.25
# ('fear', 'may'):1.0
# ('may', 'say'):0.1111111111111111
# ('say', 'next'):0.034482758620689655
# ('next', 'edg'):1.0
# ('seat', 'see'):0.25
# ('see', 'charact'):0.04
# ('charact', 'evolv'):0.018867924528301886
# ('evolv', 'know'):0.5
# ('know', '1'):0.05263157894736842
# ('1', 'villain'):0.5
# ('villain', 'batman'):0.07692307692307693
# ('batman', 'beyond'):0.07692307692307693
# ('beyond', 'geniu'):0.3333333333333333
# ('geniu', 'joaquin'):0.5
# ('phoenix', 'true'):0.0196078431372549
# ('true', 'master'):0.16666666666666666
# ('master', 'perfect'):0.3333333333333333
# ('perfect', 'art'):0.09090909090909091
# ('art', 'consum'):0.14285714285714285
# ('consum', 'charact'):1.0
# ('charact', 'may'):0.018867924528301886
# ('may', 'place'):0.1111111111111111
# ('place', 'dont'):0.5
# ('dont', 'care'):0.037037037037037035
# ('care', 'movi'):0.25
# ('movi', 'stori'):0.004975124378109453
# ('stori', 'act'):0.06896551724137931
# ('act', 'direct'):0.06060606060606061
# ('direct', 'effect'):0.08333333333333333
# ('effect', 'everyon'):0.5
# ('everyon', 'brought'):0.1111111111111111
# ('brought', 'game'):0.5
# ('game', 'up'):0.5
# ('up', 'definit'):1.0
# ('definit', 'deserv'):0.07692307692307693
# ('deserv', 'nod'):0.1
# ('nod', 'win'):0.3333333333333333
# ('win', 'role'):0.125
# ('role', 'comparison'):0.2
# ('comparison', 'jack'):0.25
# ('jack', 'nicholson'):0.75
# ('nicholson', 'heath'):1.0
# ('ledger', 'actor'):0.05555555555555555
# ('actor', 'took'):0.07692307692307693
# ('took', 'charact'):0.3333333333333333
# ('charact', 'differ'):0.018867924528301886
# ('differ', 'level'):0.06666666666666667
# ('level', 'differ'):0.5
# ('differ', 'stori'):0.06666666666666667
# ('stori', 'point'):0.034482758620689655
# ('point', 'differ'):0.0625
# ('differ', 'point'):0.06666666666666667
# ('point', 'time'):0.0625
# ('time', 'comparison'):0.030303030303030304
# ('comparison', 'would'):0.25
# ('would', 'feasibl'):0.038461538461538464
# ('feasibl', 'fair'):1.0
# ('fair', 'actor'):1.0
# ('actor', 'embrac'):0.07692307692307693
# ('embrac', 'made'):1.0
# ('made', 'come'):0.05
# ('come', 'life'):0.1
# ('life', 'geniu'):0.08333333333333333
# ('geniu', 'way'):0.5
# ('way', 'thought'):0.03571428571428571
# ('thought', 'film'):0.09090909090909091
# ('film', 'good'):0.028985507246376812
# ('good', 'dont'):0.022222222222222223
# ('dont', 'get'):0.1111111111111111
# ('get', 'hope'):0.034482758620689655
# ('hope', 'person'):0.0625
# ('person', 'act'):0.0625
# ('act', 'amaz'):0.030303030303030304
# ('amaz', 'film'):0.08333333333333333
# ('good', 'overal'):0.022222222222222223
# ('overal', 'think'):0.16666666666666666
# ('think', 'masterpiec'):0.041666666666666664
# ('masterpiec', 'film'):0.058823529411764705
# ('film', 'year'):0.057971014492753624
# ('year', 'bit'):0.09090909090909091
# ('bit', 'vers'):0.16666666666666666
# ('vers', 'throughout'):1.0
# ('throughout', 'review'):0.14285714285714285
# ('review', 'way'):0.04
# ('way', 'dislik'):0.03571428571428571
# ('dislik', 'film'):1.0
# ('film', 'thought'):0.014492753623188406
# ('thought', 'realli'):0.09090909090909091
# ('realli', 'good'):0.125
# ('good', 'overhyp'):0.022222222222222223
# ('overhyp', 'feel'):0.2
# ('feel', 'though'):0.029411764705882353
# ('though', 'lot'):0.1
# ('lot', '1010'):0.09090909090909091
# ('1010', 'review'):0.16666666666666666
# ('review', 'pure'):0.04
# ('pure', 'base'):0.5
# ('base', 'fact'):0.25
# ('fact', 'alreadi'):0.25
# ('alreadi', 'amaz'):0.5
# ('amaz', 'review'):0.08333333333333333
# ('review', 'peopl'):0.04
# ('peopl', 'want'):0.023809523809523808
# ('want', 'carri'):0.05
# ('carri', 'prais'):1.0
# ('prais', 'joke'):0.5
# ('film', 'releas'):0.014492753623188406
# ('releas', 'random'):1.0
# ('random', 'guy'):0.5
# ('guy', 'situat'):0.16666666666666666
# ('situat', 'dont'):0.3333333333333333
# ('dont', 'think'):0.037037037037037035
# ('think', 'review'):0.041666666666666664
# ('review', 'would'):0.04
# ('would', 'high'):0.038461538461538464
# ('high', 'mayb'):0.09090909090909091
# ('mayb', 'that'):0.16666666666666666
# ('that', 'point'):0.1
# ('point', 'realli'):0.0625
# ('realli', 'understand'):0.041666666666666664
# ('understand', 'ten'):0.08333333333333333
# ('ten', 'sure'):0.5
# ('sure', 'good'):0.14285714285714285
# ('good', 'movi'):0.1111111111111111
# ('movi', 'good'):0.009950248756218905
# ('good', 'act'):0.044444444444444446
# ('act', 'nice'):0.030303030303030304
# ('nice', 'shoot'):0.3333333333333333
# ('shoot', 'plot'):0.3333333333333333
# ('plot', 'intrigu'):0.05555555555555555
# ('intrigu', 'time'):0.5
# ('time', 'realli'):0.030303030303030304
# ('realli', 'long'):0.041666666666666664
# ('long', 'somewhat'):0.14285714285714285
# ('somewhat', 'bore'):0.25
# ('bore', 'need'):0.058823529411764705
# ('need', 'doublecheck'):0.05555555555555555
# ('doublecheck', 'gene'):1.0
# ('gene', 'see'):0.16666666666666666
# ('see', 'drama'):0.04
# ('drama', 'crime'):0.16666666666666666
# ('crime', 'drama'):0.14285714285714285
# ('drama', 'thrill'):0.16666666666666666
# ('thrill', 'said'):0.25
# ('said', 'would'):0.25
# ('would', 'put'):0.038461538461538464
# ('put', 'mayb'):0.08333333333333333
# ('mayb', '90'):0.16666666666666666
# ('90', 'drama'):0.5
# ('drama', 'rest'):0.16666666666666666
# ('rest', 'thrill'):0.5
# ('thrill', 'miss'):0.25
# ('miss', 'dialogu'):0.3333333333333333
# ('dialogu', 'depth'):0.25
# ('depth', 'substanc'):0.25
# ('substanc', 'plot'):0.3333333333333333
# ('plot', 'realli'):0.05555555555555555
# ('realli', 'somewhat'):0.041666666666666664
# ('somewhat', 'crazi'):0.25
# ('crazi', 'person'):0.14285714285714285
# ('person', 'becom'):0.0625
# ('becom', 'bit'):0.1111111111111111
# ('bit', 'brazier'):0.16666666666666666
# ('brazier', 'sure'):1.0
# ('sure', 'underton'):0.14285714285714285
# ('underton', 'societi'):1.0
# ('societi', 'system'):0.06666666666666667
# ('system', 'mean'):0.5
# ('mean', 'charact'):0.1111111111111111
# ('charact', 'peopl'):0.018867924528301886
# ('peopl', 'bring'):0.023809523809523808
# ('bring', 'creat'):0.16666666666666666
# ('creat', 'evil'):0.2
# ('evil', 'beast'):0.3333333333333333
# ('beast', 'later'):1.0
# ('later', 'want'):0.3333333333333333
# ('want', 'destroy'):0.05
# ('destroy', 'everyth'):1.0
# ('everyth', 'absolut'):0.2
# ('absolut', 'think'):0.16666666666666666
# ('think', 'intrigu'):0.041666666666666664
# ('intrigu', 'stori'):0.5
# ('stori', 'plot'):0.06896551724137931
# ('plot', 'dialogu'):0.05555555555555555
# ('dialogu', 'enough'):0.25
# ('enough', 'give'):0.3333333333333333
# ('give', 'ten'):0.07142857142857142
# ('ten', 'worthi'):0.5
# ('worthi', 'watch'):0.16666666666666666
# ('watch', 'ye'):0.02631578947368421
# ('ye', 'amaz'):0.2
# ('amaz', 'went'):0.08333333333333333
# ('went', 'film'):0.07692307692307693
# ('film', 'expect'):0.014492753623188406
# ('expect', 'allie'):0.06666666666666667
# ('allie', 'classic'):1.0
# ('classic', 'base'):1.0
# ('base', 'review'):0.25
# ('review', 'read'):0.04
# ('read', 'end'):0.3333333333333333
# ('end', 'watch'):0.09090909090909091
# ('watch', 'decent'):0.02631578947368421
# ('decent', 'film'):0.3333333333333333
# ('film', 'overal'):0.014492753623188406
# ('overal', 'phoenix'):0.16666666666666666
# ('phoenix', 'outstand'):0.0196078431372549
# ('outstand', 'definit'):0.3333333333333333
# ('definit', 'part'):0.07692307692307693
# ('part', 'feel'):0.07692307692307693
# ('like', 'you'):0.017857142857142856
# ('you', 'seen'):0.6666666666666666
# ('seen', 'trailer'):0.043478260869565216
# ('trailer', 'you'):0.2
# ('movi', 'best'):0.009950248756218905
# ('best', 'way'):0.038461538461538464
# ('way', 'describ'):0.03571428571428571
# ('describ', 'film'):1.0
# ('film', 'feel'):0.014492753623188406
# ('like', '2'):0.017857142857142856
# ('2', 'hour'):0.8
# ('hour', 'version'):0.1111111111111111
# ('version', 'trailer'):0.1111111111111111
# ('trailer', '2'):0.2
# ('hour', 'rel'):0.1111111111111111
# ('rel', 'common'):1.0
# ('common', 'aunti'):1.0
# ('aunti', 'felt'):1.0
# ('felt', 'lot'):0.08333333333333333
# ('lot', 'longerwhich'):0.09090909090909091
# ('longerwhich', 'isn'):1.0
# ('isn', 'good'):0.125
# ('good', 'id'):0.022222222222222223
# ('say', 'much'):0.034482758620689655
# ('much', 'rental'):0.041666666666666664
# ('rental', 'theater'):1.0
# ('theater', 'movi'):0.16666666666666666
# ('movi', 'kind'):0.009950248756218905
# ('kind', 'just'):0.14285714285714285
# ('just', 'heard'):1.0
# ('heard', 'everyon'):0.5
# ('everyon', 'say'):0.1111111111111111
# ('say', 'film'):0.06896551724137931
# ('year', 'review'):0.09090909090909091
# ('review', 'flood'):0.04
# ('flood', 'wa'):1.0
# ('wa', 'quit'):0.5
# ('quit', 'hope'):0.18181818181818182
# ('hope', 'excit'):0.0625
# ('excit', 'movi'):0.4
# ('movi', 'walk'):0.004975124378109453
# ('walk', 'cinema'):0.3333333333333333
# ('cinema', 'felt'):0.16666666666666666
# ('felt', 'hollow'):0.08333333333333333
# ('hollow', 'empti'):0.5
# ('empti', 'continu'):0.25
# ('continu', 'write'):1.0
# ('write', 'let'):0.1111111111111111
# ('let', 'say'):0.16666666666666666
# ('year', 'real'):0.09090909090909091
# ('real', 'masterpiec'):0.07142857142857142
# ('masterpiec', 'cinematographi'):0.058823529411764705
# ('cinematographi', 'excel'):0.08333333333333333
# ('excel', 'act'):0.2
# ('act', 'incred'):0.030303030303030304
# ('incred', 'that'):0.16666666666666666
# ('that', 'sidecharact'):0.1
# ('sidecharact', 'bland'):1.0
# ('bland', 'overlay'):1.0
# ('overlay', 'dramat'):0.3333333333333333
# ('dramat', 'plot'):1.0
# ('plot', 'heavili'):0.05555555555555555
# ('heavili', 'relief'):1.0
# ('relief', 'plottwist'):1.0
# ('plottwist', 'film'):1.0
# ('film', 'harsh'):0.014492753623188406
# ('harsh', 'actual'):1.0
# ('actual', 'fall'):0.0625
# ('fall', 'flat'):0.2
# ('flat', 'face'):0.3333333333333333
# ('face', 'good'):0.2
# ('good', 'point'):0.022222222222222223
# ('point', 'though'):0.0625
# ('though', 'phoenix'):0.1
# ('phoenix', 'phenomenon'):0.0196078431372549
# ('phenomenon', 'score'):0.3333333333333333
# ('score', 'great'):0.07692307692307693
# ('great', 'cinematographi'):0.04
# ('cinematographi', 'also'):0.08333333333333333
# ('also', 'incred'):0.07142857142857142
# ('incred', 'plot'):0.16666666666666666
# ('plot', 'great'):0.05555555555555555
# ('great', 'even'):0.04
# ('even', 'plot'):0.041666666666666664
# ('plot', 'hole'):0.05555555555555555
# ('hole', 'scene'):1.0
# ('scene', 'left'):0.09090909090909091
# ('left', 'empti'):0.2
# ('empti', 'film'):0.25
# ('year', 'hope'):0.09090909090909091
# ('hope', 'opinion'):0.0625
# ('opinion', 'love'):0.16666666666666666
# ('love', 'joke'):0.125
# ('joke', 'perform'):0.008
# ('perform', 'cinematographi'):0.02857142857142857
# ('cinematographi', 'direct'):0.08333333333333333
# ('direct', 'style'):0.08333333333333333
# ('style', 'build'):0.3333333333333333
# ('build', 'great'):0.1111111111111111
# ('great', 'stori'):0.04
# ('act', 'phoenix'):0.06060606060606061
# ('phoenix', 'incred'):0.0196078431372549
# ('incred', 'done'):0.16666666666666666
# ('done', 'great'):0.16666666666666666
# ('great', 'take'):0.04
# ('take', 'iron'):0.05
# ('iron', 'charact'):0.6666666666666666
# ('charact', 'now'):0.018867924528301886
# ('now', 'commit'):0.5
# ('commit', 'look'):0.5
# ('look', 'weight'):0.07692307692307693
# ('weight', 'role'):1.0
# ('role', 'develop'):0.2
# ('develop', 'laugh'):0.16666666666666666
# ('laugh', 'recur'):0.07142857142857142
# ('recur', 'theme'):1.0
# ('theme', 'mani'):0.16666666666666666
# ('mani', '10'):0.03571428571428571
# ('10', 'star'):0.3333333333333333
# ('star', 'review'):0.25
# ('review', 'tell'):0.04
# ('tell', 'lot'):0.3333333333333333
# ('lot', 'movi'):0.09090909090909091
# ('movi', 'audienc'):0.004975124378109453
# ('audienc', 'can'):0.2
# ('can', 'get'):0.14285714285714285
# ('get', 'movi'):0.06896551724137931
# ('movi', 'review'):0.004975124378109453
# ('review', 'without'):0.04
# ('without', 'toss'):0.1
# ('toss', 'one'):1.0
# ('one', 'claim'):0.025
# ('claim', 'movi'):0.3333333333333333
# ('movi', 'much'):0.009950248756218905
# ('much', 'better'):0.16666666666666666
# ('better', 'smarter'):0.045454545454545456
# ('smarter', 'superhero'):1.0
# ('movi', 'even'):0.014925373134328358
# ('even', 'basin'):0.041666666666666664
# ('basin', 'entir'):1.0
# ('entir', 'review'):0.25
# ('review', 'around'):0.04
# ('around', 'premis'):0.16666666666666666
# ('premis', 'hate'):0.5
# ('hate', 'break'):0.14285714285714285
# ('break', 'kid'):0.25
# ('kid', 'your'):1.0
# ('your', 'nowher'):0.2
# ('nowher', 'near'):1.0
# ('near', 'intellig'):0.5
# ('intellig', 'grown'):0.25
# ('grown', 'think'):1.0
# ('think', 'comic'):0.041666666666666664
# ('comic', 'publish'):0.047619047619047616
# ('publish', 'better'):1.0
# ('better', 'is'):0.045454545454545456
# ('is', 'left'):0.5
# ('left', 'behind'):0.2
# ('behind', 'grade'):1.0
# ('grade', 'school'):0.5
# ('school', 'playground'):0.5
# ('playground', 'absolut'):1.0
# ('absolut', 'relev'):0.16666666666666666
# ('relev', 'qualiti'):0.5
# ('qualiti', 'movi'):0.6666666666666666
# ('movi', 'opinion'):0.004975124378109453
# ('opinion', 'movi'):0.16666666666666666
# ('movi', 'consid'):0.004975124378109453
# ('consid', 'highli'):0.125
# ('highli', 'suspect'):1.0
# ('suspect', 'your'):1.0
# ('your', 'group'):0.2
# ('group', 'gutta'):1.0
# ('gutta', 'say'):1.0
# ('say', 'movi'):0.13793103448275862
# ('movi', 'also'):0.01990049751243781
# ('also', 'idea'):0.07142857142857142
# ('idea', 'perfect'):0.3333333333333333
# ('film', 'ever'):0.014492753623188406
# ('ever', 'made'):0.07692307692307693
# ('made', 'realli'):0.05
# ('realli', 'need'):0.041666666666666664
# ('get', 'look'):0.034482758620689655
# ('look', 'get'):0.07692307692307693
# ('get', 'live'):0.034482758620689655
# ('live', 'safe'):0.25
# ('safe', 'littl'):0.5
# ('littl', 'box'):0.1111111111111111
# ('box', 'watch'):1.0
# ('watch', 'superhero'):0.02631578947368421
# ('superhero', 'move'):0.2727272727272727
# ('move', 'mainstream'):0.029411764705882353
# ('mainstream', 'blockbust'):1.0
# ('blockbust', 'understand'):0.5
# ('understand', 'exposur'):0.08333333333333333
# ('exposur', 'theme'):1.0
# ('theme', 'like'):0.16666666666666666
# ('like', 'first'):0.017857142857142856
# ('time', 'would'):0.030303030303030304
# ('would', 'seem'):0.038461538461538464
# ('seem', 'new'):0.1111111111111111
# ('new', 'excit'):0.2
# ('excit', 'think'):0.2
# ('think', 'agre'):0.041666666666666664
# ('agre', 'probabl'):0.5
# ('best', 'do'):0.038461538461538464
# ('do', 'comic'):0.125
# ('comic', 'relat'):0.047619047619047616
# ('relat', 'movi'):0.14285714285714285
# ('movi', 'last'):0.009950248756218905
# ('last', 'decad'):0.3333333333333333
# ('decad', 'though'):0.2
# ('though', 'that'):0.1
# ('that', 'high'):0.1
# ('high', 'bar'):0.09090909090909091
# ('bar', 'meet'):0.5
# ('meet', 'cours'):0.5
# ('cours', 'joaquin'):1.0
# ('phoenix', 'talent'):0.0196078431372549
# ('talent', 'actor'):0.2
# ('actor', 'stop'):0.07692307692307693
# ('stop', 'take'):0.5
# ('take', 'step'):0.05
# ('step', 'back'):0.3333333333333333
# ('back', 'look'):0.2
# ('look', 'thing'):0.07692307692307693
# ('thing', 'joke'):0.09090909090909091
# ('joke', 'inde'):0.008
# ('inde', 'present'):0.5
# ('present', 'theme'):0.2
# ('theme', 'import'):0.16666666666666666
# ('import', 'societi'):0.16666666666666666
# ('societi', 'neglect'):0.06666666666666667
# ('neglect', 'demon'):0.3333333333333333
# ('demon', 'mental'):1.0
# ('mental', 'ill'):0.6666666666666666
# ('ill', 'degre'):0.04
# ('degre', 'sometim'):1.0
# ('sometim', 'creat'):0.25
# ('creat', 'monster'):0.2
# ('monster', 'everyon'):0.5
# ('everyon', 'around'):0.1111111111111111
# ('around', 'seen'):0.16666666666666666
# ('seen', 'come'):0.043478260869565216
# ('come', 'mile'):0.1
# ('mile', 'away'):1.0
# ('away', 'hadn'):0.14285714285714285
# ('hadn', 'busi'):1.0
# ('busi', 'look'):0.5
# ('look', 'away'):0.07692307692307693
# ('away', 'avoid'):0.14285714285714285
# ('avoid', 'feel'):0.5
# ('feel', 'uncomfort'):0.058823529411764705
# ('uncomfort', 'unfortun'):0.25
# ('unfortun', 'remind'):0.5
# ('remind', 'u'):0.25
# ('u', 'fact'):0.125
# ('fact', 'situat'):0.25
# ('situat', 'still'):0.3333333333333333
# ('still', 'exist'):0.25
# ('exist', 'movi'):0.3333333333333333
# ('movi', 'realli'):0.009950248756218905
# ('realli', 'say'):0.041666666666666664
# ('say', 'danc'):0.034482758620689655
# ('danc', 'around'):0.5
# ('around', 'import'):0.16666666666666666
# ('import', 'subject'):0.16666666666666666
# ('subject', 'like'):0.5
# ('like', 'hey'):0.017857142857142856
# ('hey', 'kiss'):0.5
# ('kiss', 'class'):0.5
# ('class', 'inequ'):0.2
# ('inequ', 'never'):1.0
# ('never', 'offer'):0.1111111111111111
# ('offer', 'actual'):0.3333333333333333
# ('actual', 'insight'):0.0625
# ('insight', 'usual'):1.0
# ('usual', 'busi'):0.25
# ('busi', 'make'):0.5
# ('make', 'forc'):0.034482758620689655
# ('forc', 'batman'):0.2
# ('batman', 'refer'):0.15384615384615385
# ('refer', 'drop'):0.2
# ('drop', 'cring'):0.3333333333333333
# ('cring', 'littl'):0.16666666666666666
# ('littl', 'edg'):0.1111111111111111
# ('edg', 'moment'):0.2
# ('moment', 'like'):0.1111111111111111
# ('like', 'dont'):0.017857142857142856
# ('dont', 'smile'):0.037037037037037035
# ('smile', 'sign'):0.5
# ('sign', 'scene'):0.3333333333333333
# ('scene', 'seem'):0.09090909090909091
# ('seem', 'design'):0.1111111111111111
# ('design', 'sole'):0.3333333333333333
# ('sole', 'someth'):1.0
# ('someth', 'hot'):0.1
# ('hot', 'topic'):1.0
# ('topic', 'print'):0.5
# ('print', 'new'):1.0
# ('new', 'shirt'):0.2
# ('shirt', 'everi'):1.0
# ('singl', 'plot'):0.25
# ('plot', 'twist'):0.1111111111111111
# ('twist', 'telegraph'):0.2
# ('telegraph', 'far'):1.0
# ('far', 'advanc'):0.07142857142857142
# ('advanc', 'lot'):1.0
# ('lot', 'u'):0.09090909090909091
# ('u', 'seen'):0.125
# ('seen', 'exact'):0.043478260869565216
# ('exact', 'twist'):1.0
# ('twist', 'mani'):0.2
# ('mani', 'time'):0.10714285714285714
# ('time', 'want'):0.06060606060606061
# ('want', 'impress'):0.05
# ('impress', 'perhap'):0.3333333333333333
# ('perhap', 'actual'):0.3333333333333333
# ('actual', 'standalon'):0.0625
# ('standalon', 'movi'):1.0
# ('movi', 'instead'):0.004975124378109453
# ('instead', 'shock'):0.16666666666666666
# ('shock', 'complet'):0.5
# ('complet', 'unnecessari'):0.07142857142857142
# ('unnecessari', 'tie'):0.3333333333333333
# ('tie', 'batman'):0.3333333333333333
# ('batman', 'univers'):0.23076923076923078
# ('univers', 'could'):0.16666666666666666
# ('could', 'done'):0.05555555555555555
# ('done', 'someth'):0.16666666666666666
# ('someth', 'interest'):0.1
# ('interest', 'theme'):0.16666666666666666
# ('theme', 'dont'):0.16666666666666666
# ('get', 'wrong'):0.06896551724137931
# ('wrong', 'dont'):0.2
# ('dont', 'problem'):0.037037037037037035
# ('problem', 'superhero'):0.3333333333333333
# ('move', 'feel'):0.029411764705882353
# ('feel', 'gratuit'):0.029411764705882353
# ('gratuit', 'someon'):1.0
# ('someon', 'came'):0.25
# ('came', 'idea'):0.2
# ('idea', 'pitch'):0.3333333333333333
# ('pitch', 'execut'):1.0
# ('execut', 'told'):0.25
# ('told', 'sound'):0.08333333333333333
# ('sound', 'great'):0.3333333333333333
# ('great', 'make'):0.04
# ('make', 'batman'):0.034482758620689655
# ('batman', 'movi'):0.07692307692307693
# ('movi', 'somehow'):0.004975124378109453
# ('somehow', 'in'):0.5
# ('in', 'sorri'):0.125
# ('sorri', 'in'):0.3333333333333333
# ('in', 'movi'):0.125
# ('movi', 'tri'):0.014925373134328358
# ('tri', 'tell'):0.1111111111111111
# ('tell', 'hardheart'):0.3333333333333333
# ('hardheart', 'yet'):1.0
# ('yet', 'deadseri'):0.2
# ('deadseri', 'speech'):1.0
# ('speech', 'mental'):1.0
# ('ill', 'modern'):0.04
# ('modern', 'societi'):0.5
# ('societi', 'simultan'):0.06666666666666667
# ('simultan', 'constantli'):1.0
# ('constantli', 'remind'):1.0
# ('remind', 'technic'):0.25
# ('technic', 'superhero'):0.5
# ('movi', 'hope'):0.004975124378109453
# ('hope', 'see'):0.0625
# ('movi', 'love'):0.004975124378109453
# ('love', 'trailer'):0.125
# ('trailer', 'movi'):0.4
# ('movi', 'want'):0.009950248756218905
# ('want', 'watch'):0.1
# ('watch', 'cinema'):0.02631578947368421
# ('cinema', 'long'):0.16666666666666666
# ('long', 'time'):0.42857142857142855
# ('time', 'watch'):0.030303030303030304
# ('watch', 'bore'):0.02631578947368421
# ('bore', 'aesthet'):0.058823529411764705
# ('aesthet', 'amaz'):1.0
# ('amaz', 'music'):0.08333333333333333
# ('music', 'good'):0.16666666666666666
# ('good', 'stori'):0.06666666666666667
# ('stori', 'execut'):0.06896551724137931
# ('execut', 'me'):0.25
# ('me', 'perform'):1.0
# ('perform', 'joke'):0.05714285714285714
# ('joke', 'good'):0.008
# ('good', 'perform'):0.022222222222222223
# ('perform', 'peopl'):0.02857142857142857
# ('peopl', 'rave'):0.023809523809523808
# ('rave', 'drive'):0.5
# ('drive', 'mad'):0.3333333333333333
# ('mad', 'either'):0.2
# ('either', 'seen'):1.0
# ('seen', 'mani'):0.13043478260869565
# ('mani', 'move'):0.10714285714285714
# ('move', 'seen'):0.058823529411764705
# ('mani', 'movi'):0.03571428571428571
# ('movi', 'bang'):0.009950248756218905
# ('bang', 'averag'):1.0
# ('averag', 'actual'):0.25
# ('actual', 'bore'):0.0625
# ('bore', 'actual'):0.058823529411764705
# ('actual', 'think'):0.0625
# ('think', 'leav'):0.041666666666666664
# ('leav', 'half'):0.16666666666666666
# ('half', 'way'):1.0
# ('way', 'bore'):0.07142857142857142
# ('bore', 'mind'):0.058823529411764705
# ('mind', 'regret'):0.3333333333333333
# ('regret', 'watch'):1.0
# ('watch', 'overhyp'):0.02631578947368421
# ('overhyp', 'confus'):0.2
# ('confus', 'right'):0.5
# ('right', 'think'):0.14285714285714285
# ('think', 'good'):0.08333333333333333
# ('good', 'premis'):0.022222222222222223
# ('premis', 'could'):0.5
# ('could', 'much'):0.05555555555555555
# ('much', 'much'):0.041666666666666664
# ('much', 'sign'):0.041666666666666664
# ('sign', 'great'):0.3333333333333333
# ('great', 'movi'):0.12
# ('movi', 'repeat'):0.004975124378109453
# ('repeat', 'view'):1.0
# ('view', 'move'):0.5
# ('move', 'joke'):0.058823529411764705
# ('joke', 'move'):0.008
# ('move', 'whatsoev'):0.029411764705882353
# ('whatsoev', 'would'):0.5
# ('would', 'watch'):0.038461538461538464
# ('watch', 'thought'):0.02631578947368421
# ('thought', 'mayb'):0.09090909090909091
# ('mayb', 'peopl'):0.16666666666666666
# ('peopl', 'get'):0.023809523809523808
# ('get', 'paid'):0.034482758620689655
# ('paid', 'write'):0.5
# ('write', 'good'):0.2222222222222222
# ('good', 'review'):0.022222222222222223
# ('review', 'actual'):0.04
# ('actual', 'met'):0.0625
# ('met', 'peopl'):1.0
# ('think', 'best'):0.041666666666666664
# ('movi', 'ever'):0.004975124378109453
# ('ever', 'ogg'):0.07692307692307693
# ('ogg', 'movi'):1.0
# ('averag', 'way'):0.25
# ('way', 'overhyp'):0.03571428571428571
# ('overhyp', 'phoenix'):0.2
# ('phoenix', 'perform'):0.0784313725490196
# ('perform', 'good'):0.02857142857142857
# ('execut', 'bad'):0.25
# ('bad', 'feel'):0.0625
# ('feel', 'never'):0.029411764705882353
# ('never', 'even'):0.1111111111111111
# ('even', 'touch'):0.041666666666666664
# ('touch', 'higher'):0.25
# ('higher', 'spectrum'):1.0
# ('spectrum', 'perform'):1.0
# ('perform', 'could'):0.02857142857142857
# ('could', 'charact'):0.05555555555555555
# ('charact', 'experienc'):0.018867924528301886
# ('experienc', 'seen'):1.0
# ('seen', 'wors'):0.043478260869565216
# ('wors', 'life'):0.5
# ('life', 'made'):0.08333333333333333
# ('made', 'feel'):0.15
# ('feel', 'hate'):0.029411764705882353
# ('hate', 'word'):0.14285714285714285
# ('word', 'use'):0.5
# ('use', 'snowflak'):0.25
# ('snowflak', 'plea'):1.0
# ('plea', 'get'):0.25
# ('get', 'social'):0.034482758620689655
# ('social', 'medium'):0.5
# ('medium', 'live'):1.0
# ('live', 'life'):0.25
# ('life', 'real'):0.08333333333333333
# ('real', 'world'):0.07142857142857142
# ('world', 'joaquin'):0.14285714285714285
# ('give', 'heath'):0.07142857142857142
# ('ledger', 'run'):0.05555555555555555
# ('run', 'money'):1.0
# ('money', 'true'):0.1111111111111111
# ('true', 'stori'):0.16666666666666666
# ('stori', 'popcorn'):0.034482758620689655
# ('popcorn', 'fluff'):1.0
# ('fluff', 'comic'):1.0
# ('book', 'flick'):0.125
# ('flick', 'take'):1.0
# ('take', 'kiss'):0.05
# ('kiss', 'see'):0.5
# ('movi', 'shut'):0.004975124378109453
# ('shut', 'ballot'):1.0
# ('ballot', 'oscar'):1.0
# ('oscar', 'joaquin'):0.047619047619047616
# ('joaquin', 'take'):0.022727272727272728
# ('take', 'one'):0.1
# ('one', 'home'):0.025
# ('home', 'hand'):1.0
# ('hand', 'one'):0.14285714285714285
# ('best', 'origin'):0.038461538461538464
# ('origin', 'stori'):0.3076923076923077
# ('stori', 'ever'):0.034482758620689655
# ('ever', 'put'):0.07692307692307693
# ('put', 'downsid'):0.08333333333333333
# ('downsid', 'movi'):1.0
# ('movi', 'stand'):0.004975124378109453
# ('stand', 'alon'):0.5
# ('alon', 'film'):0.5
# ('film', 'sequel'):0.014492753623188406
# ('sequel', 'tie'):1.0
# ('tie', 'do'):0.3333333333333333
# ('do', 'univers'):0.125
# ('univers', 'told'):0.16666666666666666
# ('told', 'philip'):0.16666666666666666
# ('philip', 'take'):0.3333333333333333
# ('joke', 'one'):0.008
# ('one', 'pure'):0.025
# ('pure', 'brillianc'):0.5
# ('brillianc', 'joaquin'):0.5
# ('phoenix', 'joke'):0.0196078431372549
# ('deserv', 'didn'):0.1
# ('didn', 'steal'):0.14285714285714285
# ('steal', 'jack'):1.0
# ('jack', 'heath'):0.25
# ('heath', 'yet'):0.058823529411764705
# ('yet', 'got'):0.2
# ('got', 'tast'):0.14285714285714285
# ('tast', 'music'):1.0
# ('music', 'intens'):0.16666666666666666
# ('intens', 'realism'):0.5
# ('realism', 'perform'):1.0
# ('perform', 'stori'):0.02857142857142857
# ('stori', 'perfect'):0.06896551724137931
# ('perfect', 'combin'):0.09090909090909091
# ('combin', 'everyth'):0.5
# ('everyth', 'never'):0.2
# ('never', 'felt'):0.1111111111111111
# ('felt', 'charact'):0.08333333333333333
# ('charact', 'like'):0.018867924528301886
# ('like', 'joke'):0.017857142857142856
# ('joke', 'could'):0.008
# ('could', 'real'):0.05555555555555555
# ('real', 'saw'):0.07142857142857142
# ('saw', 'phoenix'):0.25
# ('phoenix', 'show'):0.0196078431372549
# ('show', 'u'):0.15384615384615385
# ('u', 'joke'):0.125
# ('joke', 'societi'):0.016
# ('societi', 'show'):0.06666666666666667
# ('u', 'power'):0.125
# ('power', 'obtain'):0.25
# ('obtain', 'philip'):1.0
# ('philip', 'hand'):0.3333333333333333
# ('hand', 'perfect'):0.14285714285714285
# ('perfect', 'choic'):0.09090909090909091
# ('choic', 'music'):0.25
# ('music', 'camera'):0.16666666666666666
# ('camera', 'angl'):0.5
# ('angl', 'light'):0.5
# ('light', 'everi'):0.25
# ('everi', 'import'):0.14285714285714285
# ('import', 'factor'):0.16666666666666666
# ('factor', 'overal'):1.0
# ('overal', 'expect'):0.16666666666666666
# ('expect', 'stori'):0.06666666666666667
# ('perfect', 'mani'):0.09090909090909091
# ('mani', 'shock'):0.03571428571428571
# ('shock', 'turn'):0.5
# ('turn', 'happen'):0.25
# ('happen', 'realli'):0.0625
# ('realli', 'repres'):0.041666666666666664
# ('repres', 'today'):1.0
# ('today', 'societi'):0.5
# ('societi', 'first'):0.06666666666666667
# ('first', 'screen'):0.09090909090909091
# ('screen', 'would'):0.5
# ('would', 'applaus'):0.038461538461538464
# ('applaus', '80'):0.5
# ('80', 'min'):1.0
# ('min', '8'):1.0
# ('8', 'say'):0.5
# ('say', 'write'):0.034482758620689655
# ('write', 'great'):0.1111111111111111
# ('great', 'exampl'):0.04
# ('exampl', 'good'):0.25
# ('act', 'product'):0.030303030303030304
# ('product', 'valu'):1.0
# ('valu', 'can'):0.3333333333333333
# ('not', 'save'):0.3333333333333333
# ('save', 'script'):0.5
# ('script', 'step'):0.3333333333333333
# ('step', 'tiresom'):0.3333333333333333
# ('tiresom', 'stereotyp'):1.0
# ('stereotyp', 'failur'):1.0
# ('failur', 'delv'):1.0
# ('delv', 'charact'):1.0
# ('charact', 'ident'):0.018867924528301886
# ('ident', 'meet'):1.0
# ('meet', 'joke'):0.5
# ('joke', 'alreadi'):0.008
# ('alreadi', 'balanc'):0.5
# ('balanc', 'call'):1.0
# ('call', 'descent'):0.125
# ('descent', 'mad'):0.3333333333333333
# ('mad', 'realli'):0.2
# ('realli', 'coupl'):0.041666666666666664
# ('coupl', 'week'):0.3333333333333333
# ('week', 'away'):1.0
# ('away', 'far'):0.14285714285714285
# ('far', 'descent'):0.07142857142857142
# ('descent', 'stroll'):0.3333333333333333
# ('stroll', 'charact'):1.0
# ('charact', 'studi'):0.07547169811320754
# ('studi', 'despit'):0.25
# ('despit', 'claim'):0.3333333333333333
# ('claim', 'contrari'):0.3333333333333333
# ('contrari', 'showcas'):0.5
# ('showcas', 'good'):0.5
# ('good', 'actor'):0.022222222222222223
# ('actor', 'overlay'):0.07692307692307693
# ('overlay', 'contort'):0.3333333333333333
# ('contort', 'bodi'):1.0
# ('bodi', 'laugh'):1.0
# ('laugh', 'magic'):0.07142857142857142
# ('magic', 'mistaken'):1.0
# ('mistaken', 'express'):1.0
# ('express', 'mad'):0.5
# ('mad', 'past'):0.2
# ('past', 'influenc'):0.2
# ('influenc', 'conflict'):1.0
# ('conflict', 'semin'):1.0
# ('semin', 'moment'):1.0
# ('moment', 'creat'):0.1111111111111111
# ('creat', 'spiral'):0.2
# ('spiral', 'perhap'):1.0
# ('perhap', 'realli'):0.3333333333333333
# ('realli', 'relationship'):0.041666666666666664
# ('relationship', 'gone'):1.0
# ('gone', 'sour'):1.0
# ('sour', 'would'):1.0
# ('would', 'justifi'):0.038461538461538464
# ('justifi', 'descent'):0.25
# ('descent', 'instead'):0.3333333333333333
# ('instead', 'fait'):0.16666666666666666
# ('fait', 'accompli'):1.0
# ('accompli', 'lazi'):1.0
# ('lazi', 'write'):1.0
# ('write', 'focus'):0.1111111111111111
# ('focus', 'fanci'):0.3333333333333333
# ('fanci', 'long'):1.0
# ('long', 'shot'):0.14285714285714285
# ('shot', 'joaquin'):0.5
# ('phoenix', 'danc'):0.0196078431372549
# ('danc', 'crazi'):0.25
# ('crazi', 'produc'):0.14285714285714285
# ('produc', 'someth'):0.3333333333333333
# ('someth', 'valu'):0.1
# ('valu', 'franchis'):0.3333333333333333
# ('franchis', 'beyond'):1.0
# ('beyond', 'pathet'):0.3333333333333333
# ('pathet', 'taxi'):1.0
# ('taxi', 'divert'):0.07692307692307693
# ('divert', 'comedi'):1.0
# ('comedi', 'trepoff'):0.2
# ('trepoff', 'briefest'):1.0
# ('briefest', 'object'):1.0
# ('object', 'singl'):1.0
# ('singl', 'worstcomplet'):0.25
# ('worstcomplet', 'nonexist'):1.0
# ('nonexist', 'version'):1.0
# ('version', 'joke'):0.4444444444444444
# ('joke', 'charact'):0.048
# ('charact', 'histori'):0.018867924528301886
# ('histori', 'trollworthi'):0.25
# ('trollworthi', 'masterpiec'):1.0
# ('masterpiec', 'review'):0.058823529411764705
# ('review', 'dictionari'):0.04
# ('dictionari', 'definit'):1.0
# ('definit', 'proof'):0.07692307692307693
# ('proof', 'easi'):1.0
# ('easi', 'fool'):0.3333333333333333
# ('fool', 'laughabl'):0.5
# ('laughabl', 'careless'):1.0
# ('careless', 'sheep'):1.0
# ('sheep', 'keep'):1.0
# ('keep', 'cri'):0.14285714285714285
# ('cri', 'societi'):0.25
# ('societi', 'cring'):0.06666666666666667
# ('cring', 'lower'):0.16666666666666666
# ('lower', 'inch'):0.3333333333333333
# ('inch', 'perfect'):1.0
# ('perfect', 'portrait'):0.09090909090909091
# ('portrait', 'declin'):1.0
# ('declin', 'insan'):0.5
# ('insan', 'joaquin'):0.3333333333333333
# ('phoenix', 'portray'):0.0196078431372549
# ('portray', 'fearlessli'):0.1111111111111111
# ('fearlessli', 'perform'):1.0
# ('perform', 'lifetim'):0.05714285714285714
# ('lifetim', 'choreograph'):0.5
# ('choreograph', 'impecc'):1.0
# ('impecc', 'told'):1.0
# ('phillip', 'noth'):0.125
# ('noth', 'short'):0.14285714285714285
# ('short', 'breathtak'):0.2
# ('breathtak', 'cinematographi'):0.5
# ('cinematographi', 'backdrop'):0.08333333333333333
# ('backdrop', 'ideolog'):1.0
# ('ideolog', 'origin'):1.0
# ('origin', 'film'):0.15384615384615385
# ('film', 'complex'):0.014492753623188406
# ('complex', 'charact'):1.0
# ('charact', 'compliment'):0.018867924528301886
# ('compliment', 'superb'):1.0
# ('superb', 'soundtrack'):1.0
# ('soundtrack', 'act'):0.5
# ('act', 'hauntingli'):0.030303030303030304
# ('hauntingli', 'beauti'):1.0
# ('beauti', 'film'):0.5
# ('film', 'definit'):0.014492753623188406
# ('definit', '1010'):0.07692307692307693
# ('1010', 'edit'):0.16666666666666666
# ('edit', 'bring'):0.3333333333333333
# ('bring', 'part'):0.16666666666666666
# ('part', '2'):0.07692307692307693
# ('2', 'plssssss'):0.1
# ('plssssss', 'want'):1.0
# ('want', 'realli'):0.05
# ('realli', 'slow'):0.041666666666666664
# ('slow', 'pace'):0.2222222222222222
# ('pace', 'bore'):0.3333333333333333
# ('bore', 'overhyp'):0.058823529411764705
# ('overhyp', 'opinion'):0.2
# ('opinion', 'phoenix'):0.16666666666666666
# ('phoenix', 'convinc'):0.0392156862745098
# ('convinc', 'alway'):0.25
# ('alway', 'meant'):0.3333333333333333
# ('meant', 'joke'):0.3333333333333333
# ('joke', 'movi'):0.048
# ('movi', 'went'):0.004975124378109453
# ('went', 'beyond'):0.07692307692307693
# ('beyond', 'expect'):0.3333333333333333
# ('expect', 'mani'):0.06666666666666667
# ('mani', 'emot'):0.03571428571428571
# ('emot', 'went'):0.2857142857142857
# ('went', 'coupl'):0.07692307692307693
# ('coupl', 'hour'):0.3333333333333333
# ('hour', 'think'):0.1111111111111111
# ('think', 'rate'):0.041666666666666664
# ('rate', 'r'):0.125
# ('r', 'phoenix'):1.0
# ('phoenix', 'abl'):0.0196078431372549
# ('abl', 'clock'):0.25
# ('clock', 'joke'):1.0
# ('joke', 'full'):0.008
# ('full', 'psychic'):0.5
# ('psychic', 'potenti'):0.25
# ('potenti', 'charact'):0.2
# ('charact', 'meant'):0.018867924528301886
# ('meant', 'amaz'):0.3333333333333333
# ('amaz', 'stori'):0.16666666666666666
# ('stori', 'call'):0.034482758620689655
# ('call', 'mean'):0.125
# ...
# ('bother', 'invest'):1.0
# ('invest', 'time'):1.0
# ('time', 'money'):0.030303030303030304
# ('money', 'requir'):0.1111111111111111
# ('requir', 'creat'):1.0
# ('creat', 'turkey'):0.2
# ('turkey', 'much'):1.0
# ('much', 'le'):0.041666666666666664
# ('le', 'watch'):0.25
# ('watch', 'they'):0.02631578947368421
# ('they', 'murder'):1.0
# ('murder', 'joke'):0.2
# ('joke', 'sake'):0.008
# ('sake', 'social'):1.0
# ('social', 'commentari'):0.5
# ('commentari', 'pp'):0.5
# ('pp', 'promot'):0.5
# ('promot', 'dont'):1.0
# ('dont', 'deni'):0.037037037037037035
# ('deni', 'mental'):1.0
# ('ill', 'real'):0.04
# ('real', 'issu'):0.07142857142857142
# ('issu', 'attent'):0.2
# ('attent', 'brought'):0.25
# ('brought', 'folk'):0.5
# ('folk', 'watch'):1.0
# ('move', 'supervillian'):0.029411764705882353
# ('supervillian', 'see'):1.0
# ('see', 'supervillaini'):0.04
# ('supervillaini', '2'):1.0
# ('hour', 'public'):0.1111111111111111
# ('public', 'servic'):0.5
# ('servic', 'announc'):0.5
# ('announc', 'hung'):1.0
# ('hung', 'long'):1.0
# ('long', 'could'):0.14285714285714285
# ('could', 'hope'):0.05555555555555555
# ('hope', 'movi'):0.0625
# ('movi', 'redeem'):0.004975124378109453
# ('redeem', '3'):1.0
# ('3', 'quarter'):0.2
# ('quarter', 'way'):1.0
# ('way', 'could'):0.03571428571428571
# ('could', 'take'):0.05555555555555555
# ('watch', 'spin'):0.02631578947368421
# ('spin', 'wheel'):0.5
# ('wheel', 'fan'):1.0
# ('fan', 'jack'):0.5
# ('ledger', 'version'):0.05555555555555555
# ('joke', 'like'):0.008
# ('like', 'find'):0.017857142857142856
# ('find', 'film'):0.5
# ('film', 'pain'):0.014492753623188406
# ('pain', 'watch'):0.2
# ('watch', 'best'):0.02631578947368421
# ('act', 'stori'):0.030303030303030304
# ('stori', 'oscar'):0.034482758620689655
# ('win', 'movi'):0.125
# ('movi', 'sat'):0.004975124378109453
# ('sat', 'slowwwwww'):1.0
# ('slowwwwww', 'movi'):1.0
# ('would', 'gladli'):0.038461538461538464
# ('gladli', 'left'):1.0
# ('left', 'half'):0.2
# ('bore', 'movi'):0.058823529411764705
# ('last', '5'):0.16666666666666666
# ('minut', 'overhyp'):0.25
# ('overhyp', 'usualth'):0.2
# ('usualth', 'violenc'):1.0
# ('violenc', 'must'):0.14285714285714285
# ('must', 'cut'):0.5
# ('cut', 'version'):0.5
# ('version', 'seen'):0.1111111111111111
# ('seen', 'think'):0.043478260869565216
# ('think', 'seen'):0.041666666666666664
# ('seen', 'more'):0.043478260869565216
# ('more', 'dinner'):1.0
# ('dinner', 'movi'):1.0
# ('movi', 'realiti'):0.004975124378109453
# ('realiti', 'far'):0.2
# ('far', 'fiction'):0.07142857142857142
# ('fiction', 'what'):1.0
# ('what', 'made'):0.3333333333333333
# ('made', 'movi'):0.05
# ('movi', 'oscar'):0.004975124378109453
# ('oscar', 'winner'):0.047619047619047616
# ('winner', 'actor'):1.0
# ('actor', 'made'):0.07692307692307693
# ('made', 'new'):0.05
# ('new', 'joke'):0.2
# ('joke', 'rivalri'):0.008
# ('rivalri', 'heath'):1.0
# ('joke', 'better'):0.008
# ('joke', 'peopl'):0.008
# ('peopl', 'opinion'):0.023809523809523808
# ('opinion', 'piec'):0.16666666666666666
# ('piec', 'art'):0.16666666666666666
# ('art', 'mental'):0.14285714285714285
# ('person', 'without'):0.0625
# ('without', 'talent'):0.1
# ('talent', 'intellig'):0.4
# ('intellig', 'can'):0.25
# ('not', 'becom'):0.3333333333333333
# ('becom', 'super'):0.1111111111111111
# ('super', 'villain'):0.3333333333333333
# ('villain', 'angri'):0.07692307692307693
# ('angri', 'mental'):1.0
# ('person', 'talent'):0.0625
# ('intellig', 'anger'):0.25
# ('anger', 'noth'):1.0
# ('noth', 'film'):0.14285714285714285
# ('lack', 'creativ'):0.125
# ('creativ', 'depth'):0.25
# ('depth', 'sen'):0.25
# ('sen', 'unfortun'):0.3333333333333333
# ('unfortun', 'joke'):0.5
# ('joke', 'iron'):0.008
# ('charact', 'thing'):0.018867924528301886
# ('thing', 'twilight'):0.09090909090909091
# ('twilight', 'empir'):1.0
# ('empir', 'film'):1.0
# ('film', 'yesterday'):0.014492753623188406
# ('yesterday', 'day'):0.5
# ('day', 'understand'):0.3333333333333333
# ('understand', 'touch'):0.08333333333333333
# ('touch', 'histori'):0.25
# ('histori', 'movi'):0.25
# ('movi', 'drag'):0.004975124378109453
# ('drag', 'deepest'):1.0
# ('deepest', 'thought'):1.0
# ('thought', 'dark'):0.09090909090909091
# ('dark', 'secret'):0.041666666666666664
# ('secret', 'suffer'):1.0
# ('suffer', 'masterpiec'):0.14285714285714285
# ('masterpiec', 'grind'):0.058823529411764705
# ('grind', 'like'):1.0
# ('like', 'meat'):0.017857142857142856
# ('meat', 'grinder'):1.0
# ('grinder', 'watch'):1.0
# ('watch', 'silenc'):0.02631578947368421
# ('silenc', 'open'):1.0
# ('open', 'mouth'):1.0
# ('mouth', 'like'):1.0
# ('like', 'whole'):0.017857142857142856
# ('whole', 'cinema'):0.1111111111111111
# ('cinema', 'dont'):0.16666666666666666
# ('dont', 'like'):0.037037037037037035
# ('like', 'comic'):0.017857142857142856
# ('movi', 'marvel'):0.004975124378109453
# ('marvel', 'pompou'):0.3333333333333333
# ('pompou', 'absurd'):1.0
# ('absurd', 'insipid'):1.0
# ('insipid', 'opinion'):1.0
# ('opinion', 'art'):0.16666666666666666
# ('art', 'attract'):0.14285714285714285
# ('attract', 'do'):1.0
# ('do', 'made'):0.0625
# ('made', 'histori'):0.05
# ('histori', 'made'):0.25
# ('made', 'art'):0.05
# ('art', 'made'):0.14285714285714285
# ('made', 'drama'):0.05
# ('drama', 'understand'):0.16666666666666666
# ('understand', 'watch'):0.08333333333333333
# ('watch', 'exampl'):0.02631578947368421
# ('exampl', 'avenu'):0.25
# ('avenu', 'leagu'):1.0
# ('leagu', 'justic'):0.5
# ('justic', 'eat'):0.5
# ('eat', 'macdonald'):0.3333333333333333
# ('macdonald', 'hamburg'):1.0
# ('hamburg', 'watch'):1.0
# ('watch', 'joke'):0.02631578947368421
# ('joke', 'eat'):0.008
# ('eat', '1000'):0.3333333333333333
# ('1000', 'stake'):1.0
# ('stake', 'luxuri'):1.0
# ('luxuri', 'restaur'):1.0
# ('restaur', 'world'):1.0
# ('world', 'outstand'):0.14285714285714285
# ('outstand', 'perform'):0.3333333333333333
# ('phoenix', 'complet'):0.0196078431372549
# ('complet', 'embodi'):0.07142857142857142
# ('charact', 'film'):0.018867924528301886
# ('film', 'peopl'):0.014492753623188406
# ('peopl', 'decad'):0.023809523809523808
# ('decad', 'watch'):0.2
# ('watch', 'inevit'):0.02631578947368421
# ('inevit', 'render'):0.3333333333333333
# ('render', 'speechless'):0.5
# ('speechless', 'except'):0.5
# ('except', 'anyon'):0.3333333333333333
# ('anyon', '30'):0.14285714285714285
# ('30', 'see'):1.0
# ('see', 'kind'):0.04
# ('kind', 'grip'):0.14285714285714285
# ('grip', 'king'):0.5
# ('comedi', '1982'):0.2
# ('1982', 'plan'):1.0
# ('plan', 'watch'):0.3333333333333333
# ('would', 'suggest'):0.038461538461538464
# ('suggest', 'ship'):1.0
# ('ship', 'last'):1.0
# ('last', '20'):0.16666666666666666
# ('20', '30min'):1.0
# ('30min', 'otherwis'):1.0
# ('otherwis', 'complet'):0.3333333333333333
# ('complet', 'bore'):0.07142857142857142
# ('bore', 'thought'):0.058823529411764705
# ('thought', 'peopl'):0.09090909090909091
# ('say', 'suppos'):0.034482758620689655
# ('suppos', 'better'):0.3333333333333333
# ('say', 'joke'):0.034482758620689655
# ('doesn', 'potenti'):0.1
# ('potenti', 'spent'):0.2
# ('spent', '90'):1.0
# ('90', 'movi'):0.5
# ('show', 'mental'):0.07692307692307693
# ('mental', 'issu'):0.037037037037037035
# ('issu', 'joke'):0.2
# ('joke', 'without'):0.008
# ('without', 'doubt'):0.1
# ('doubt', 'new'):0.3333333333333333
# ('new', 'favorit'):0.2
# ('favorit', 'do'):0.3333333333333333
# ('gritti', 'enough'):0.3333333333333333
# ('enough', 'psycholog'):0.3333333333333333
# ('psycholog', 'twist'):0.2
# ('twist', 'keep'):0.2
# ('keep', 'guess'):0.14285714285714285
# ('guess', 'begin'):1.0
# ('begin', 'end'):0.25
# ('end', 'noth'):0.09090909090909091
# ('noth', 'taken'):0.14285714285714285
# ('taken', 'face'):1.0
# ('face', 'valu'):0.2
# ('valu', 'film'):0.3333333333333333
# ('film', 'forc'):0.014492753623188406
# ('forc', 'think'):0.2
# ('think', 'begin'):0.041666666666666664
# ('end', 'dont'):0.09090909090909091
# ('dont', 'listen'):0.037037037037037035
# ('listen', 'critic'):1.0
# ('critic', 'one'):0.14285714285714285
# ('one', 'worth'):0.025
# ('worth', 'watch'):0.2
# ('watch', 'multipl'):0.02631578947368421
# ('multipl', 'time'):0.2
# ('time', 'theater'):0.030303030303030304
# ('theater', 'say'):0.16666666666666666
# ('say', 'satisfi'):0.034482758620689655
# ('satisfi', 'would'):1.0
# ('would', 'somewhat'):0.038461538461538464
# ('somewhat', 'mislead'):0.25
# ('mislead', 'joaquin'):1.0
# ('phoenix', 'make'):0.0196078431372549
# ('uncomfort', 'almost'):0.25
# ('almost', 'entir'):0.125
# ('entir', 'time'):0.25
# ('time', 'couldn'):0.030303030303030304
# ('couldn', 'help'):0.5
# ('help', 'think'):0.3333333333333333
# ('think', 'christian'):0.041666666666666664
# ('christian', 'abl'):1.0
# ('abl', 'machin'):0.25
# ('machin', 'robert'):1.0
# ('no', 'taxi'):0.2
# ('driver', 'comparison'):0.08333333333333333
# ('comparison', 'clearli'):0.25
# ('clearli', 'high'):0.25
# ('high', 'prais'):0.09090909090909091
# ('prais', 'act'):0.5
# ('act', 'film'):0.030303030303030304
# ('film', 'slowli'):0.014492753623188406
# ('slowli', 'build'):0.3333333333333333
# ('build', 'momentum'):0.1111111111111111
# ('momentum', 'buildsit'):1.0
# ('buildsit', 'realli'):1.0
# ('realli', 'build'):0.041666666666666664
# ('build', 'look'):0.1111111111111111
# ('look', 'tradit'):0.07692307692307693
# ('tradit', 'comic'):1.0
# ('book', 'action'):0.125
# ('action', 'may'):0.06666666666666667
# ('feel', 'move'):0.029411764705882353
# ('move', 'bit'):0.029411764705882353
# ('pace', 'allow'):0.3333333333333333
# ('allow', 'transform'):0.5
# ('transform', 'feel'):0.25
# ('feel', 'superfici'):0.029411764705882353
# ('superfici', 'walk'):1.0
# ('walk', 'theater'):0.3333333333333333
# ('theater', 'wont'):0.16666666666666666
# ('wont', 'know'):0.25
# ('know', 'exactli'):0.05263157894736842
# ('exactli', 'feel'):0.25
# ('feel', 'you'):0.029411764705882353
# ('you', 'sure'):0.3333333333333333
# ('sure', 'want'):0.14285714285714285
# ('want', 'know'):0.05
# ('know', 'everyon'):0.05263157894736842
# ('everyon', 'el'):0.1111111111111111
# ('el', 'feel'):0.3333333333333333
# ('feel', 'heath'):0.029411764705882353
# ('heath', 'great'):0.058823529411764705
# ('great', 'dark'):0.04
# ('knight', 'even'):0.1111111111111111
# ('even', 'like'):0.041666666666666664
# ('like', 'dare'):0.017857142857142856
# ('dare', 'let'):0.6666666666666666
# ('let', 'suicid'):0.16666666666666666
# ('suicid', 'squad'):1.0
# ('squad', 'see'):1.0
# ('see', 'countless'):0.04
# ('countless', 'a'):1.0
# ('a', 'joke'):1.0
# ('joke', 'definit'):0.008
# ('definit', 'dont'):0.07692307692307693
# ('watch', 'even'):0.02631578947368421
# ('even', 'free'):0.041666666666666664
# ('free', 'watch'):0.5
# ('watch', 'rather'):0.02631578947368421
# ('rather', 'wast'):0.3333333333333333
# ('wast', 'money'):0.2
# ('money', 'cinema'):0.1111111111111111
# ('cinema', 'phoenix'):0.16666666666666666
# ('phoenix', 'depress'):0.0196078431372549
# ('depress', 'watch'):0.3333333333333333
# ('want', 'fast'):0.05
# ('fast', 'forward'):1.0
# ('forward', 'thou'):0.3333333333333333
# ('thou', 'perform'):1.0
# ('perform', 'much'):0.02857142857142857
# ('much', 'drama'):0.041666666666666664
# ('drama', 'sit'):0.16666666666666666
# ('sit', 'watch'):0.3333333333333333
# ('watch', 'without'):0.02631578947368421
# ('without', 'want'):0.1
# ('want', 'get'):0.05
# ('get', 'someth'):0.034482758620689655
# ('someth', 'like'):0.1
# ('like', 'make'):0.017857142857142856
# ('make', 'cup'):0.034482758620689655
# ('cup', 'tea'):1.0
# ('tea', 'person'):1.0
# ('person', 'would'):0.0625
# ('see', 'dare'):0.04
# ('let', 'charact'):0.16666666666666666
# ('charact', 'tongu'):0.018867924528301886
# ('tongu', 'cheek'):1.0
# ('cheek', 'type'):1.0
# ('type', 'harvey'):1.0
# ('harvey', 'quit'):1.0
# ('quit', 'cameo'):0.09090909090909091
# ('cameo', 'excit'):1.0
# ('movi', 'came'):0.004975124378109453
# ('theater', 'rave'):0.16666666666666666
# ('rave', 'review'):0.5
# ('review', 'even'):0.04
# ('even', 'excit'):0.041666666666666664
# ('excit', 'never'):0.2
# ('never', 'got'):0.1111111111111111
# ('got', 'chanc'):0.14285714285714285
# ('chanc', 'watch'):1.0
# ('watch', 'theater'):0.02631578947368421
# ('theater', 'in'):0.16666666666666666
# ('in', 'glad'):0.125
# ('glad', 'didn'):1.0
# ('didn', 'movi'):0.14285714285714285
# ('movi', '2'):0.004975124378109453
# ('hour', 'felt'):0.1111111111111111
# ('like', '4'):0.017857142857142856
# ('4', 'flat'):1.0
# ('flat', 'bore'):0.3333333333333333
# ('bore', 'plot'):0.058823529411764705
# ('plot', 'liter'):0.05555555555555555
# ('liter', 'noth'):0.3333333333333333
# ('noth', 'happen'):0.14285714285714285
# ('movi', 'mental'):0.004975124378109453
# ('ill', 'insecur'):0.04
# ('insecur', 'man'):1.0
# ('man', 'talk'):0.1111111111111111
# ('talk', 'therapist'):0.2
# ('therapist', 'laugh'):1.0
# ('peopl', 'arthur'):0.023809523809523808
# ('arthur', 'laugh'):0.05555555555555555
# ('laugh', 'terribl'):0.07142857142857142
# ('terribl', 'annoy'):0.25
# ('annoy', 'throughout'):0.3333333333333333
# ('throughout', 'whole'):0.14285714285714285
# ('whole', 'movi'):0.1111111111111111
# ('arthur', 'depth'):0.05555555555555555
# ('depth', 'person'):0.25
# ('person', 'movi'):0.0625
# ('movi', 'bore'):0.004975124378109453
# ('bore', 'start'):0.058823529411764705
# ('start', 'fall'):0.125
# ('fall', 'asleep'):0.2
# ('asleep', 'anyon'):1.0
# ('anyon', 'thing'):0.14285714285714285
# ('movi', 'deep'):0.004975124378109453
# ('deep', 'meaning'):0.2
# ('meaning', 'masterpiec'):1.0
# ('masterpiec', 'clearli'):0.058823529411764705
# ('clearli', 'seen'):0.25
# ('seen', 'move'):0.043478260869565216
# ('move', 'list'):0.029411764705882353
# ('list', 'mani'):0.5
# ('move', 'much'):0.029411764705882353
# ('much', 'move'):0.041666666666666664
# ('move', 'deep'):0.029411764705882353
# ('deep', 'movi'):0.2
# ('tri', 'show'):0.1111111111111111
# ('show', 'villain'):0.07692307692307693
# ('comic', 'distraught'):0.047619047619047616
# ('distraught', 'weak'):1.0
# ('weak', 'man'):0.5
# ('man', 'realiti'):0.1111111111111111
# ('realiti', 'joke'):0.2
# ('comic', 'anyth'):0.047619047619047616
# ('anyth', 'crazi'):0.1111111111111111
# ('crazi', 'compet'):0.14285714285714285
# ('compet', 'master'):1.0
# ('master', '11'):0.3333333333333333
# ('11', 'oscar'):1.0
# ('nomin', 'idiot'):0.2
# ('idiot', 'movi'):1.0
# ('movi', 'anyth'):0.004975124378109453
# ('anyth', 'oscar'):0.1111111111111111
# ('worthi', 'homag'):0.16666666666666666
# ('homag', 'borrow'):1.0
# ('borrow', 'wholesal'):0.5
# ('wholesal', 'materi'):1.0
# ('materi', 'film'):0.5
# ('film', 'littl'):0.014492753623188406
# ('littl', 'make'):0.1111111111111111
# ('make', 'taxi'):0.034482758620689655
# ('driver', 'element'):0.08333333333333333
# ('element', 'notabl'):0.25
# ('notabl', 'end'):0.5
# ('end', 'borrow'):0.09090909090909091
# ('borrow', 'network'):0.5
# ('network', 'case'):0.5
# ('case', 'taxi'):1.0
# ('driver', 'whole'):0.08333333333333333
# ('whole', 'line'):0.1111111111111111
# ('line', 'dialogu'):0.3333333333333333
# ('dialogu', 'charact'):0.25
# ('charact', 'scene'):0.018867924528301886
# ('scene', 'lift'):0.09090909090909091
# ('lift', 'place'):0.5
# ('place', 'movi'):0.5
# ('movi', 'except'):0.004975124378109453
# ('except', 'execut'):0.3333333333333333
# ('execut', 'isn'):0.25
# ('isn', 'polish'):0.125
# ('polish', 'act'):1.0
# ('act', 'calibr'):0.030303030303030304
# ('calibr', 'stori'):1.0
# ('stori', 'origin'):0.034482758620689655
# ('origin', 'watch'):0.07692307692307693
# ('watch', 'taxi'):0.02631578947368421
# ('driver', 'network'):0.08333333333333333
# ('network', 'film'):0.5
# ('film', 'made'):0.014492753623188406
# ('made', '40'):0.05
# ('40', 'year'):1.0
# ('year', 'earlier'):0.09090909090909091
# ('earlier', 'made'):0.5
# ('made', 'better'):0.05
# ('better', 'disturb'):0.045454545454545456
# ('disturb', 'got'):0.1
# ('got', 'movi'):0.14285714285714285
# ('movi', 'humor'):0.004975124378109453
# ('humor', 'much'):0.5
# ('better', 'see'):0.045454545454545456
# ('see', 'first'):0.04
# ('first', 'feel'):0.09090909090909091
# ('feel', 'piti'):0.029411764705882353
# ('piti', 'guy'):0.5
# ('guy', 'suffer'):0.16666666666666666
# ('suffer', 'lack'):0.14285714285714285
# ('lack', 'charm'):0.125
# ('charm', 'well'):1.0
# ('well', 'killer'):0.1111111111111111
# ('killer', 'heath'):1.0
# ('ledger', 'far'):0.05555555555555555
# ('better', 'legendari'):0.045454545454545456
# ('legendari', 'charact'):0.25
# ('charact', 'legendari'):0.018867924528301886
# ('perform', 'actor'):0.02857142857142857
# ('actor', 'abl'):0.07692307692307693
# ('abl', 'move'):0.25
# ('move', 'heath'):0.029411764705882353
# ('ledger', 'perform'):0.05555555555555555
# ('perform', 'movi'):0.02857142857142857
# ('movi', 'total'):0.004975124378109453
# ('total', 'worth'):0.3333333333333333
# ('worth', 'movi'):0.2
# ('movi', 'deserv'):0.004975124378109453
# ('oscar', 'showcas'):0.047619047619047616
# ('showcas', 'never'):0.5
# ('seen', 'origin'):0.043478260869565216
# ('origin', 'joke'):0.07692307692307693
# ('joke', 'love'):0.008

# %% [markdown]
# 1.3 Noun Phrases and relative probabilities of each review in terms of other reviews

# %%
whole_dataset = ''
index = []
i = 1
for line in title_review['After Lemmatization']:
  whole_dataset = whole_dataset + line
  value = 'Review-' + str(i)
  index.append(value)
  i += 1

# %%
from textblob import TextBlob
noun_phrases = []
frequency = []
for line in title_review['After Lemmatization']:
  blob = TextBlob(line)
  for nouns in blob.noun_phrases:
    noun_phrases.append(nouns)
for word in noun_phrases:
  noun_phrases_freq = []
  for line in title_review['After Lemmatization']:
    noun_phrases_freq.append(line.count(word) / whole_dataset.count(word))
  frequency.append(noun_phrases_freq)
noun_phrases_df = pd.DataFrame(frequency).T
noun_phrases_df.columns = list(noun_phrases)
noun_phrases_df.index = index
noun_phrases_df
# Out:
#             everi movi  ...  origin joke
# Review-1           1.0  ...          0.0
# Review-2           0.0  ...          0.0
# Review-3           0.0  ...          0.0
# Review-4           0.0  ...          0.0
# Review-5           0.0  ...          0.0
# ...                ...  ...          ...
# Review-96          0.0  ...          0.0
# Review-97          0.0  ...          0.0
# Review-98          0.0  ...          0.0
# Review-99          0.0  ...          0.0
# Review-100         0.0  ...          1.0
#
# [100 rows x 955 columns]

# %% [markdown]
# # **Question 2: Undersand TF-IDF and Document representation**

# %% [markdown]
# (40 points). Starting from the documents (all the reviews, or abstracts, or tweets) collected for assignment two, write a python program:
#
# (1) To build the **documents-terms weights (tf*idf) matrix bold text**.
#
# (2) To rank the documents with respect to query (design a query by yourself, for example, "An Outstanding movie with a haunting performance and best character development") by using **cosine similarity**.

# %% [markdown]
# 2.1 - TF-IDF

# %%
# Write your code here
import math
def tf_idf_value(sentence,word):
  size = len(sentence.split(" "))
  tf_value = sentence.count(word)/size
  idf_value = 0
  if(tf_value!=0):
    idf_value = math.log(size)/sentence.count(word)
  else:
    return 0;
  return tf_value*idf_value

sentences = title_review["Spelling Correction"].values.tolist()
tokens_list = set([j for i in sentences for j in i.split(" ")])
tf_idf = pd.DataFrame(tokens_list,columns=["token"])
count = 0
for i in sentences:
  tf_idf[str(count)] = tf_idf["token"].apply(lambda x : tf_idf_value(i,x))
  count+=1

tf_idf
# Out:
#            token         0         1  ...        97        98        99
# 0                 0.081918  0.093937  ...  0.086004  0.149787  0.140502
# 1        support  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 2        typical  0.081918  0.000000  ...  0.000000  0.000000  0.000000
# 3          loses  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 4           miss  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# ...          ...       ...       ...  ...       ...       ...       ...
# 2016     proving  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 2017     journey  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 2018     chronic  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 2019   impressed  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 2020  excitement  0.000000  0.000000  ...  0.000000  0.000000  0.000000
#
# [2021 rows x 101 columns]

# %% [markdown]
# 2.2 - Ranking using Cosine Similarity

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

# %%
query_sentence = 'The perfect portrait of a decline to insanity" & Joaquin Phoenix portrays this flawlessly in a performance of a lifetime. Choreographed impeccably by Todd Phillips & is nothing short of breathtaking. The cinematography & backdrop ideology of such an original film for such a complex character is only complimented by the superb soundtrack & acting. A hauntingly beautiful film & A Definate 10/10. Edit: Bring on part 2 plssssss!. We all want it!.'
X_list = word_tokenize(query_sentence)
sw = stopwords.words('english') 
X_set = {w for w in X_list if not w in sw}

# %%
def compute_vector(X_set, Y_set):
  rvector = X_set.union(Y_set)
  l1 =[];l2 =[]
  for w in rvector: 
      if w in X_set: l1.append(1)
      else: l1.append(0) 
      if w in Y_set: l2.append(1) 
      else: l2.append(0)
  return rvector, l1, l2

# %%
def compute_cosine(rvector, l1, l2):
  c = 0
  for i in range(len(rvector)): 
        c+= l1[i]*l2[i] 
  cosine = c / float((sum(l1)*sum(l2))**0.5) 
  return cosine

# %%
similarity_list = []
for sentence in title_review['Spelling Correction']:
  Y_list = word_tokenize(sentence)
  Y_set = {w for w in Y_list if not w in sw}
  rvector, l1, l2 = compute_vector(X_set, Y_set)
  try:
    similarity = compute_cosine(rvector, l1, l2)
  except ZeroDivisionError:
    similarity = 'None'
  similarity_list.append(similarity)
cosine_dataframe = pd.DataFrame(list(zip(title_review['Review'],similarity_list)), columns=['Reviews','Cosine Similarity'])
cosine_dataframe
# Out:
#                                               Reviews Cosine Similarity
# 0   Every once in a while a movie comes, that trul...         0.0434783
# 1   This is a movie that only those who have felt ...         0.0256664
# 2   Truly a masterpiece, The Best Hollywood film o...         0.0761387
# 3   Joaquin Phoenix gives a tour de force performa...         0.0227508
# 4   Most of the time movies are anticipated like t...         0.0230266
# ..                                                ...               ...
# 95  Heath great in dark Knight, even liked Jared L...          0.061938
# 96  I was very excited about this movie when it ca...         0.0345136
# 97  There is doing an homage and then there is bor...          0.073721
# 98  Disturbing. Just got out of the movie. My humo...                 0
# 99  What a legendary character and what a legendar...          0.067651
#
# [100 rows x 2 columns]

# %% [markdown]
# # **Question 3: Create your own training and evaluation data for sentiment analysis**

# %% [markdown]
# (15 points). **You dodn't need to write program for this question!** Read each review (abstract or tweet) you collected in detail, and annotate each review with a sentiment (positive, negative, or neutral). Save the annotated dataset into a csv file with three columns (first column: document_id, clean_text, sentiment), upload the csv file to GitHub and submit the file link blew. This datset will be used for assignment four: sentiment analysis and text classification.

# %%
https://github.com/santhoshjinna15/INFO5731/blob/main/Reviews_Sentimental_Analysis.csv
