# %% [markdown]
# <a href="https://colab.research.google.com/github/santhoshjinna15/INFO5731/blob/main/In_class_exercise_08_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **The eighth in-class-exercise (20 points in total, 3/30/2021)**

# %% [markdown]
# The data for this exercise is from the dataset you created from assignment three. Please perform answer the following questions based on your data:

# %% [markdown]
# Installing  Libraries

# %%
# !pip install polyglot
# Out:
# Collecting polyglot
#   Downloading https://files.pythonhosted.org/packages/e7/98/e24e2489114c5112b083714277204d92d372f5bbe00d5507acf40370edb9/polyglot-16.7.4.tar.gz (126kB)
#      |████████████████████████████████| 133kB 6.5MB/s
# Building wheels for collected packages: polyglot
#   Building wheel for polyglot (setup.py) ... done
#   Created wheel for polyglot: filename=polyglot-16.7.4-py2.py3-none-any.whl size=52557 sha256=7f596d34723b22718901fcfca0663a4b668b85c5de71ec714658f4018c2789f1
#   Stored in directory: /root/.cache/pip/wheels/5e/91/ef/f1369fdc1203b0a9347d4b24f149b83a305f39ab047986d9da
# Successfully built polyglot
# Installing collected packages: polyglot
# Successfully installed polyglot-16.7.4

# %%
# !pip install pyicu
# Out:
# Collecting pyicu
#   Downloading https://files.pythonhosted.org/packages/31/46/fa08c8efae2951e67681ec24319f789fc1a74e2096dd74373e34c79319de/PyICU-2.6.tar.gz (233kB)
#      |████████████████████████████████| 235kB 6.8MB/s
# Building wheels for collected packages: pyicu
#   Building wheel for pyicu (setup.py) ... done
#   Created wheel for pyicu: filename=PyICU-2.6-cp37-cp37m-linux_x86_64.whl size=1306416 sha256=c04dc5dce52088d825bc6d8ac1def177e04446653e14d9e4b87d84c9285ac75d
#   Stored in directory: /root/.cache/pip/wheels/31/21/2f/1c91831e8a93537ab21f6b4b935781b681104635fdb0315791
# Successfully built pyicu
# Installing collected packages: pyicu
# Successfully installed pyicu-2.6

# %%
# !pip install pycld2
# Out:
# Collecting pycld2
#   Downloading https://files.pythonhosted.org/packages/21/d2/8b0def84a53c88d0eb27c67b05269fbd16ad68df8c78849e7b5d65e6aec3/pycld2-0.41.tar.gz (41.4MB)
#      |████████████████████████████████| 41.4MB 100kB/s
# Building wheels for collected packages: pycld2
#   Building wheel for pycld2 (setup.py) ... done
#   Created wheel for pycld2: filename=pycld2-0.41-cp37-cp37m-linux_x86_64.whl size=9834229 sha256=e970cc56271476df05421289048dd4bdb260deffa8fccf5d64c06b6c150a76da
#   Stored in directory: /root/.cache/pip/wheels/c6/8f/e9/08a1a8932a490175bd140206cd86a3dbcfc70498100de11079
# Successfully built pycld2
# Installing collected packages: pycld2
# Successfully installed pycld2-0.41

# %%
# !pip install morfessor
# Out:
# Collecting morfessor
#   Downloading https://files.pythonhosted.org/packages/39/e6/7afea30be2ee4d29ce9de0fa53acbb033163615f849515c0b1956ad074ee/Morfessor-2.0.6-py3-none-any.whl
# Installing collected packages: morfessor
# Successfully installed morfessor-2.0.6

# %%
# %%bash
# polyglot download sentiment2.en
# Out:
# [polyglot_data] Downloading package sentiment2.en to
# [polyglot_data]     /root/polyglot_data...

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# ## (1) (10 points) Write a python program to extract the sentiment related terms from the corpus. You may use python package such as polyglot or external lexicon resources in the question. Rank the sentiment related terms by frequency.

# %%
# Write your code here

import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/santhoshjinna15/INFO5731/main/Reviews_Sentimental_Analysis.csv')
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
from nltk.corpus import stopwords
from textblob import TextBlob
df['Review'] = df['Review'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['Review'] = df['Review'].str.replace('[^\w\s]','')
stop = stopwords.words('english')
df['Review'] = df['Review'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['Review'] = df['Review'].apply(lambda x: str(TextBlob(x).correct()))

# %%
from polyglot.text import Text
sentimental_words = []
for line in df['Review']:
  text = Text(line)
  for i in text.words:
    if i.polarity != 0:
      sentimental_words.append(i)
sentimental_words
# Out:
# ['brilliance',
#  'grotesque',
#  'hard',
#  'mesmerizing',
#  'tragic',
#  'funny',
#  'rollercoaster',
#  'proper',
#  'best',
#  'isolated',
#  'sorry',
#  'encourage',
#  'better',
#  'respect',
#  'like',
#  'isolated',
#  'masterpiece',
#  'best',
#  'best',
#  'best',
#  'willingly',
#  'remarkable',
#  'disturbing',
#  'violent',
#  'proving',
#  'corruption',
#  'rich',
#  'talented',
#  'believable',
#  'shake',
#  'bitter',
#  'comforting',
#  'perfect',
#  'fearless',
#  'stunning',
#  'impossible',
#  'dark',
#  'joke',
#  'stunned',
#  'accomplished',
#  'impossible',
#  'exceeds',
#  'dark',
#  'crime',
#  'like',
#  'falling',
#  'joke',
#  'happy',
#  'ignore',
#  'complaints',
#  'pernicious',
#  'embarrassing',
#  'better',
#  'criminal',
#  'dark',
#  'joke',
#  'dark',
#  'fall',
#  'love',
#  'bad',
#  'romantic',
#  'scars',
#  'amazing',
#  'best',
#  'breathtaking',
#  'uncomfortable',
#  'like',
#  'horrible',
#  'great',
#  'inspiration',
#  'honest',
#  'violent',
#  'disturbing',
#  'violent',
#  'controversy',
#  'great',
#  'best',
#  'hate',
#  'madness',
#  'enjoy',
#  'masterpiece',
#  'amazing',
#  'enjoy',
#  'joke',
#  'inflated',
#  'trouble',
#  'lead',
#  'delay',
#  'worth',
#  'joke',
#  'blockbuster',
#  'slowly',
#  'wonderful',
#  'scars',
#  'joke',
#  'good',
#  'joke',
#  'rational',
#  'insane',
#  'insane',
#  'joke',
#  'superior',
#  'dark',
#  'joke',
#  'good',
#  'appreciated',
#  'oppressive',
#  'modern',
#  'eager',
#  'best',
#  'worst',
#  'convincing',
#  'sad',
#  'missed',
#  'confident',
#  'win',
#  'joke',
#  'damn',
#  'interesting',
#  'plot',
#  'damn',
#  'enjoy',
#  'disturb',
#  'best',
#  'dark',
#  'thrilled',
#  'morality',
#  'poor',
#  'joke',
#  'joke',
#  'reliable',
#  'realistic',
#  'bad',
#  'bad',
#  'important',
#  'joke',
#  'threat',
#  'bad',
#  'suitable',
#  'willing',
#  'good',
#  'best',
#  'painful',
#  'good',
#  'triumph',
#  'win',
#  'wasteful',
#  'joke',
#  'awesome',
#  'awesome',
#  'easy',
#  'cruel',
#  'decline',
#  'wasteful',
#  'loose',
#  'joke',
#  'disturbed',
#  'right',
#  'awarded',
#  'critic',
#  'critics',
#  'critic',
#  'wrong',
#  'super',
#  'hero',
#  'masterpiece',
#  'boredom',
#  'fear',
#  'genius',
#  'master',
#  'win',
#  'feasible',
#  'fair',
#  'genius',
#  'good',
#  'amazing',
#  'good',
#  'masterpiece',
#  'dislike',
#  'good',
#  'amazing',
#  'praise',
#  'joke',
#  'classic',
#  'decent',
#  'outstanding',
#  'like',
#  'best',
#  'like',
#  'good',
#  'good',
#  'good',
#  'nice',
#  'plot',
#  'intriguing',
#  'boring',
#  'crime',
#  'thrilled',
#  'thrilled',
#  'miss',
#  'plot',
#  'crazy',
#  'evil',
#  'destroy',
#  'intriguing',
#  'plot',
#  'enough',
#  'worthy',
#  'amazing',
#  'excited',
#  'hollow',
#  'masterpiece',
#  'excellent',
#  'incredible',
#  'bland',
#  'plot',
#  'relief',
#  'harsh',
#  'falls',
#  'good',
#  'great',
#  'incredible',
#  'plot',
#  'great',
#  'plot',
#  'best',
#  'downside',
#  'joke',
#  'pure',
#  'brilliance',
#  'joke',
#  'steal',
#  'better',
#  'smarter',
#  'hate',
#  'break',
#  'intelligent',
#  'better',
#  'suspect',
#  'perfect',
#  'safe',
#  'like',
#  'exciting',
#  'best',
#  'talented',
#  'joke',
#  'neglect',
#  'uncomfortable',
#  'unfortunately',
#  'important',
#  'like',
#  'inequality',
#  'like',
#  'smile',
#  'hot',
#  'plot',
#  'twist',
#  'twists',
#  'impressed',
#  'shocked',
#  'unnecessary',
#  'interesting',
#  'wrong',
#  'problem',
#  'great',
#  'sorry',
#  'illness',
#  'modern',
#  'perfection',
#  'intense',
#  'perfect',
#  'like',
#  'joke',
#  'joke',
#  'perfect',
#  'important',
#  'perfect',
#  'shocking',
#  'loved',
#  'bored',
#  'amazing',
#  'good',
#  'joke',
#  'good',
#  'raving',
#  'mad',
#  'boring',
#  'bored',
#  'regret',
#  'confused',
#  'right',
#  'good',
#  'great',
#  'joke',
#  'good',
#  'best',
#  'good',
#  'bad',
#  'worse',
#  'hate',
#  'breaking',
#  'killer',
#  'scare',
#  'threatening',
#  'depressing',
#  'joke',
#  'entertaining',
#  'dark',
#  'doubt',
#  'skinny',
#  'lonely',
#  'hail',
#  'hero',
#  'inspiration',
#  'joke',
#  'brilliant',
#  'manipulate',
#  'charming',
#  'confidence',
#  'joke',
#  'dumb',
#  'depressing',
#  'insecure',
#  'joke',
#  'dark',
#  'joke',
#  'fun',
#  'great',
#  'optimism',
#  'slow',
#  'miserable',
#  'insane',
#  'insane',
#  'enough',
#  'doubt',
#  'joke',
#  'love',
#  'joke',
#  'joke',
#  'awful',
#  'good',
#  'disturbed',
#  'good',
#  'dark',
#  'gritty',
#  'super',
#  'hero',
#  'perfect',
#  'decline',
#  'insanity',
#  'breathtaking',
#  'complex',
#  'superb',
#  'beautiful',
#  'joke',
#  'amazing',
#  'brilliant',
#  'best',
#  'joke',
#  'dignity',
#  'respect',
#  'good',
#  'like',
#  'frustrated',
#  'amazing',
#  'brilliant',
#  'magnificent',
#  'safe',
#  'joke',
#  'gritty',
#  'insanely',
#  'dark',
#  'disturbing',
#  'terrible',
#  'refused',
#  'proper',
#  'greatest',
#  'like',
#  'dark',
#  'wise',
#  'betrayal',
#  'joke',
#  'better',
#  'greatest',
#  'like',
#  'dark',
#  'inevitable',
#  'better',
#  'joke',
#  'joke',
#  'fortunate',
#  'greatest',
#  'top',
#  'scars',
#  'best',
#  'loses',
#  'joke',
#  'liked',
#  'like',
#  'fall',
#  'problem',
#  'hated',
#  'masterpiece',
#  'worthy',
#  'enjoy',
#  'slow',
#  'joke',
#  'crazy',
#  'lame',
#  'stunned',
#  'right',
#  'hell',
#  'unstable',
#  'ironic',
#  'joke',
#  'accurate',
#  'realistic',
#  'dark',
#  'disturbing',
#  'led',
#  'worthy',
#  'bad',
#  'heartbreaking',
#  'inevitably',
#  'crime',
#  'love',
#  'like',
#  'suffer',
#  'better',
#  'missed',
#  'joke',
#  'helped',
#  'great',
#  'great',
#  'great',
#  'plot',
#  'brilliant',
#  'super',
#  'great',
#  'joke',
#  'joke',
#  'best',
#  'worthy',
#  'best',
#  'unbelievable',
#  'better',
#  'win',
#  'best',
#  'joke',
#  'win',
#  'best',
#  'snub',
#  'joke',
#  'great',
#  'suffering',
#  'issues',
#  'neglect',
#  'madness',
#  'accurate',
#  'fresh',
#  'crime',
#  'realistic',
#  'amazing',
#  'joke',
#  'joke',
#  'accurate',
#  'decent',
#  'joke',
#  'great',
#  'plot',
#  'interesting',
#  'believable',
#  'impressively',
#  'splendid',
#  'outstanding',
#  'lack',
#  'positive',
#  'lead',
#  'tough',
#  'positive',
#  'nice',
#  'positive',
#  'joke',
#  'misunderstood',
#  'inspire',
#  'crime',
#  'hard',
#  'joke',
#  'misery',
#  'suffer',
#  'racism',
#  'hate',
#  'neglect',
#  'worse',
#  'like',
#  'clearly',
#  'progressive',
#  'intense',
#  'joke',
#  'joke',
#  'bad',
#  'boring',
#  'slow',
#  'perfection',
#  'good',
#  'bad',
#  'greatest',
#  'best',
#  'breaks',
#  'winning',
#  'slow',
#  'joke',
#  'chaos',
#  'amazing',
#  'deserving',
#  'perfect',
#  'harmony',
#  'controversy',
#  'perfect',
#  'pity',
#  'appreciate',
#  'marvel',
#  'like',
#  'marvel',
#  'better',
#  'trash',
#  'joke',
#  'favorite',
#  'appreciate',
#  'appreciate',
#  'wild',
#  'waste',
#  'happy',
#  'good',
#  'boring',
#  'like',
#  'joke',
#  'incredible',
#  'motionless',
#  'awe',
#  'troubled',
#  'monster',
#  'like',
#  'wasteful',
#  'merry',
#  'ignore',
#  'ignore',
#  'work',
#  'right',
#  'slow',
#  'killing',
#  'dreadful',
#  'joke',
#  'joke',
#  'trusting',
#  'disappointed',
#  'convincing',
#  'like',
#  'brutal',
#  'enjoyed',
#  'bad',
#  'bad',
#  'chaos',
#  'anarchy',
#  'killed',
#  'stupid',
#  'brutally',
#  'brutal',
#  'boring',
#  'masterpiece',
#  'best',
#  'illness',
#  'illness',
#  'creative',
#  'suffering',
#  'refuse',
#  'wrong',
#  'joke',
#  'success',
#  'joke',
#  'suave',
#  'witty',
#  'lethal',
#  'gimmicks',
#  'morbid',
#  'anarchist',
#  'criminal',
#  'illness',
#  'problems',
#  'illness',
#  'sufferer',
#  'inappropriate',
#  'subjected',
#  'injustice',
#  'indignation',
#  'murder',
#  'mystery',
#  'achievement',
#  'positive',
#  'fairly',
#  'confident',
#  'plot',
#  'engaging',
#  'monotony',
#  'shallow',
#  'right',
#  'like',
#  'recoil',
#  'emaciated',
#  'burn',
#  'wonder',
#  'positive',
#  'imperfections',
#  'like',
#  'interesting',
#  'joke',
#  'dark',
#  'joke',
#  'joke',
#  'butcher',
#  'joke',
#  'joke',
#  'achievement',
#  'doubt',
#  'best',
#  'joke',
#  'beautiful',
#  'greatness',
#  'smiling',
#  'sucks',
#  'important',
#  'good',
#  'joke',
#  'troubled',
#  'frustration',
#  'trash',
#  'right',
#  'better',
#  'wrong',
#  'well',
#  'extraordinary',
#  'excellent',
#  'boring',
#  'disturbing',
#  'lacks',
#  'excitement',
#  'excellent',
#  'like',
#  'good',
#  'bad',
#  'vent',
#  'masterpiece',
#  'dark',
#  'best',
#  'critics',
#  'lost',
#  'favor',
#  'good',
#  'creative',
#  'joke',
#  'lie',
#  'joke',
#  'amazing',
#  'great',
#  'boring',
#  'lacks',
#  'plot',
#  'twist',
#  'crazy',
#  'suffers',
#  'illness',
#  'loves',
#  'sad',
#  'kills',
#  'like',
#  'better',
#  'masterpiece',
#  'top',
#  'good',
#  'bad',
#  'joke',
#  'great',
#  'thank',
#  'love',
#  'love',
#  'like',
#  'good',
#  'break',
#  'like',
#  'tormented',
#  'unstable',
#  'loses',
#  'torment',
#  'hell',
#  'breaks',
#  'loose',
#  'difficult',
#  'good',
#  'plot',
#  'like',
#  'plot',
#  'awfully',
#  'happy',
#  'liked',
#  'worked',
#  'incredibly',
#  'terrible',
#  'slowly',
#  'joke',
#  'joke',
#  'worth',
#  'good',
#  'well',
#  'joke',
#  'crazy',
#  'suitable',
#  'joke',
#  'realistic',
#  'sane',
#  'sick',
#  'gruesome',
#  'joke',
#  'proper',
#  'joke',
#  'clear',
#  'support',
#  'mess',
#  'like',
#  'proper',
#  'support',
#  'joke',
#  'good',
#  'vice',
#  'like',
#  'bad',
#  'well',
#  'slow',
#  'worth',
#  'controversy',
#  'violent',
#  'right',
#  'violent',
#  'violent',
#  'nonsense',
#  'wrong',
#  'ruin',
#  'better',
#  'dark',
#  'great',
#  'joke',
#  'good',
#  'bad',
#  'ugly',
#  'inspiring',
#  'gold',
#  'joke',
#  'engaging',
#  'believable',
#  'dark',
#  'depression',
#  'optimistic',
#  'shallow',
#  'rich',
#  'impressively',
#  'great',
#  'lead',
#  'proper',
#  'inappropriate',
#  'painful',
#  'outcry',
#  'hurt',
#  'deprived',
#  'injustice',
#  'well',
#  'supporting',
#  'worthy',
#  'award',
#  'believable',
#  'realistic',
#  'extraordinary',
#  'skill',
#  'joke',
#  'disappointment',
#  'like',
#  'fool',
#  'good',
#  'stupid',
#  'humor',
#  'like',
#  'stiff',
#  'joke',
#  'best',
#  'joke',
#  'complains',
#  'killing',
#  'silly',
#  'critics',
#  'happy',
#  'lucky',
#  'happy',
#  'dark',
#  'like',
#  'marvel',
#  'best',
#  'best',
#  'profound',
#  'dark',
#  'ridiculous',
#  'boring',
#  'worse',
#  'bad',
#  'marvel',
#  'like',
#  'love',
#  'hate',
#  'joke',
#  'intriguing',
#  'mysterious',
#  'enough',
#  'lose',
#  'like',
#  'dark',
#  'bored',
#  'hell',
#  'killer',
#  'muddy',
#  'annoy',
#  'worse',
#  'beautiful',
#  'tragedy',
#  'pretty',
#  'dark',
#  'funny',
#  'wrong',
#  'worth',
#  'best',
#  'joke',
#  'impressive',
#  'good',
#  'like',
#  'great',
#  'good',
#  'best',
#  'love',
#  'amazing',
#  'work',
#  'enjoyable',
#  'superb',
#  'joke',
#  'happy',
#  'award',
#  'well',
#  'work',
#  'joke',
#  'difficult',
#  'struggles',
#  'illness',
#  'lead',
#  'good',
#  'horrible',
#  'dark',
#  'entertaining',
#  'joke',
#  'love',
#  'joke',
#  'likes',
#  'dark',
#  'plot',
#  'amazing',
#  'interesting',
#  'like',
#  'boring',
#  'like',
#  'breaking',
#  'beautiful',
#  'joke',
#  'amazingly',
#  'perfect',
#  'enjoyed',
#  'perfect',
#  'enjoyed',
#  'best',
#  'dark',
#  'beautiful',
#  'sad',
#  'scar',
#  'missed',
#  'great',
#  'classic',
#  'best',
#  'win',
#  'shock',
#  'well',
#  'darkness',
#  'rejected',
#  'rejected',
#  'smiles',
#  'best',
#  'wrong',
#  'scars',
#  'safe',
#  'good',
#  'favorite',
#  'fat',
#  'like',
#  'right',
#  'understandable',
#  'like',
#  'marvel',
#  'uncomfortable',
#  'like',
#  'bad',
#  'wrong',
#  'broken',
#  'prejudice',
#  'praise',
#  'well',
#  'important',
#  'bloody',
#  'intense',
#  'like',
#  'missed',
#  'interesting',
#  'wonder',
#  'award',
#  'masterpiece',
#  'wrong',
#  'like',
#  'worst',
#  'great',
#  'good',
#  'like',
#  'worth',
#  'great',
#  'guarantee',
#  'waste',
#  'brilliant',
#  'masterpiece',
#  'boring',
#  'like',
#  'modern',
#  'great',
#  'well',
#  'easy',
#  'good',
#  'dark',
#  'slow',
#  'good',
#  'slow',
#  'poorly',
#  'joke',
#  'reliable',
#  'weak',
#  'outstanding',
#  'inevitably',
#  'exceptional',
#  'strong',
#  'impressive',
#  'thank',
#  'brutal',
#  'lack',
#  'love',
#  'brutally',
#  'warmth',
#  'violent',
#  'peace',
#  'stunning',
#  'work',
#  'exceeded',
#  'worthy',
#  'joke',
#  'like',
#  'interesting',
#  'like',
#  'masterpiece',
#  'groundbreaking',
#  'joke',
#  'successfully',
#  'hollow',
#  'joke',
#  'joke',
#  'fails',
#  'suitable',
#  'talented',
#  'dangerous',
#  'unstable',
#  'like',
#  'accurate',
#  'irrelevant',
#  'good',
#  'masterpiece',
#  'fails',
#  'inaccurate',
#  'poor',
#  'lacks',
#  'good',
#  'poor',
#  'hard',
#  'realistic',
#  'unnecessary',
#  ...]

# %% [markdown]
# Ranking by Frequency

# %%
from collections import Counter
frequencies = Counter(sentimental_words)
rank_df = pd.DataFrame(list(frequencies.most_common()), columns=['Words', 'Frequencies'])
rank_df.index = list(range(1, len(frequencies.most_common())+1))
rank_df
# Out:
#           Words  Frequencies
# 1          joke          135
# 2          like           61
# 3          good           53
# 4          best           40
# 5          dark           33
# ..          ...          ...
# 467         cry            1
# 468   marvelous            1
# 469   tolerable            1
# 470  pleasantly            1
# 471     anguish            1
#
# [471 rows x 2 columns]

# %% [markdown]
# ## (2) (10 points) Compare the performance of the following tools in sentiment identification: TextBlob (https://textblob.readthedocs.io/en/dev/), VADER (https://github.com/cjhutto/vaderSentiment), TFIDF-based Support Vector Machine (SVM) (Split your data into training and testing data). Take your own annotation as the standard answers.
#
# Reference code: https://towardsdatascience.com/fine-grained-sentiment-analysis-in-python-part-1-2697bb111ed4

# %%
# Write your code here
def Encoder(senti):
  sentiment_encoded = 0
  if senti == 'Positive':
    sentiment_encoded = 1
  elif senti == 'Negative':
    sentiment_encoded = 2
  return sentiment_encoded

# %%
actual_sentiment = []
for senti in df['Sentimental Analysis']:
  actual_sentiment.append(Encoder(senti))

# %% [markdown]
# Sentimental Analysis usig Text Blob

# %%
from textblob import TextBlob
textblob_sentiments = []
for line in df['Review']:
  polarity = TextBlob(line).sentiment.polarity
  if polarity > 0:
    textblob_sentiments.append(1)
  elif polarity < 0:
    textblob_sentiments.append(2)
  elif polarity == 0.0:
    textblob_sentiments.append(0)
text_blob_df = pd.DataFrame(list(zip(df['Review'], actual_sentiment, textblob_sentiments)), columns = ['Reviews', 'Actual', 'Predicted'])
text_blob_df
# Out:
#                                                Reviews  Actual  Predicted
# 0    every movie comes truly makes impact joaquins ...       1          2
# 1    movie felt alone isolated truly relate underst...       1          0
# 2    truly masterpiece best hollywood film 2019 one...       1          1
# 3    joaquin phoenix gives tour de force performanc...       0          2
# 4    time moves anticipated like end falling short ...       2          1
# ..                                                 ...     ...        ...
# 103  truly masterpiece best hollywood film 2019 one...       1          1
# 104  acting cinematography sound design script phen...       1          2
# 105  plan watching would suggest shipping last 20 3...       2          2
# 106  want title make wouldn know based comicbook ch...       1          1
# 107  now movie admit first heard joaquin phoenix go...       1          1
#
# [108 rows x 3 columns]

# %%
from sklearn.metrics import f1_score, accuracy_score
text_blob_accuracy = accuracy_score(text_blob_df['Actual'], text_blob_df['Predicted'])*100
text_blob_f1_score = f1_score(text_blob_df['Actual'], text_blob_df['Predicted'], average = 'macro')
print("Text Blob Accuracy is {0} and F1 Score is {1}".format(text_blob_accuracy, text_blob_f1_score))
# Out:
# Text Blob Accuracy is 56.481481481481474 and F1 Score is 0.399400871459695

# %% [markdown]
# Sentimental Analysis using Vader

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
vader = SentimentIntensityAnalyzer()
vader_sentiments = []
for line in df['Review']:
  polarity = vader.polarity_scores(line)['compound']
  if polarity > 0:
    vader_sentiments.append(1)
  elif polarity < 0:
    vader_sentiments.append(2)
  elif polarity == 0.0:
    vader_sentiments.append(0)
vader_df = pd.DataFrame(list(zip(df['Review'], actual_sentiment, vader_sentiments)), columns = ['Reviews', 'Actual', 'Predicted'])
vader_df
# Out:
# /usr/local/lib/python3.7/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "
#                                                Reviews  Actual  Predicted
# 0    every movie comes truly makes impact joaquins ...       1          1
# 1    movie felt alone isolated truly relate underst...       1          1
# 2    truly masterpiece best hollywood film 2019 one...       1          1
# 3    joaquin phoenix gives tour de force performanc...       0          1
# 4    time moves anticipated like end falling short ...       2          1
# ..                                                 ...     ...        ...
# 103  truly masterpiece best hollywood film 2019 one...       1          1
# 104  acting cinematography sound design script phen...       1          1
# 105  plan watching would suggest shipping last 20 3...       2          1
# 106  want title make wouldn know based comicbook ch...       1          2
# 107  now movie admit first heard joaquin phoenix go...       1          1
#
# [108 rows x 3 columns]

# %%
from sklearn.metrics import f1_score, accuracy_score
vader_accuracy = accuracy_score(vader_df['Actual'], vader_df['Predicted'])*100
vader_f1_score = f1_score(vader_df['Actual'], vader_df['Predicted'], average = 'macro')
print("Vader Accuracy is {0} and F1 Score is {1}".format(vader_accuracy, vader_f1_score))
# Out:
# Vader Accuracy is 58.333333333333336 and F1 Score is 0.3673289183222958

# %% [markdown]
# Sentimenatl Analysis using SVM

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
TFid_vectorizer = TfidfVectorizer(min_df = 5,
                             max_df = 0.8,
                             sublinear_tf = True,
                             use_idf = True)

# %%
Train_X, Test_X, Train_Y, Test_Y = train_test_split(df['Review'],df['Sentimental Analysis'],test_size=0.33)
Encoder = LabelEncoder()
Train_Y = Encoder.fit_transform(Train_Y)
Test_Y = Encoder.fit_transform(Test_Y)
Train_X_vectors = TFid_vectorizer.fit_transform(Train_X)
Test_X_vectors = TFid_vectorizer.transform(Test_X)

# %%
from sklearn import svm
from sklearn.metrics import classification_report
svm_model = svm.SVC(kernel='linear')
svm_model.fit(Train_X_vectors, Train_Y)
predicted = svm_model.predict(Test_X_vectors)
report = classification_report(Test_Y, predicted, output_dict=True)
report
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'0': {'f1-score': 0.28571428571428575,
#   'precision': 0.3333333333333333,
#   'recall': 0.25,
#   'support': 8},
#  '1': {'f1-score': 0.0, 'precision': 0.0, 'recall': 0.0, 'support': 4},
#  '2': {'f1-score': 0.7407407407407408,
#   'precision': 0.6666666666666666,
#   'recall': 0.8333333333333334,
#   'support': 24},
#  'accuracy': 0.6111111111111112,
#  'macro avg': {'f1-score': 0.34215167548500885,
#   'precision': 0.3333333333333333,
#   'recall': 0.36111111111111116,
#   'support': 36},
#  'weighted avg': {'f1-score': 0.5573192239858906,
#   'precision': 0.5185185185185186,
#   'recall': 0.6111111111111112,
#   'support': 36}}

# %% [markdown]
# ---

# %% [markdown]
#                              Accuracy   F1 Score
#               Text Blob     56.48       39.94
#               Vader         58          36.74
#               SVM           58.33       42.11

# %% [markdown]
# SVM has the best F1-score, followed by Text Blob and Vader. SVM is better compared to Text Blob, and Vader is better to both.
