# %% [markdown]
# <a href="https://colab.research.google.com/github/santhoshjinna15/INFO5731/blob/main/In_class_exercise_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The fifth In-class-exercise (2/23/2021, 20 points in total)

# %% [markdown]
# In exercise-03, I asked you to collected 500 textual data based on your own information needs (If you didn't collect the textual data, you should recollect for this exercise). Now we need to think about how to represent the textual data for text classification. In this exercise, you are required to select 10 types of features (10 types of features but absolutely more than 10 features) in the followings feature list, then represent the 500 texts with these features. The output should be in the following format:
# ![image.png](attachment:image.png)
#
# The feature list:
#
# * (1) tf-idf features
# * (2) POS-tag features: number of adjective, adverb, auxiliary, punctuation, complementizer, coordinating conjunction, subordinating conjunction, determiner, interjection, noun, possessor, preposition, pronoun, quantifier, verb, and other. (select some of them if you use pos-tag features)
# * (3) Linguistic features:
#   * number of right-branching nodes across all constituent types
#   * number of right-branching nodes for NPs only
#   * number of left-branching nodes across all constituent types
#   * number of left-branching nodes for NPs only
#   * number of premodifiers across all constituent types
#   * number of premodifiers within NPs only
#   * number of postmodifiers across all constituent types
#   * number of postmodifiers within NPs only
#   * branching index across all constituent types, i.e. the number of right-branching nodes minus number of left-branching nodes
#   * branching index for NPs only
#   * branching weight index: number of tokens covered by right-branching nodes minus number of tokens covered by left-branching nodes across all categories
#   * branching weight index for NPs only
#   * modification index, i.e. the number of premodifiers minus the number of postmodifiers across all categories
#   * modification index for NPs only
#   * modification weight index: length in tokens of all premodifiers minus length in tokens of all postmodifiers across all categories
#   * modification weight index for NPs only
#   * coordination balance, i.e. the maximal length difference in coordinated constituents
#
#   * density (density can be calculated using the ratio of folowing function words to content words) of determiners/quantifiers
#   * density of pronouns
#   * density of prepositions
#   * density of punctuation marks, specifically commas and semicolons
#   * density of auxiliary verbs
#   * density of conjunctions
#   * density of different pronoun types: Wh, 1st, 2nd, and 3rd person pronouns
#
#   * maximal and average NP length
#   * maximal and average AJP length
#   * maximal and average PP length
#   * maximal and average AVP length
#   * sentence length
#
# * Other features in your mind (ie., pre-defined patterns)

# %% [markdown]
# Extracting Data

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
main_text = [] # List to store Review headings
sub_text =[] #List to store reviews
sub_rating=[]#List to store ratings
for number in range(60):
  link = "https://www.flipkart.com/boat-aavante-bar-1150-60-w-bluetooth-soundbar/product-reviews/itm1fe41ecae973b?pid=ACCFH425PNGFUHAU&lid=LSTACCFH425PNGFUHAUROM019&marketplace=FLIPKART&page=" + str(number) # Generating link dynamically
 # print(link)
  page = requests.get(link) # Accessing the webpage
  soup = BeautifulSoup(page.text, 'html.parser')
  main_reviews = soup.find_all(class_='_2-N8zT') # Getting the Review Heading by using the class name
  text_reviews = soup.find_all(class_='t-ZTKy') # Getting the full reviews by using the class name
  rating       = soup.find_all(class_='_3LWZlK _1BLPMq')
  for ele, sub_ele,sub_in_ele in zip(main_reviews, text_reviews,rating) : # Iterating through the list
      main_text.append(ele.text) #Appending to empty list
      sub_text.append(sub_ele.text)
      sub_rating.append(sub_in_ele.text)
df = pd.DataFrame(list(zip(main_text, sub_text,sub_rating)), columns =['Glimpse of Review', 'Full Review','Rating'])  # Creating Dataframe
print("Length of data frame is {0}".format(len(df)))
df
# Out:
# Length of data frame is 536
#          Glimpse of Review  ... Rating
# 0                Wonderful  ...      4
# 1        Worth every penny  ...      5
# 2                  Awesome  ...      5
# 3           Master Blaster  ...      4
# 4                Very Good  ...      4
# ..                     ...  ...    ...
# 531          Great product  ...      5
# 532                 Super!  ...      5
# 533              Fabulous!  ...      5
# 534  Mind-blowing purchase  ...      5
# 535         Simply awesome  ...      5
#
# [536 rows x 3 columns]

# %% [markdown]
# Preprocessing Data
#
# Converting to lower case

# %%
df['After Preprocessing'] = df['Full Review'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df
# Out:
#          Glimpse of Review  ...                                After Preprocessing
# 0                Wonderful  ...  sound is really good , even without sub woofer...
# 1        Worth every penny  ...  excellent product, nice sound quality, preset ...
# 2                  Awesome  ...  best brand, built quality is very good, no mor...
# 3           Master Blaster  ...  using it since last 6 days :pros :1) stylish l...
# 4                Very Good  ...  writing this review after using it 7 days ..ov...
# ..                     ...  ...                                                ...
# 531          Great product  ...  best speaker for small room,the audio is so cl...
# 532                 Super!  ...         worthy product and stylish designread more
# 533              Fabulous!  ...              overall this product amazingread more
# 534  Mind-blowing purchase  ...          value for money and satisfactionread more
# 535         Simply awesome  ...           good sound and quality...thanksread more
#
# [536 rows x 4 columns]

# %% [markdown]
# Removing Punctuation

# %%
df['After Preprocessing'] = df['After Preprocessing'].str.replace('[^\w\s]','')
df
# Out:
#          Glimpse of Review  ...                                After Preprocessing
# 0                Wonderful  ...  sound is really good  even without sub woofer ...
# 1        Worth every penny  ...  excellent product nice sound quality preset so...
# 2                  Awesome  ...  best brand built quality is very good no more ...
# 3           Master Blaster  ...  using it since last 6 days pros 1 stylish look...
# 4                Very Good  ...  writing this review after using it 7 days over...
# ..                     ...  ...                                                ...
# 531          Great product  ...  best speaker for small roomthe audio is so cle...
# 532                 Super!  ...         worthy product and stylish designread more
# 533              Fabulous!  ...              overall this product amazingread more
# 534  Mind-blowing purchase  ...          value for money and satisfactionread more
# 535         Simply awesome  ...              good sound and qualitythanksread more
#
# [536 rows x 4 columns]

# %% [markdown]
# Removing Numerics

# %%
df['After Preprocessing'] = df['After Preprocessing'].apply(lambda x: ''.join([i for i in x if not i.isdigit()]))
df
# Out:
#          Glimpse of Review  ...                                After Preprocessing
# 0                Wonderful  ...  sound is really good  even without sub woofer ...
# 1        Worth every penny  ...  excellent product nice sound quality preset so...
# 2                  Awesome  ...  best brand built quality is very good no more ...
# 3           Master Blaster  ...  using it since last  days pros  stylish look a...
# 4                Very Good  ...  writing this review after using it  days overa...
# ..                     ...  ...                                                ...
# 531          Great product  ...  best speaker for small roomthe audio is so cle...
# 532                 Super!  ...         worthy product and stylish designread more
# 533              Fabulous!  ...              overall this product amazingread more
# 534  Mind-blowing purchase  ...          value for money and satisfactionread more
# 535         Simply awesome  ...              good sound and qualitythanksread more
#
# [536 rows x 4 columns]

# %% [markdown]
# Removing Special Characters

# %%
import re
df['After Preprocessing'] = df['After Preprocessing'].apply(lambda x: ''.join(re.sub(r"[^a-zA-Z0-9]+", ' ', charctr) for charctr in x ))
df
# Out:
#          Glimpse of Review  ...                                After Preprocessing
# 0                Wonderful  ...  sound is really good  even without sub woofer ...
# 1        Worth every penny  ...  excellent product nice sound quality preset so...
# 2                  Awesome  ...  best brand built quality is very good no more ...
# 3           Master Blaster  ...  using it since last  days pros  stylish look a...
# 4                Very Good  ...  writing this review after using it  days overa...
# ..                     ...  ...                                                ...
# 531          Great product  ...  best speaker for small roomthe audio is so cle...
# 532                 Super!  ...         worthy product and stylish designread more
# 533              Fabulous!  ...              overall this product amazingread more
# 534  Mind-blowing purchase  ...          value for money and satisfactionread more
# 535         Simply awesome  ...              good sound and qualitythanksread more
#
# [536 rows x 4 columns]

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
#     Downloading collection 'all'
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package alpino to /root/nltk_data...
#        |   Unzipping corpora/alpino.zip.
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Unzipping corpora/biocreative_ppi.zip.
#        | Downloading package brown to /root/nltk_data...
#        |   Unzipping corpora/brown.zip.
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Unzipping corpora/brown_tei.zip.
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Unzipping corpora/cess_cat.zip.
#        | Downloading package cess_esp to /root/nltk_data...
#        |   Unzipping corpora/cess_esp.zip.
#        | Downloading package chat80 to /root/nltk_data...
#        |   Unzipping corpora/chat80.zip.
#        | Downloading package city_database to /root/nltk_data...
#        |   Unzipping corpora/city_database.zip.
#        | Downloading package cmudict to /root/nltk_data...
#        |   Unzipping corpora/cmudict.zip.
#        | Downloading package comparative_sentences to
#        |     /root/nltk_data...
#        |   Unzipping corpora/comparative_sentences.zip.
#        | Downloading package comtrans to /root/nltk_data...
#        | Downloading package conll2000 to /root/nltk_data...
#        |   Unzipping corpora/conll2000.zip.
#        | Downloading package conll2002 to /root/nltk_data...
#        |   Unzipping corpora/conll2002.zip.
#        | Downloading package conll2007 to /root/nltk_data...
#        | Downloading package crubadan to /root/nltk_data...
#        |   Unzipping corpora/crubadan.zip.
#        | Downloading package dependency_treebank to /root/nltk_data...
#        |   Unzipping corpora/dependency_treebank.zip.
#        | Downloading package dolch to /root/nltk_data...
#        |   Unzipping corpora/dolch.zip.
#        | Downloading package europarl_raw to /root/nltk_data...
#        |   Unzipping corpora/europarl_raw.zip.
#        | Downloading package floresta to /root/nltk_data...
#        |   Unzipping corpora/floresta.zip.
#        | Downloading package framenet_v15 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v15.zip.
#        | Downloading package framenet_v17 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v17.zip.
#        | Downloading package gazetteers to /root/nltk_data...
#        |   Unzipping corpora/gazetteers.zip.
#        | Downloading package genesis to /root/nltk_data...
#        |   Unzipping corpora/genesis.zip.
#        | Downloading package gutenberg to /root/nltk_data...
#        |   Unzipping corpora/gutenberg.zip.
#        | Downloading package ieer to /root/nltk_data...
#        |   Unzipping corpora/ieer.zip.
#        | Downloading package inaugural to /root/nltk_data...
#        |   Unzipping corpora/inaugural.zip.
#        | Downloading package indian to /root/nltk_data...
#        |   Unzipping corpora/indian.zip.
#        | Downloading package jeita to /root/nltk_data...
#        | Downloading package kimmo to /root/nltk_data...
#        |   Unzipping corpora/kimmo.zip.
#        | Downloading package knbc to /root/nltk_data...
#        | Downloading package lin_thesaurus to /root/nltk_data...
#        |   Unzipping corpora/lin_thesaurus.zip.
#        | Downloading package mac_morpho to /root/nltk_data...
#        |   Unzipping corpora/mac_morpho.zip.
#        | Downloading package machado to /root/nltk_data...
#        | Downloading package masc_tagged to /root/nltk_data...
#        | Downloading package moses_sample to /root/nltk_data...
#        |   Unzipping models/moses_sample.zip.
#        | Downloading package movie_reviews to /root/nltk_data...
#        |   Unzipping corpora/movie_reviews.zip.
#        | Downloading package names to /root/nltk_data...
#        |   Unzipping corpora/names.zip.
#        | Downloading package nombank.1.0 to /root/nltk_data...
#        | Downloading package nps_chat to /root/nltk_data...
#        |   Unzipping corpora/nps_chat.zip.
#        | Downloading package omw to /root/nltk_data...
#        |   Unzipping corpora/omw.zip.
#        | Downloading package opinion_lexicon to /root/nltk_data...
#        |   Unzipping corpora/opinion_lexicon.zip.
#        | Downloading package paradigms to /root/nltk_data...
#        |   Unzipping corpora/paradigms.zip.
#        | Downloading package pil to /root/nltk_data...
#        |   Unzipping corpora/pil.zip.
#        | Downloading package pl196x to /root/nltk_data...
#        |   Unzipping corpora/pl196x.zip.
#        | Downloading package ppattach to /root/nltk_data...
#        |   Unzipping corpora/ppattach.zip.
#        | Downloading package problem_reports to /root/nltk_data...
#        |   Unzipping corpora/problem_reports.zip.
#        | Downloading package propbank to /root/nltk_data...
#        | Downloading package ptb to /root/nltk_data...
#        |   Unzipping corpora/ptb.zip.
#        | Downloading package product_reviews_1 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_1.zip.
#        | Downloading package product_reviews_2 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_2.zip.
#        | Downloading package pros_cons to /root/nltk_data...
#        |   Unzipping corpora/pros_cons.zip.
#        | Downloading package qc to /root/nltk_data...
#        |   Unzipping corpora/qc.zip.
#        | Downloading package reuters to /root/nltk_data...
#        | Downloading package rte to /root/nltk_data...
#        |   Unzipping corpora/rte.zip.
#        | Downloading package semcor to /root/nltk_data...
#        | Downloading package senseval to /root/nltk_data...
#        |   Unzipping corpora/senseval.zip.
#        | Downloading package sentiwordnet to /root/nltk_data...
#        |   Unzipping corpora/sentiwordnet.zip.
#        | Downloading package sentence_polarity to /root/nltk_data...
#        |   Unzipping corpora/sentence_polarity.zip.
#        | Downloading package shakespeare to /root/nltk_data...
#        |   Unzipping corpora/shakespeare.zip.
#        | Downloading package sinica_treebank to /root/nltk_data...
#        |   Unzipping corpora/sinica_treebank.zip.
#        | Downloading package smultron to /root/nltk_data...
#        |   Unzipping corpora/smultron.zip.
#        | Downloading package state_union to /root/nltk_data...
#        |   Unzipping corpora/state_union.zip.
#        | Downloading package stopwords to /root/nltk_data...
#        |   Unzipping corpora/stopwords.zip.
#        | Downloading package subjectivity to /root/nltk_data...
#        |   Unzipping corpora/subjectivity.zip.
#        | Downloading package swadesh to /root/nltk_data...
#        |   Unzipping corpora/swadesh.zip.
#        | Downloading package switchboard to /root/nltk_data...
#        |   Unzipping corpora/switchboard.zip.
#        | Downloading package timit to /root/nltk_data...
#        |   Unzipping corpora/timit.zip.
#        | Downloading package toolbox to /root/nltk_data...
#        |   Unzipping corpora/toolbox.zip.
#        | Downloading package treebank to /root/nltk_data...
#        |   Unzipping corpora/treebank.zip.
#        | Downloading package twitter_samples to /root/nltk_data...
#        |   Unzipping corpora/twitter_samples.zip.
#        | Downloading package udhr to /root/nltk_data...
#        |   Unzipping corpora/udhr.zip.
#        | Downloading package udhr2 to /root/nltk_data...
#        |   Unzipping corpora/udhr2.zip.
#        | Downloading package unicode_samples to /root/nltk_data...
#        |   Unzipping corpora/unicode_samples.zip.
#        | Downloading package universal_treebanks_v20 to
#        |     /root/nltk_data...
#        | Downloading package verbnet to /root/nltk_data...
#        |   Unzipping corpora/verbnet.zip.
#        | Downloading package verbnet3 to /root/nltk_data...
#        |   Unzipping corpora/verbnet3.zip.
#        | Downloading package webtext to /root/nltk_data...
#        |   Unzipping corpora/webtext.zip.
#        | Downloading package wordnet to /root/nltk_data...
#        |   Unzipping corpora/wordnet.zip.
#        | Downloading package wordnet_ic to /root/nltk_data...
#        |   Unzipping corpora/wordnet_ic.zip.
#        | Downloading package words to /root/nltk_data...
#        |   Unzipping corpora/words.zip.
#        | Downloading package ycoe to /root/nltk_data...
#        |   Unzipping corpora/ycoe.zip.
#        | Downloading package rslp to /root/nltk_data...
#        |   Unzipping stemmers/rslp.zip.
#        | Downloading package maxent_treebank_pos_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
#        | Downloading package universal_tagset to /root/nltk_data...
#        |   Unzipping taggers/universal_tagset.zip.
#        | Downloading package maxent_ne_chunker to /root/nltk_data...
#        |   Unzipping chunkers/maxent_ne_chunker.zip.
#        | Downloading package punkt to /root/nltk_data...
#        |   Unzipping tokenizers/punkt.zip.
#        | Downloading package book_grammars to /root/nltk_data...
#        |   Unzipping grammars/book_grammars.zip.
#        | Downloading package sample_grammars to /root/nltk_data...
#        |   Unzipping grammars/sample_grammars.zip.
#        | Downloading package spanish_grammars to /root/nltk_data...
#        |   Unzipping grammars/spanish_grammars.zip.
#        | Downloading package basque_grammars to /root/nltk_data...
#        |   Unzipping grammars/basque_grammars.zip.
#        | Downloading package large_grammars to /root/nltk_data...
#        |   Unzipping grammars/large_grammars.zip.
#        | Downloading package tagsets to /root/nltk_data...
#        |   Unzipping help/tagsets.zip.
#        | Downloading package snowball_data to /root/nltk_data...
#        | Downloading package bllip_wsj_no_aux to /root/nltk_data...
#        |   Unzipping models/bllip_wsj_no_aux.zip.
#        | Downloading package word2vec_sample to /root/nltk_data...
#        |   Unzipping models/word2vec_sample.zip.
#        | Downloading package panlex_swadesh to /root/nltk_data...
#        | Downloading package mte_teip5 to /root/nltk_data...
#        |   Unzipping corpora/mte_teip5.zip.
#        | Downloading package averaged_perceptron_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger.zip.
#        | Downloading package averaged_perceptron_tagger_ru to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger_ru.zip.
#        | Downloading package perluniprops to /root/nltk_data...
#        |   Unzipping misc/perluniprops.zip.
#        | Downloading package nonbreaking_prefixes to
#        |     /root/nltk_data...
#        |   Unzipping corpora/nonbreaking_prefixes.zip.
#        | Downloading package vader_lexicon to /root/nltk_data...
#        | Downloading package porter_test to /root/nltk_data...
#        |   Unzipping stemmers/porter_test.zip.
#        | Downloading package wmt15_eval to /root/nltk_data...
#        |   Unzipping models/wmt15_eval.zip.
#        | Downloading package mwa_ppdb to /root/nltk_data...
#        |   Unzipping misc/mwa_ppdb.zip.
#        |
#      Done downloading collection all
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %% [markdown]
# Removing Stop Words

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
df['After Preprocessing'] = df['After Preprocessing'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df
# Out:
#          Glimpse of Review  ...                                After Preprocessing
# 0                Wonderful  ...  sound really good even without sub woofer bass...
# 1        Worth every penny  ...  excellent product nice sound quality preset so...
# 2                  Awesome  ...  best brand built quality good distortion sound...
# 3           Master Blaster  ...  using since last days pros stylish look awesom...
# 4                Very Good  ...  writing review using days overall sound astoni...
# ..                     ...  ...                                                ...
# 531          Great product  ...  best speaker small roomthe audio clear could h...
# 532                 Super!  ...                  worthy product stylish designread
# 533              Fabulous!  ...                        overall product amazingread
# 534  Mind-blowing purchase  ...                       value money satisfactionread
# 535         Simply awesome  ...                       good sound qualitythanksread
#
# [536 rows x 4 columns]

# %% [markdown]
# Spelling Correction

# %%
from textblob import TextBlob
df['After Preprocessing'].apply(lambda x: str(TextBlob(x).correct()))
# Out:
# 0      sound really good even without sub offer bass ...
# 1      excellent product nice sound quality present s...
# 2      best brand built quality good distortion sound...
# 3      using since last days pro stylish look awesome...
# 4      writing review using days overall sound astoni...
#                              ...
# 531    best speaker small soothe audit clear could he...
# 532                      worthy product stylish designed
# 533                          overall product amazingread
# 534                         value money satisfactionread
# 535                         good sound qualitythanksread
# Name: After Preprocessing, Length: 536, dtype: object

# %% [markdown]
# Stemming

# %%
from nltk.stem import PorterStemmer
st = PorterStemmer()
df['After Preprocessing'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
# Out:
# 0      sound realli good even without sub woofer bass...
# 1      excel product nice sound qualiti preset sound ...
# 2      best brand built qualiti good distort sound co...
# 3      use sinc last day pro stylish look awesom soun...
# 4      write review use day overal sound astonish cla...
#                              ...
# 531    best speaker small roomth audio clear could he...
# 532                    worthi product stylish designread
# 533                           overal product amazingread
# 534                          valu money satisfactionread
# 535                         good sound qualitythanksread
# Name: After Preprocessing, Length: 536, dtype: object

# %% [markdown]
# Lemmatization

# %%
from textblob import Word
import nltk
nltk.download('wordnet')

df['After Preprocessing'] = df['After Preprocessing'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
df
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#          Glimpse of Review  ...                                After Preprocessing
# 0                Wonderful  ...  sound really good even without sub woofer bass...
# 1        Worth every penny  ...  excellent product nice sound quality preset so...
# 2                  Awesome  ...  best brand built quality good distortion sound...
# 3           Master Blaster  ...  using since last day pro stylish look awesome ...
# 4                Very Good  ...  writing review using day overall sound astonis...
# ..                     ...  ...                                                ...
# 531          Great product  ...  best speaker small roomthe audio clear could h...
# 532                 Super!  ...                  worthy product stylish designread
# 533              Fabulous!  ...                        overall product amazingread
# 534  Mind-blowing purchase  ...                       value money satisfactionread
# 535         Simply awesome  ...                       good sound qualitythanksread
#
# [536 rows x 4 columns]

# %% [markdown]
# Parts of Speech Tagging and Features

# %%
from nltk.tokenize import word_tokenize
pos = []
for sentence in df['After Preprocessing']:
  text = word_tokenize(sentence)
  pos.append(nltk.pos_tag(text))
pos
# Out:
# [[('sound', 'NN'),
#   ('really', 'RB'),
#   ('good', 'JJ'),
#   ('even', 'RB'),
#   ('without', 'IN'),
#   ('sub', 'NN'),
#   ('woofer', 'NN'),
#   ('bass', 'NN'),
#   ('good', 'JJ'),
#   ('enough', 'RB'),
#   ('fine', 'JJ'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('really', 'RB'),
#   ('good', 'JJ'),
#   ('didnt', 'NN'),
#   ('support', 'NN'),
#   ('hdmi', 'VBD'),
#   ('digital', 'JJ'),
#   ('audio', 'RB'),
#   ('even', 'RB'),
#   ('co', 'VBP'),
#   ('axial', 'JJ'),
#   ('really', 'RB'),
#   ('sad', 'JJ'),
#   ('thatread', 'NN')],
#  [('excellent', 'JJ'),
#   ('product', 'NN'),
#   ('nice', 'JJ'),
#   ('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('preset', 'VBN'),
#   ('sound', 'JJ'),
#   ('mode', 'NN'),
#   ('nice', 'JJ'),
#   ('bass', 'NN'),
#   ('price', 'NN'),
#   ('segment', 'NN'),
#   ('good', 'JJ'),
#   ('installation', 'NN'),
#   ('service', 'NN'),
#   ('good', 'JJ'),
#   ('connectivity', 'NN'),
#   ('lag', 'VBP'),
#   ('tv', 'NN'),
#   ('connectionread', 'NN')],
#  [('best', 'JJS'),
#   ('brand', 'NN'),
#   ('built', 'VBN'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('distortion', 'NN'),
#   ('sound', 'NN'),
#   ('compared', 'VBN'),
#   ('mi', 'JJ'),
#   ('brand', 'NN'),
#   ('would', 'MD'),
#   ('like', 'VB'),
#   ('give', 'VB'),
#   ('installation', 'NN'),
#   ('person', 'NN'),
#   ('much', 'JJ'),
#   ('friendly', 'RB'),
#   ('knowledgeable', 'JJ'),
#   ('person', 'NN'),
#   ('told', 'VBD'),
#   ('kind', 'NN'),
#   ('technical', 'JJ'),
#   ('detail', 'NN'),
#   ('thank', 'NN'),
#   ('much', 'JJ'),
#   ('providing', 'VBG'),
#   ('good', 'JJ'),
#   ('service', 'NN'),
#   ('thank', 'NN'),
#   ('flipkartread', 'NN')],
#  [('using', 'VBG'),
#   ('since', 'IN'),
#   ('last', 'JJ'),
#   ('day', 'NN'),
#   ('pro', 'VBD'),
#   ('stylish', 'JJ'),
#   ('look', 'NN'),
#   ('awesome', 'JJ'),
#   ('sound', 'NN'),
#   ('setting', 'VBG'),
#   ('provided', 'JJ'),
#   ('remote', 'JJ'),
#   ('matter', 'NN'),
#   ('watt', 'NN'),
#   ('good', 'JJ'),
#   ('enough', 'RB'),
#   ('medium', 'NN'),
#   ('sized', 'JJ'),
#   ('room', 'NN'),
#   ('ft', 'NN'),
#   ('x', 'NNP'),
#   ('ft', 'JJ'),
#   ('auto', 'NN'),
#   ('switch', 'NN'),
#   ('use', 'NN'),
#   ('helpful', 'JJ'),
#   ('dont', 'NN'),
#   ('expect', 'VBP'),
#   ('good', 'JJ'),
#   ('result', 'NN'),
#   ('day', 'NN'),
#   ('one', 'CD'),
#   ('take', 'NN'),
#   ('day', 'NN'),
#   ('gear', 'VBP'),
#   ('full', 'JJ'),
#   ('powercons', 'NNS'),
#   ('bluetooth', 'DT'),
#   ('connectivity', 'NN'),
#   ('poor', 'JJ'),
#   ('get', 'NN'),
#   ('disconnected', 'VBN'),
#   ('better', 'RBR'),
#   ('get', 'VB'),
#   ('connected', 'VBN'),
#   ('aux', 'RB'),
#   ('cable', 'NN'),
#   ('connected', 'VBN'),
#   ('meter', 'RBR'),
#   ('boat', 'NN'),
#   ('aux', 'RB'),
#   ('cable', 'NN'),
#   ('u', 'JJ'),
#   ('connread', 'NN')],
#  [('writing', 'VBG'),
#   ('review', 'NN'),
#   ('using', 'VBG'),
#   ('day', 'NN'),
#   ('overall', 'JJ'),
#   ('sound', 'NN'),
#   ('astonishing', 'VBG'),
#   ('clarity', 'NN'),
#   ('perfectbass', 'NN'),
#   ('besttreble', 'JJ'),
#   ('bestremote', 'NN'),
#   ('control', 'NN'),
#   ('greatlook', 'NN'),
#   ('sexy', 'JJ'),
#   ('length', 'NN'),
#   ('inchinstallation', 'NN'),
#   ('guy', 'NN'),
#   ('useless', 'NN'),
#   ('installed', 'VBN'),
#   ('tilted', 'VBD'),
#   ('wall', 'NN'),
#   ('call', 'NN'),
#   ('home', 'NN'),
#   ('electrician', 'NN'),
#   ('install', 'NN'),
#   ('straight', 'VBD'),
#   ('cut', 'VBN'),
#   ('star', 'NN'),
#   ('reviewotherwise', 'NN'),
#   ('avante', 'NN'),
#   ('watt', 'WRB'),
#   ('soundbar', 'NN'),
#   ('outstanding', 'JJ'),
#   ('noone', 'NN'),
#   ('beat', 'VBD'),
#   ('boat', 'JJ'),
#   ('company', 'NN'),
#   ('im', 'NN'),
#   ('big', 'JJ'),
#   ('fanread', 'NN')],
#  [('excellent', 'JJ'),
#   ('product', 'NN'),
#   ('nice', 'JJ'),
#   ('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('sound', 'NN'),
#   ('really', 'RB'),
#   ('good', 'JJ'),
#   ('bass', 'NN'),
#   ('good', 'JJ'),
#   ('enough', 'RB'),
#   ('attractive', 'JJ'),
#   ('look', 'NN'),
#   ('build', 'JJ'),
#   ('quality', 'NN'),
#   ('also', 'RB'),
#   ('good', 'JJ'),
#   ('problem', 'NN'),
#   ('usb', 'NN'),
#   ('port', 'NN'),
#   ('back', 'RB'),
#   ('hanged', 'VBD'),
#   ('wall', 'NN'),
#   ('usb', 'NN'),
#   ('connected', 'VBD'),
#   ('happy', 'JJ'),
#   ('purchase', 'NN'),
#   ('delivery', 'NN'),
#   ('time', 'NN'),
#   ('good', 'JJ'),
#   ('serviceread', 'NN')],
#  [('product', 'NN'),
#   ('good', 'JJ'),
#   ('certain', 'JJ'),
#   ('word', 'NN'),
#   ('play', 'VB'),
#   ('one', 'CD'),
#   ('understanding', 'JJ'),
#   ('function', 'NN'),
#   ('product', 'NN'),
#   ('best', 'JJS'),
#   ('feature', 'NN'),
#   ('product', 'NN'),
#   ('indian', 'JJ'),
#   ('brand', 'NN'),
#   ('usb', 'JJ'),
#   ('connectivity', 'NN'),
#   ('different', 'JJ'),
#   ('thing', 'NN'),
#   ('altogether', 'RB'),
#   ('doesnt', 'JJ'),
#   ('allow', 'IN'),
#   ('connect', 'JJ'),
#   ('tv', 'NN'),
#   ('device', 'NN'),
#   ('usb', 'IN'),
#   ('usb', 'JJ'),
#   ('refers', 'NNS'),
#   ('flash', 'VBP'),
#   ('drivependrive', 'JJ'),
#   ('plug', 'NN'),
#   ('usb', 'NN'),
#   ('slot', 'NN'),
#   ('play', 'NN'),
#   ('song', 'RB'),
#   ('directly', 'RB'),
#   ('connecting', 'VBG'),
#   ('using', 'VBG'),
#   ('aux', 'JJ'),
#   ('cable', 'NN'),
#   ('dont', 'NN'),
#   ('expect', 'VBP'),
#   ('result', 'NN'),
#   ('read', 'NN')],
#  [('good', 'JJ'),
#   ('product', 'NN'),
#   ('loved', 'VBD'),
#   ('buy', 'JJ'),
#   ('easily', 'RB'),
#   ('delivery', 'NN'),
#   ('best', 'JJS'),
#   ('good', 'JJ'),
#   ('bass', 'NN'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('awesome', 'VBP'),
#   ('read', 'NN')],
#  [('good', 'JJ'),
#   ('build', 'NN'),
#   ('quality', 'NN'),
#   ('great', 'JJ'),
#   ('sound', 'JJ'),
#   ('clarity', 'NN'),
#   ('sufficient', 'JJ'),
#   ('x', 'NNP'),
#   ('sqft', 'NN'),
#   ('bedroom', 'NN'),
#   ('bass', 'NN'),
#   ('lower', 'RBR'),
#   ('side', 'NN'),
#   ('though', 'IN'),
#   ('remote', 'JJ'),
#   ('control', 'NN'),
#   ('good', 'JJ'),
#   ('versatile', 'NN'),
#   ('bluetooth', 'DT'),
#   ('connectivity', 'NN'),
#   ('great', 'JJ'),
#   ('use', 'NN'),
#   ('better', 'RBR'),
#   ('aux', 'NN'),
#   ('cable', 'NN'),
#   ('one', 'CD'),
#   ('provided', 'VBD'),
#   ('box', 'NN'),
#   ('best', 'JJS'),
#   ('outputread', 'NN')],
#  [('good', 'JJ'),
#   ('product', 'NN'),
#   ('got', 'VBD'),
#   ('rate', 'NN'),
#   ('bbd', 'NN'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('dedicated', 'VBN'),
#   ('switch', 'NN'),
#   ('treble', 'JJ'),
#   ('bass', 'NN'),
#   ('also', 'RB'),
#   ('presets', 'VBZ'),
#   ('like', 'IN'),
#   ('news', 'NN'),
#   ('movie', 'NN'),
#   ('music', 'NN'),
#   ('etc', 'NN'),
#   ('available', 'JJ'),
#   ('remote', 'NN'),
#   ('used', 'VBN'),
#   ('sound', 'JJ'),
#   ('bar', 'NN'),
#   ('mitv', 'NN'),
#   ('wired', 'VBD'),
#   ('connection', 'NN'),
#   ('sound', 'NN'),
#   ('good', 'JJ'),
#   ('bluetooth', 'NN'),
#   ('connectivity', 'NN'),
#   ('good', 'JJ'),
#   ('sound', 'NN'),
#   ('also', 'RB'),
#   ('nice', 'JJ'),
#   ('pack', 'NN'),
#   ('come', 'VBP'),
#   ('aux', 'IN'),
#   ('cable', 'NN'),
#   ('remote', 'VBP'),
#   ('controller', 'NN'),
#   ('battery', 'NN'),
#   ('included', 'VBD'),
#   ('remote', 'JJ'),
#   ('controller', 'NN'),
#   ('better', 'RBR'),
#   ('boat', 'NN'),
#   ('includes', 'VBZ'),
#   ('r', 'NN'),
#   ('betteries', 'NNS'),
#   ('k', 'VBP'),
#   ('soundbarread', 'JJ')],
#  [('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('fabulousi', 'NN'),
#   ('happylooking', 'VBG'),
#   ('sexy', 'NNS'),
#   ('barreally', 'RB'),
#   ('first', 'JJ'),
#   ('time', 'NN'),
#   ('purchase', 'NN'),
#   ('item', 'NN'),
#   ('boughtits', 'VBZ'),
#   ('one', 'CD'),
#   ('best', 'JJS'),
#   ('product', 'NN'),
#   ('like', 'IN'),
#   ('everto', 'JJ'),
#   ('purchase', 'NN'),
#   ('item', 'NN'),
#   ('thank', 'JJ'),
#   ('flipkart', 'NN'),
#   ('read', 'NN')],
#  [('honest', 'JJS'),
#   ('review', 'NN'),
#   ('product', 'NN'),
#   ('sound', 'JJ'),
#   ('enhancement', 'JJ'),
#   ('product', 'NN'),
#   ('guy', 'NN'),
#   ('please', 'NN'),
#   ('expect', 'VBP'),
#   ('miracle', 'NN'),
#   ('soundbar', 'NN'),
#   ('nothing', 'NN'),
#   ('called', 'VBN'),
#   ('signature', 'NN'),
#   ('sound', 'NN'),
#   ('advertised', 'VBD'),
#   ('bass', 'NN'),
#   ('absolutely', 'RB'),
#   ('muddy', 'JJ'),
#   ('full', 'JJ'),
#   ('volume', 'NN'),
#   ('testing', 'VBG'),
#   ('purpose', 'JJ'),
#   ('sound', 'JJ'),
#   ('start', 'NN'),
#   ('distort', 'NN'),
#   ('tear', 'VBP'),
#   ('build', 'JJ'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('doubt', 'NN'),
#   ('sound', 'NN'),
#   ('buyer', 'NN'),
#   ('look', 'NN'),
#   ('satisfying', 'VBG'),
#   ('soundbar', 'NN'),
#   ('barely', 'RB'),
#   ('add', 'VB'),
#   ('depth', 'RB'),
#   ('overall', 'JJ'),
#   ('sound', 'NN'),
#   ('existing', 'VBG'),
#   ('tv', 'NN'),
#   ('tread', 'NN')],
#  [('got', 'VBD'),
#   ('good', 'JJ'),
#   ('dealwas', 'NN'),
#   ('little', 'JJ'),
#   ('le', 'JJ'),
#   ('expectationsas', 'NN'),
#   ('w', 'NN'),
#   ('speaker', 'NN'),
#   ('experience', 'NN'),
#   ('boat', 'NN'),
#   ('bluetooth', 'DT'),
#   ('speaker', 'NN'),
#   ('much', 'RB'),
#   ('better', 'RBR'),
#   ('comparativelythe', 'JJ'),
#   ('lowest', 'JJS'),
#   ('bass', 'NN'),
#   ('also', 'RB'),
#   ('much', 'JJ'),
#   ('problem', 'NN'),
#   ('still', 'RB'),
#   ('cant', 'JJ'),
#   ('make', 'NN'),
#   ('required', 'VBN'),
#   ('sometimes', 'RB'),
#   ('listening', 'VBG'),
#   ('news', 'NN'),
#   ('etcbut', 'NN'),
#   ('satisfactory', 'JJ'),
#   ('product', 'NN'),
#   ('trust', 'NN'),
#   ('flipkart', 'RB'),
#   ('even', 'RB'),
#   ('boat', 'VB'),
#   ('servicesthe', 'NN'),
#   ('functionality', 'NN'),
#   ('remote', 'VBP'),
#   ('ideal', 'JJ'),
#   ('mean', 'JJ'),
#   ('mode', 'NN'),
#   ('doesnt', 'NN'),
#   ('serve', 'VBP'),
#   ('purposeread', 'NN')],
#  [('specifically', 'RB'),
#   ('looked', 'VBD'),
#   ('soundbar', 'NN'),
#   ('handpicked', 'VBD'),
#   ('one', 'CD'),
#   ('boat', 'NN'),
#   ('due', 'JJ'),
#   ('output', 'NN'),
#   ('power', 'NN'),
#   ('without', 'IN'),
#   ('battery', 'NN'),
#   ('use', 'NN'),
#   ('child', 'JJ'),
#   ('school', 'NN'),
#   ('online', 'NN'),
#   ('session', 'NN'),
#   ('soundbar', 'NN'),
#   ('ensures', 'VBZ'),
#   ('excellent', 'JJ'),
#   ('sound', 'JJ'),
#   ('clarity', 'NN'),
#   ('especially', 'RB'),
#   ('teacher', 'JJ'),
#   ('lecture', 'NN'),
#   ('heard', 'VBD'),
#   ('clearly', 'RB'),
#   ('without', 'IN'),
#   ('need', 'NN'),
#   ('use', 'NN'),
#   ('headphone', 'CD'),
#   ('prevent', 'NN'),
#   ('potential', 'JJ'),
#   ('ear', 'JJ'),
#   ('infection', 'NN'),
#   ('child', 'NN'),
#   ('damage', 'NN'),
#   ('due', 'JJ'),
#   ('prolonged', 'VBD'),
#   ('headphoneearphone', 'NN'),
#   ('use', 'NN'),
#   ('increasing', 'VBG'),
#   ('quality', 'NN'),
#   ('online', 'JJ'),
#   ('school', 'NN'),
#   ('learning', 'VBG'),
#   ('experience', 'NN'),
#   ('besides', 'IN'),
#   ('parent', 'NN'),
#   ('keep', 'NN'),
#   ('ear', 'NN'),
#   ('distance', 'NN'),
#   ('knread', 'NN')],
#  [('product', 'NN'),
#   ('mini', 'NN'),
#   ('theatre', 'NN'),
#   ('homesound', 'VBD'),
#   ('awesome', 'JJ'),
#   ('voice', 'NN'),
#   ('super', 'NN'),
#   ('goodand', 'NN'),
#   ('also', 'RB'),
#   ('one', 'CD'),
#   ('major', 'JJ'),
#   ('thing', 'NN'),
#   ('ismusic', 'JJ'),
#   ('low', 'JJ'),
#   ('sound', 'NN'),
#   ('amazing', 'VBG'),
#   ('hearing', 'VBG'),
#   ('experience', 'NN'),
#   ('relaxes', 'NNS'),
#   ('mind', 'VBP'),
#   ('best', 'JJS'),
#   ('product', 'NN'),
#   ('price', 'NN'),
#   ('choose', 'JJ'),
#   ('worth', 'JJ'),
#   ('fulread', 'NN')],
#  [('sound', 'JJ'),
#   ('bar', 'NN'),
#   ('amazing', 'NN'),
#   ('best', 'JJS'),
#   ('bass', 'NN'),
#   ('treble', 'JJ'),
#   ('ratio', 'NN'),
#   ('need', 'VBP'),
#   ('enjoy', 'VB'),
#   ('stuff', 'JJ'),
#   ('personally', 'RB'),
#   ('didnt', 'VBP'),
#   ('want', 'JJ'),
#   ('bar', 'NN'),
#   ('woofer', 'NN'),
#   ('watching', 'VBG'),
#   ('tv', 'NN'),
#   ('much', 'JJ'),
#   ('boom', 'NN'),
#   ('boom', 'NN'),
#   ('cause', 'NN'),
#   ('headache', 'NN'),
#   ('bar', 'NN'),
#   ('give', 'VBP'),
#   ('taste', 'NN'),
#   ('balanced', 'JJ'),
#   ('way', 'NN'),
#   ('must', 'MD'),
#   ('buyread', 'VB')],
#  [('bought', 'VBN'),
#   ('diwali', 'NN'),
#   ('salesound', 'RB'),
#   ('good', 'JJ'),
#   ('price', 'NN'),
#   ('rangeperfect', 'NN'),
#   ('inch', 'NN'),
#   ('mi', 'NN'),
#   ('led', 'VBD'),
#   ('tvbass', 'NN'),
#   ('good', 'JJ'),
#   ('enough', 'RB'),
#   ('small', 'JJ'),
#   ('roomsbetter', 'NN'),
#   ('audio', 'JJ'),
#   ('quality', 'NN'),
#   ('bluetoothoverall', 'RB'),
#   ('good', 'JJ'),
#   ('dealgo', 'NNS'),
#   ('itread', 'VBP')],
#  [('awesome', 'JJ'),
#   ('sound', 'NN'),
#   ('built', 'VBN'),
#   ('quality', 'NN'),
#   ('ive', 'NN'),
#   ('wanting', 'VBG'),
#   ('buy', 'VB'),
#   ('sound', 'JJ'),
#   ('bar', 'NN'),
#   ('since', 'IN'),
#   ('long', 'RB'),
#   ('high', 'JJ'),
#   ('cost', 'NN'),
#   ('soundbars', 'NNS'),
#   ('general', 'JJ'),
#   ('one', 'CD'),
#   ('factor', 'NN'),
#   ('something', 'NN'),
#   ('prevented', 'VBD'),
#   ('buying', 'VBG'),
#   ('one', 'CD'),
#   ('came', 'VBD'),
#   ('across', 'IN'),
#   ('boat', 'NN'),
#   ('soundbar', 'NN'),
#   ('great', 'JJ'),
#   ('review', 'NN'),
#   ('decided', 'VBD'),
#   ('give', 'JJ'),
#   ('try', 'NN'),
#   ('one', 'CD'),
#   ('doesnt', 'NN'),
#   ('separate', 'JJ'),
#   ('subwoofer', 'NN'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('much', 'RB'),
#   ('much', 'RB'),
#   ('better', 'RBR'),
#   ('expected', 'VBN'),
#   ('happy', 'JJ'),
#   ('purchase', 'NN'),
#   ('watching', 'VBG'),
#   ('movie', 'NN'),
#   ('listening', 'NN'),
#   ('song', 'JJ'),
#   ('tv', 'NN'),
#   ('different', 'JJ'),
#   ('level', 'NN'),
#   ('wiread', 'NN')],
#  [('superb', 'NN'),
#   ('sound', 'NN'),
#   ('claritydecent', 'JJ'),
#   ('basstheater', 'NN'),
#   ('experience', 'NN'),
#   ('sound', 'VBD'),
#   ('fast', 'RB'),
#   ('delivery', 'NN'),
#   ('fast', 'JJ'),
#   ('installation', 'NN'),
#   ('tooo', 'NN'),
#   ('thank', 'NN'),
#   ('flipkartgot', 'VBD'),
#   ('good', 'JJ'),
#   ('dealread', 'NN')],
#  [('firts', 'NNS'),
#   ('home', 'NN'),
#   ('theater', 'NN'),
#   ('speaker', 'NN'),
#   ('dont', 'NN'),
#   ('think', 'VBP'),
#   ('tomuch', 'JJ'),
#   ('expectation', 'NN'),
#   ('perfect', 'JJ'),
#   ('tv', 'NN'),
#   ('watt', 'NN'),
#   ('put', 'VBD'),
#   ('low', 'JJ'),
#   ('mp', 'NN'),
#   ('music', 'NN'),
#   ('listening', 'VBG'),
#   ('hall', 'JJ'),
#   ('room', 'NN'),
#   ('enoigh', 'VBP'),
#   ('woofer', 'NN'),
#   ('much', 'JJ'),
#   ('better', 'JJR'),
#   ('ok', 'JJ'),
#   ('enough', 'RB'),
#   ('like', 'IN'),
#   ('play', 'NN'),
#   ('kbps', 'FW'),
#   ('mp', 'NN'),
#   ('music', 'NN'),
#   ('better', 'RBR'),
#   ('output', 'NN'),
#   ('phone', 'NN'),
#   ('dts', 'NN'),
#   ('output', 'NN'),
#   ('give', 'VBP'),
#   ('better', 'JJR'),
#   ('soundread', 'NN')],
#  [('giving', 'VBG'),
#   ('honest', 'JJS'),
#   ('reviewthe', 'NN'),
#   ('bestest', 'JJS'),
#   ('quality', 'NN'),
#   ('mid', 'NN'),
#   ('range', 'NN'),
#   ('sound', 'NN'),
#   ('barsound', 'IN'),
#   ('quality', 'NN'),
#   ('awesomebass', 'NN'),
#   ('good', 'JJ'),
#   ('qualitym', 'NN'),
#   ('using', 'VBG'),
#   ('speaker', 'JJR'),
#   ('laptop', 'JJ'),
#   ('nbuild', 'NN'),
#   ('quality', 'NN'),
#   ('excellent', 'JJ'),
#   ('hav', 'NN'),
#   ('premium', 'NN'),
#   ('quality', 'NN'),
#   ('lookread', 'NN')],
#  [('good', 'JJ'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('delivery', 'NN'),
#   ('without', 'IN'),
#   ('damagei', 'NN'),
#   ('liked', 'VBD'),
#   ('product', 'NN'),
#   ('le', 'NN'),
#   ('money', 'NN'),
#   ('get', 'VB'),
#   ('good', 'JJ'),
#   ('product', 'NN'),
#   ('boatread', 'NN')],
#  [('goodread', 'NN')],
#  [('markbut', 'NN'),
#   ('bad', 'JJ'),
#   ('sound', 'JJ'),
#   ('okbass', 'NN'),
#   ('good', 'JJ'),
#   ('love', 'NN'),
#   ('bass', 'NN'),
#   ('go', 'VBP'),
#   ('optionit', 'JJ'),
#   ('item', 'NN'),
#   ('bass', 'NN'),
#   ('loverread', 'NN')],
#  [('best', 'JJS'),
#   ('option', 'NN'),
#   ('price', 'NN'),
#   ('range', 'NN'),
#   ('really', 'RB'),
#   ('change', 'VB'),
#   ('boring', 'VBG'),
#   ('sound', 'JJ'),
#   ('output', 'NN'),
#   ('tv', 'NN'),
#   ('really', 'RB'),
#   ('good', 'JJ'),
#   ('level', 'NN'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('thinking', 'VBG'),
#   ('buy', 'VBP'),
#   ('close', 'JJ'),
#   ('eye', 'NN'),
#   ('buy', 'NN'),
#   ('boatprosvery', 'NN'),
#   ('good', 'JJ'),
#   ('looking', 'VBG'),
#   ('designbass', 'NN'),
#   ('good', 'JJ'),
#   ('enoughtreble', 'JJ'),
#   ('excellentvery', 'NN'),
#   ('useful', 'JJ'),
#   ('remote', 'JJ'),
#   ('two', 'CD'),
#   ('mm', 'JJ'),
#   ('jack', 'NN'),
#   ('usb', 'JJ'),
#   ('port', 'NN'),
#   ('backan', 'NN'),
#   ('aux', 'IN'),
#   ('cable', 'NN'),
#   ('includedl', 'NN'),
#   ('shapedresponsive', 'JJ'),
#   ('fast', 'RB'),
#   ('bluetooth', 'CC'),
#   ('connectivityconsthe', 'JJ'),
#   ('power', 'NN'),
#   ('connecting', 'VBG'),
#   ('cable', 'NN'),
#   ('really', 'RB'),
#   ('small', 'JJ'),
#   ('tv', 'NN'),
#   ('setupnothing', 'NN'),
#   ('else', 'RB'),
#   ('go', 'VBP'),
#   ('read', 'VB')],
#  [('connect', 'NN'),
#   ('led', 'VBD'),
#   ('sound', 'JJ'),
#   ('bar', 'NN'),
#   ('boom', 'NN'),
#   ('feel', 'VBP'),
#   ('like', 'IN'),
#   ('watching', 'VBG'),
#   ('cinema', 'NN'),
#   ('really', 'RB'),
#   ('good', 'JJ'),
#   ('sound', 'NN'),
#   ('excellent', 'JJ'),
#   ('bass', 'NN'),
#   ('good', 'JJ'),
#   ('build', 'NN'),
#   ('quality', 'NN'),
#   ('highly', 'RB'),
#   ('recommend', 'JJ'),
#   ('buy', 'VB'),
#   ('star', 'JJ'),
#   ('rate', 'NN'),
#   ('product', 'NN'),
#   ('give', 'VB'),
#   ('sound', 'JJ'),
#   ('bar', 'NN'),
#   ('thank', 'NN'),
#   ('flipkart', 'NN'),
#   ('boat', 'NN'),
#   ('good', 'JJ'),
#   ('productread', 'NN')],
#  [('good', 'JJ'),
#   ('crystal', 'NN'),
#   ('clear', 'JJ'),
#   ('sound', 'NN'),
#   ('good', 'JJ'),
#   ('bass', 'NN'),
#   ('nice', 'NN'),
#   ('built', 'VBN'),
#   ('quality', 'JJ'),
#   ('look', 'NN'),
#   ('premiummust', 'JJ'),
#   ('buy', 'NN'),
#   ('happy', 'JJ'),
#   ('purchaseread', 'NN')],
#  [('best', 'JJS'),
#   ('buy', 'NN'),
#   ('range', 'NN'),
#   ('got', 'VBD'),
#   ('kvery', 'JJ'),
#   ('nice', 'JJ'),
#   ('sleek', 'JJ'),
#   ('glossy', 'JJ'),
#   ('design', 'NN'),
#   ('easy', 'JJ'),
#   ('connect', 'JJ'),
#   ('remote', 'NN'),
#   ('operation', 'NN'),
#   ('boat', 'NN'),
#   ('affordable', 'JJ'),
#   ('alternative', 'JJ'),
#   ('nowread', 'NN')],
#  [('goodread', 'NN')],
#  [('goodread', 'NN')],
#  [('nice', 'JJ'), ('soundread', 'NN')],
#  [('good', 'JJ'),
#   ('quality', 'NN'),
#   ('nice', 'JJ'),
#   ('music', 'NN'),
#   ('bassread', 'NN')],
#  [('everthing', 'VBG'),
#   ('super', 'NN'),
#   ('got', 'VBD'),
#   ('remote', 'JJ'),
#   ('brokenread', 'NN')],
#  [('excellent', 'JJ'),
#   ('product', 'NN'),
#   ('price', 'NN'),
#   ('rangeread', 'NN')],
#  [('awesome', 'JJ'), ('productread', 'NN')],
#  [('wahworth', 'NN'),
#   ('moneyjust', 'NN'),
#   ('go', 'VBP'),
#   ('itsound', 'JJ'),
#   ('bass', 'NN'),
#   ('awesoneread', 'NN')],
#  [('awesome', 'JJ'),
#   ('soundbest', 'JJS'),
#   ('soundbar', 'NN'),
#   ('k', 'NN'),
#   ('read', 'VBD')],
#  [('nyc', 'JJ'),
#   ('product', 'NN'),
#   ('thanks', 'NNS'),
#   ('flipcart', 'JJ'),
#   ('time', 'NN'),
#   ('delivery', 'NN'),
#   ('bar', 'NN'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('vry', 'VBP'),
#   ('high', 'JJ'),
#   ('bestread', 'NN')],
#  [('sound', 'RB'),
#   ('good', 'JJ'),
#   ('met', 'VBN'),
#   ('expectation', 'NN'),
#   ('thing', 'NN'),
#   ('unfortunate', 'JJ'),
#   ('product', 'NN'),
#   ('made', 'VBN'),
#   ('chinaread', 'NN')],
#  [('worst', 'JJS'),
#   ('seelers', 'NNS'),
#   ('accept', 'VBP'),
#   ('retern', 'JJ'),
#   ('defect', 'JJ'),
#   ('item', 'NN'),
#   ('dont', 'JJ'),
#   ('buy', 'NN'),
#   ('seelers', 'NNS'),
#   ('product', 'NN'),
#   ('sound', 'NN'),
#   ('bar', 'NN'),
#   ('facing', 'VBG'),
#   ('sound', 'JJ'),
#   ('issue', 'NN'),
#   ('buffering', 'VBG'),
#   ('bt', 'JJ'),
#   ('tec', 'JJ'),
#   ('visit', 'NN'),
#   ('rejuct', 'NN'),
#   ('retern', 'JJ'),
#   ('replacementread', 'NN')],
#  [('awesome', 'JJ'),
#   ('amazing', 'VBG'),
#   ('sound', 'NN'),
#   ('clarity', 'NN'),
#   ('nice', 'JJ'),
#   ('basslove', 'NN'),
#   ('worth', 'NN'),
#   ('valueread', 'NN')],
#  [('value', 'NN'),
#   ('money', 'NN'),
#   ('comfort', 'NN'),
#   ('inch', 'NN'),
#   ('led', 'VBD'),
#   ('tvgood', 'NN'),
#   ('soundread', 'NN')],
#  [('tha', 'NN'), ('sound', 'NN'), ('bass', 'NN'), ('niceread', 'NN')],
#  [('awesomeread', 'NN')],
#  [('super', 'JJ'), ('sound', 'NN'), ('quality', 'NN'), ('bestread', 'NN')],
#  [('doesnt', 'JJ'),
#   ('hv', 'NN'),
#   ('volume', 'NN'),
#   ('memory', 'NN'),
#   ('functionit', 'NN'),
#   ('started', 'VBD'),
#   ('full', 'JJ'),
#   ('volume', 'NN'),
#   ('everytimeread', 'NN')],
#  [('starspurchased', 'VBN'),
#   ('stopped', 'VBD'),
#   ('working', 'VBG'),
#   ('power', 'NN'),
#   ('failure', 'NN'),
#   ('day', 'NN'),
#   ('lodging', 'VBG'),
#   ('many', 'JJ'),
#   ('complaint', 'NN'),
#   ('finally', 'RB'),
#   ('picked', 'VBD'),
#   ('product', 'NN'),
#   ('day', 'NN'),
#   ('received', 'VBD'),
#   ('backhorrible', 'JJ'),
#   ('experienceread', 'NN')],
#  [('bought', 'JJ'),
#   ('product', 'NN'),
#   ('flipkartsound', 'NN'),
#   ('quality', 'NN'),
#   ('excellentinstallation', 'NN'),
#   ('boy', 'NN'),
#   ('also', 'RB'),
#   ('responsive', 'JJ'),
#   ('quickbass', 'NN'),
#   ('also', 'RB'),
#   ('gooddesign', 'JJ'),
#   ('excellent', 'JJ'),
#   ('home', 'NN'),
#   ('friendlyvery', 'NN'),
#   ('much', 'RB'),
#   ('satisfied', 'VBD'),
#   ('luv', 'JJ'),
#   ('productread', 'NN')],
#  [('got', 'VBD'), ('r', 'JJ'), ('nice', 'JJ'), ('qualityread', 'NN')],
#  [('price', 'NN'), ('worthread', 'NN')],
#  [('good', 'JJ'),
#   ('sound', 'NN'),
#   ('bar', 'NN'),
#   ('without', 'IN'),
#   ('bass', 'NN'),
#   ('speaker', 'NN'),
#   ('missing', 'VBG'),
#   ('somethingso', 'NN'),
#   ('advise', 'NN'),
#   ('go', 'VBP'),
#   ('boat', 'NN'),
#   ('sound', 'NN'),
#   ('bar', 'NN'),
#   ('bass', 'NN'),
#   ('speaker', 'NN'),
#   ('box', 'NN'),
#   ('setread', 'NN')],
#  [('best', 'JJS'), ('sound', 'NN'), ('qualityread', 'NN')],
#  [('value', 'NN'),
#   ('money', 'NN'),
#   ('close', 'JJ'),
#   ('ur', 'JJ'),
#   ('eye', 'NN'),
#   ('select', 'NN'),
#   ('read', 'NN')],
#  [('awesome', 'JJ'), ('soundread', 'NN')],
#  [('good', 'JJ'), ('qualityread', 'NN')],
#  [('totally', 'RB'), ('goodread', 'JJ')],
#  [('fantasticread', 'NN')],
#  [('amezing', 'VBG'), ('sound', 'NN'), ('system', 'NN'), ('read', 'VBD')],
#  [('one', 'CD'),
#   ('month', 'NN'),
#   ('stopped', 'VBD'),
#   ('working', 'VBG'),
#   ('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('playing', 'NN'),
#   ('music', 'NN'),
#   ('music', 'NN'),
#   ('application', 'NN'),
#   ('connectivity', 'NN'),
#   ('bluetooth', 'DT'),
#   ('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('mark', 'NN'),
#   ('movie', 'NN'),
#   ('application', 'NN'),
#   ('youtuberead', 'NN')],
#  [('looking', 'VBG'),
#   ('like', 'IN'),
#   ('copy', 'NN'),
#   ('boatdont', 'NN'),
#   ('buyvery', 'NN'),
#   ('bad', 'JJ'),
#   ('experience', 'NN'),
#   ('flipcartnot', 'NN'),
#   ('originalpl', 'IN'),
#   ('ignore', 'NN'),
#   ('productread', 'NN')],
#  [('bass', 'NN'), ('good', 'JJ'), ('sound', 'NN'), ('goodread', 'NN')],
#  [('wireless', 'JJ'),
#   ('connectivity', 'NN'),
#   ('awesome', 'JJ'),
#   ('experience', 'NN'),
#   ('read', 'NN')],
#  [('nice', 'JJ'),
#   ('product', 'NN'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('niceread', 'NN')],
#  [('working', 'VBG'), ('greatread', 'NN')],
#  [('bluetooth', 'DT'),
#   ('range', 'NN'),
#   ('bluetooth', 'DT'),
#   ('connectivity', 'NN'),
#   ('good', 'JJ'),
#   ('read', 'NN')],
#  [('amazing', 'VBG'),
#   ('product', 'NN'),
#   ('much', 'JJ'),
#   ('happy', 'JJ'),
#   ('product', 'NN'),
#   ('value', 'NN'),
#   ('moneyread', 'NN')],
#  [('proper', 'JJ'), ('soundread', 'NN')],
#  [('grt', 'JJ'),
#   ('product', 'NN'),
#   ('service', 'NN'),
#   ('flipkart', 'RB'),
#   ('enjoying', 'VBG'),
#   ('since', 'IN'),
#   ('last', 'JJ'),
#   ('weekread', 'NN')],
#  [('nice', 'JJ'),
#   ('sound', 'NN'),
#   ('bar', 'NN'),
#   ('good', 'JJ'),
#   ('sound', 'NN'),
#   ('qualityread', 'NN')],
#  [('best', 'JJS'), ('soundbar', 'NN'), ('love', 'NN'), ('itread', 'NN')],
#  [('goodread', 'NN')],
#  [('nice', 'JJ'), ('productvalue', 'NN'), ('moneyread', 'NN')],
#  [('liked', 'VBN'), ('muchaverageread', 'NN')],
#  [('installer', 'NN'),
#   ('unexperienced', 'JJ'),
#   ('product', 'NN'),
#   ('bad', 'JJ'),
#   ('connectivityread', 'NN')],
#  [('happysuparbread', 'NN')],
#  [('super', 'JJ'), ('sound', 'NN'), ('qualityread', 'NN')],
#  [('worth', 'JJ'),
#   ('every', 'DT'),
#   ('penny', 'NN'),
#   ('spend', 'NN'),
#   ('speaker', 'NN'),
#   ('looking', 'VBG'),
#   ('decent', 'JJ'),
#   ('sound', 'NN'),
#   ('bar', 'NN'),
#   ('boat', 'NN'),
#   ('aavant', 'JJ'),
#   ('bar', 'NN'),
#   ('per', 'IN'),
#   ('expectation', 'NN'),
#   ('go', 'VBP'),
#   ('itread', 'NN')],
#  [('good', 'JJ'),
#   ('flipkard', 'NN'),
#   ('product', 'NN'),
#   ('boat', 'NN'),
#   ('companyread', 'NN')],
#  [('superb', 'NN'), ('speakerread', 'NN')],
#  [('much', 'RB'),
#   ('good', 'JJ'),
#   ('quality', 'NN'),
#   ('buy', 'VBP'),
#   ('one', 'CD'),
#   ('week', 'NN'),
#   ('installation', 'NN'),
#   ('complete', 'NN'),
#   ('still', 'RB'),
#   ('todayread', 'VB')],
#  [('nice', 'JJ'),
#   ('product', 'NN'),
#   ('need', 'NN'),
#   ('sub', 'JJ'),
#   ('woofer', 'NN'),
#   ('bassread', 'NN')],
#  [('saoundbar', 'NN'),
#   ('good', 'JJ'),
#   ('product', 'NN'),
#   ('super', 'NN'),
#   ('saoundread', 'NN')],
#  [('problem', 'NN'),
#   ('sound', 'NN'),
#   ('bass', 'VBD'),
#   ('flipcart', 'JJ'),
#   ('delivery', 'NN'),
#   ('worst', 'JJS'),
#   ('experience', 'NN'),
#   ('installation', 'NN'),
#   ('remainder', 'NN'),
#   ('complain', 'NN'),
#   ('installation', 'NN'),
#   ('person', 'NN'),
#   ('came', 'VBD'),
#   ('drill', 'RB'),
#   ('hang', 'JJ'),
#   ('speaker', 'NN'),
#   ('neither', 'CC'),
#   ('connect', 'JJ'),
#   ('tv', 'NN'),
#   ('explain', 'NN'),
#   ('function', 'NN'),
#   ('product', 'NN'),
#   ('anyone', 'NN'),
#   ('want', 'VBP'),
#   ('buy', 'NN'),
#   ('dont', 'NN'),
#   ('faith', 'JJ'),
#   ('installation', 'NN'),
#   ('personread', 'NN')],
#  [('price', 'NN'),
#   ('best', 'JJS'),
#   ('shape', 'NN'),
#   ('best', 'JJS'),
#   ('sound', 'NN'),
#   ('best', 'JJS'),
#   ('connectivity', 'NN'),
#   ('poorread', 'NN')],
#  [('nice', 'JJ'), ('worthread', 'NN')],
#  [('sound', 'JJ'),
#   ('nice', 'JJ'),
#   ('connectivity', 'NN'),
#   ('good', 'JJ'),
#   ('design', 'NN'),
#   ('excellent', 'JJ'),
#   ('powerful', 'JJ'),
#   ('soundread', 'NN')],
#  [('wonderful', 'JJ'), ('sound', 'NN'), ('bassread', 'NN')],
#  [('good', 'JJ'), ('sound', 'NN'), ('qualityread', 'NN')],
#  [('nice', 'JJ'),
#   ('quality', 'NN'),
#   ('like', 'IN'),
#   ('sound', 'NN'),
#   ('barread', 'NN')],
#  [('tv', 'NN'), ('connection', 'NN'), ('workingread', 'NN')],
#  [('built', 'VBN'), ('quality', 'NN'), ('awesomeread', 'NN')],
#  [('best', 'JJS'), ('product', 'NN'), ('design', 'NN'), ('superbread', 'NN')],
#  [('bad', 'JJ'),
#   ('nice', 'JJ'),
#   ('product', 'NN'),
#   ('im', 'NN'),
#   ('love', 'VBP'),
#   ('itread', 'NN')],
#  [('good', 'JJ'),
#   ('product', 'NN'),
#   ('wall', 'NN'),
#   ('mounted', 'VBD'),
#   ('system', 'NN'),
#   ('poorread', 'NN')],
#  [('badread', 'NN')],
#  [('bluetooth', 'DT'), ('connection', 'NN'), ('pureread', 'NN')],
#  [('boat', 'NN'),
#   ('aavante', 'NN'),
#   ('bar', 'NN'),
#   ('w', 'NN'),
#   ('bluetooth', 'NN'),
#   ('speaker', 'NN'),
#   ('good', 'JJ'),
#   ('sound', 'NN'),
#   ('clarity', 'NN'),
#   ('vocal', 'JJ'),
#   ('clear', 'JJ'),
#   ('bass', 'NN'),
#   ('averagemodes', 'NNS'),
#   ('could', 'MD'),
#   ('observe', 'VB'),
#   ('difference', 'NN'),
#   ('music', 'NN'),
#   ('movie', 'NN'),
#   ('news', 'NN'),
#   ('mode', 'NN'),
#   ('werent', 'NN'),
#   ('much', 'JJ'),
#   ('effectivebluetooth', 'DT'),
#   ('connectivity', 'NN'),
#   ('fine', 'NN'),
#   ('faced', 'VBN'),
#   ('problem', 'NN'),
#   ('pairingno', 'NN'),
#   ('usb', 'NN'),
#   ('cable', 'NN'),
#   ('given', 'VBN'),
#   ('included', 'VBD'),
#   ('accessoriesvalue', 'JJ'),
#   ('money', 'NN'),
#   ('productoverall', 'NN'),
#   ('rating', 'NN'),
#   ('read', 'NN')],
#  [('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('build', 'VBP'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('totally', 'RB'),
#   ('satisfied', 'JJ'),
#   ('productread', 'NN')],
#  [('valu', 'NN'), ('fore', 'RB'), ('monygood', 'VBD'), ('productread', 'NN')],
#  [('nice', 'JJ'), ('productread', 'NN')],
#  [('recommended', 'VBN'),
#   ('boosting', 'JJ'),
#   ('tv', 'NN'),
#   ('volume', 'NN'),
#   ('give', 'VB'),
#   ('loudness', 'JJ'),
#   ('bass', 'NN'),
#   ('normal', 'JJ'),
#   ('tv', 'NN'),
#   ('viewing', 'VBG'),
#   ('smart', 'JJ'),
#   ('digital', 'JJ'),
#   ('viewing', 'VBG'),
#   ('doesnt', 'NN'),
#   ('come', 'VB'),
#   ('support', 'NN'),
#   ('dolbydts', 'NN'),
#   ('technology', 'NN'),
#   ('movie', 'NN'),
#   ('experience', 'NN'),
#   ('moreover', 'NN'),
#   ('doesnt', 'VBD'),
#   ('even', 'RB'),
#   ('come', 'VBN'),
#   ('hdmiopticalcoaxial', 'JJ'),
#   ('port', 'NN'),
#   ('precisely', 'RB'),
#   ('bumping', 'VBG'),
#   ('tv', 'NN'),
#   ('volume', 'NN'),
#   ('expect', 'VBP'),
#   ('muchread', 'NN')],
#  [('goodread', 'NN')],
#  [('two', 'CD'),
#   ('aux', 'JJ'),
#   ('one', 'CD'),
#   ('usb', 'JJ'),
#   ('bluetooth', 'NN'),
#   ('input', 'NN'),
#   ('function', 'NN'),
#   ('sound', 'NN'),
#   ('bass', 'NN'),
#   ('quality', 'NN'),
#   ('ok', 'RB'),
#   ('tested', 'VBN'),
#   ('feature', 'NN'),
#   ('working', 'VBG'),
#   ('fine', 'JJ'),
#   ('remote', 'JJ'),
#   ('controller', 'NN'),
#   ('range', 'NN'),
#   ('average', 'JJ'),
#   ('button', 'NN'),
#   ('bass', 'NN'),
#   ('treble', 'JJ'),
#   ('sound', 'NN'),
#   ('modesmy', 'NN'),
#   ('android', 'JJ'),
#   ('tv', 'NN'),
#   ('box', 'NN'),
#   ('keep', 'VB'),
#   ('losing', 'VBG'),
#   ('voice', 'NN'),
#   ('connected', 'VBD'),
#   ('bluetooth', 'DT'),
#   ('mode', 'NN'),
#   ('yamaha', 'NN'),
#   ('sound', 'NN'),
#   ('bar', 'NN'),
#   ('doesnt', 'NN'),
#   ('problem', 'NN'),
#   ('playing', 'NN'),
#   ('song', 'NN'),
#   ('phone', 'NN'),
#   ('via', 'IN'),
#   ('bluetooth', 'DT'),
#   ('good', 'JJ'),
#   ('get', 'NN'),
#   ('aux', 'IN'),
#   ('cable', 'NN'),
#   ('box', 'NN'),
#   ('screw', 'VBD'),
#   ('wall', 'JJ'),
#   ('seperation', 'NN'),
#   ('rubber', 'NN'),
#   ('pad', 'NN'),
#   ('wall', 'NN'),
#   ('mountingread', 'NN')],
#  [('mind', 'NN'), ('blowing', 'VBG'), ('product', 'NN'), ('read', 'NN')],
#  [('sound', 'RB'), ('good', 'JJ'), ('qualityread', 'NN')],
#  [('thought', 'VBN'),
#   ('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('awesome', 'JJ'),
#   ('wastage', 'NN'),
#   ('money', 'NN'),
#   ('top', 'NN'),
#   ('continuously', 'RB'),
#   ('connected', 'JJ'),
#   ('power', 'NN'),
#   ('u', 'NN'),
#   ('want', 'VBP'),
#   ('use', 'NN'),
#   ('sound', 'JJ'),
#   ('bar', 'NN'),
#   ('read', 'NN')],
#  [('purchased', 'VBN'),
#   ('best', 'JJS'),
#   ('price', 'NN'),
#   ('nice', 'NNS'),
#   ('qualityread', 'VBD')],
#  [('bluetooth', 'DT'),
#   ('sound', 'JJ'),
#   ('fine', 'JJ'),
#   ('bass', 'NN'),
#   ('ok', 'NN'),
#   ('aux', 'VBP'),
#   ('sound', 'NN'),
#   ('disturbed', 'VBD'),
#   ('cant', 'JJ'),
#   ('fix', 'NN'),
#   ('treble', 'JJ'),
#   ('n', 'JJ'),
#   ('bass', 'NN'),
#   ('look', 'NN'),
#   ('niceread', 'JJ')],
#  [('sound', 'NN'), ('goodread', 'NN')],
#  [('nice', 'RB'), ('good', 'JJ'), ('sound', 'NN'), ('qualityread', 'NN')],
#  [('perfect', 'JJ'),
#   ('deal', 'NN'),
#   ('price', 'NN'),
#   ('product', 'NN'),
#   ('good', 'JJ'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('bluetooth', 'DT'),
#   ('connection', 'NN'),
#   ('good', 'JJ'),
#   ('expected', 'VBN'),
#   ('see', 'VBP'),
#   ('lag', 'JJ'),
#   ('betweenread', 'NN')],
#  [('low', 'JJ'),
#   ('quality', 'NN'),
#   ('sound', 'NN'),
#   ('low', 'JJ'),
#   ('flipkard', 'NN'),
#   ('team', 'NN'),
#   ('bad', 'JJ'),
#   ('responsible', 'JJ'),
#   ('customer', 'NN'),
#   ('complaint', 'NN'),
#   ('redurn', 'NN'),
#   ('accfted', 'VBN'),
#   ('flipkard', 'RB'),
#   ('complaint', 'NN'),
#   ('productread', 'NN')],
#  [('rd', 'JJ'), ('class', 'NN'), ('product', 'NN'), ('badread', 'NN')],
#  [('low', 'JJ'),
#   ('quality', 'NN'),
#   ('sound', 'NN'),
#   ('low', 'JJ'),
#   ('flipkard', 'NN'),
#   ('team', 'NN'),
#   ('bad', 'JJ'),
#   ('responsible', 'JJ'),
#   ('customer', 'NN'),
#   ('complaint', 'NN'),
#   ('redurn', 'NN'),
#   ('accfted', 'VBN'),
#   ('flipkard', 'RB'),
#   ('complaint', 'NN'),
#   ('productread', 'NN')],
#  [('rd', 'JJ'), ('class', 'NN'), ('product', 'NN'), ('badread', 'NN')],
#  [('boat', 'NN'),
#   ('w', 'WRB'),
#   ('bluetooth', 'DT'),
#   ('sound', 'NN'),
#   ('bar', 'NN'),
#   ('pair', 'NN'),
#   ('smartphone', 'VBD'),
#   ('easily', 'RB'),
#   ('sound', 'JJ'),
#   ('bass', 'NN'),
#   ('quality', 'NN'),
#   ('awesome', 'VBP'),
#   ('possible', 'JJ'),
#   ('pair', 'NN'),
#   ('sony', 'NN'),
#   ('android', 'NN'),
#   ('v', 'NN'),
#   ('model', 'NN'),
#   ('connected', 'VBN'),
#   ('aux', 'IN'),
#   ('cable', 'NN'),
#   ('flip', 'JJ'),
#   ('kart', 'NN'),
#   ('service', 'NN'),
#   ('fastread', 'NN')],
#  [('good', 'JJ'), ('rsread', 'NN')],
#  [('battery', 'NN'), ('backupread', 'NN')],
#  [('product', 'NN'),
#   ('good', 'JJ'),
#   ('designand', 'NN'),
#   ('soundbass', 'NN'),
#   ('lessbut', 'NN'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('bluetooth', 'DT'),
#   ('connectivity', 'NN'),
#   ('issue', 'NN'),
#   ('online', 'VBP'),
#   ('meeting', 'NN'),
#   ('plateforms', 'NNS'),
#   ('like', 'IN'),
#   ('m', 'NN'),
#   ('team', 'NN'),
#   ('zoom', 'NN'),
#   ('etc', 'NN'),
#   ('cant', 'JJ'),
#   ('play', 'NN'),
#   ('without', 'IN'),
#   ('audio', 'JJ'),
#   ('jackoverall', 'NN'),
#   ('value', 'NN'),
#   ('money', 'NN'),
#   ('price', 'NN'),
#   ('segmentread', 'NN')],
#  [('good', 'JJ'), ('quality', 'NN'), ('soundread', 'NN')],
#  [('waste', 'NN'), ('installation', 'NN'), ('solwread', 'NN')],
#  [('sound', 'NN'), ('superread', 'NN')],
#  [('purchase', 'NN'), ('shop', 'NN'), ('im', 'VBZ'), ('happyread', 'NN')],
#  [('clear', 'JJ'),
#   ('sound', 'NN'),
#   ('reasonable', 'JJ'),
#   ('bassclassy', 'JJ'),
#   ('remote', 'NN'),
#   ('overall', 'JJ'),
#   ('great', 'JJ'),
#   ('value', 'NN'),
#   ('moneyread', 'NN')],
#  [('good', 'JJ'),
#   ('product', 'NN'),
#   ('listen', 'JJ'),
#   ('music', 'NN'),
#   ('ni', 'RB'),
#   ('low', 'JJ'),
#   ('medium', 'NN'),
#   ('volumeread', 'NN')],
#  [('installation', 'NN'),
#   ('executive', 'NN'),
#   ('nd', 'JJ'),
#   ('time', 'NN'),
#   ('came', 'VBD'),
#   ('good', 'JJ'),
#   ('experience', 'NN'),
#   ('mr', 'NN'),
#   ('ganta', 'NN'),
#   ('shiva', 'NN'),
#   ('prasad', 'JJ'),
#   ('ist', 'JJ'),
#   ('time', 'NN'),
#   ('attempted', 'JJ'),
#   ('executive', 'NN'),
#   ('useless', 'NN'),
#   ('made', 'VBD'),
#   ('fear', 'JJ'),
#   ('instrument', 'NN'),
#   ('suitable', 'NN'),
#   ('led', 'VBD'),
#   ('tv', 'NN'),
#   ('read', 'NN')],
#  [('nice', 'JJ'), ('productread', 'NN')],
#  [('greatread', 'NN')],
#  [('vgoodread', 'NN')],
#  [('lovely', 'RB'), ('quality', 'NN'), ('superrrrread', 'NN')],
#  [('superbread', 'NN')],
#  [('good', 'JJ'), ('qualityread', 'NN')],
#  [('suepr', 'NN'), ('sound', 'NN'), ('barread', 'NN')],
#  [('bad', 'JJ'), ('productsread', 'NN')],
#  [('mini', 'NN'), ('home', 'NN'), ('theaterread', 'NN')],
#  [('really', 'RB'),
#   ('easy', 'JJ'),
#   ('setup', 'NN'),
#   ('well', 'RB'),
#   ('designedit', 'RB'),
#   ('sound', 'JJ'),
#   ('much', 'JJ'),
#   ('bettermy', 'NN'),
#   ('issue', 'NN'),
#   ('sizeif', 'VBD'),
#   ('little', 'JJ'),
#   ('bit', 'RB'),
#   ('small', 'JJ'),
#   ('bestread', 'NN')],
#  [('good', 'JJ'), ('oneread', 'NN')],
#  [('awesomeread', 'NN')],
#  [('goodread', 'NN')],
#  [('really', 'RB'),
#   ('easy', 'JJ'),
#   ('setup', 'NN'),
#   ('well', 'RB'),
#   ('designedit', 'RB'),
#   ('sound', 'JJ'),
#   ('much', 'JJ'),
#   ('bettermy', 'NN'),
#   ('issue', 'NN'),
#   ('sizeif', 'VBD'),
#   ('little', 'JJ'),
#   ('bit', 'RB'),
#   ('small', 'JJ'),
#   ('bestread', 'NN')],
#  [('good', 'JJ'), ('oneread', 'NN')],
#  [('awesomeread', 'NN')],
#  [('goodread', 'NN')],
#  [('good', 'JJ'), ('sound', 'NN'), ('designread', 'NN')],
#  [('connected', 'VBN'),
#   ('mobile', 'JJ'),
#   ('clarity', 'NN'),
#   ('music', 'NN'),
#   ('tv', 'NN'),
#   ('much', 'JJ'),
#   ('exceptationread', 'NN')],
#  [('sound', 'JJ'), ('quality', 'NN'), ('worestread', 'NN')],
#  [('niceread', 'NN')],
#  [('average', 'JJ'),
#   ('qualityconnectivity', 'NN'),
#   ('low', 'JJ'),
#   ('qualityread', 'NN')],
#  [('superr', 'NN'),
#   ('boat', 'NN'),
#   ('aaventr', 'NN'),
#   ('bar', 'NN'),
#   ('jabardast', 'NN'),
#   ('be', 'VB'),
#   ('soundread', 'JJ')],
#  [('awesomeread', 'NN')],
#  [('best', 'JJS'), ('aaaread', 'NN')],
#  [('boat', 'NN'),
#   ('sound', 'NN'),
#   ('bar', 'NN'),
#   ('love', 'NN'),
#   ('u', 'NN'),
#   ('barread', 'NN')],
#  [('bass', 'NN'),
#   ('bit', 'NN'),
#   ('low', 'JJ'),
#   ('high', 'JJ'),
#   ('volume', 'NN'),
#   ('suppresses', 'NNS'),
#   ('morebutsound', 'VBP'),
#   ('clarity', 'NN'),
#   ('awesomeconnection', 'NN'),
#   ('fast', 'RB'),
#   ('instantwould', 'JJ'),
#   ('great', 'JJ'),
#   ('batteryread', 'NN')],
#  [('bad', 'JJ'), ('experienceread', 'NN')],
#  [('amazing', 'VBG'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('look', 'NN'),
#   ('worth', 'JJ'),
#   ('product', 'NN'),
#   ('thnx', 'NN'),
#   ('lot', 'NN'),
#   ('flipkart', 'RB'),
#   ('great', 'JJ'),
#   ('product', 'NN'),
#   ('great', 'JJ'),
#   ('service', 'NN'),
#   ('read', 'VBD')],
#  [('using', 'VBG'),
#   ('product', 'NN'),
#   ('last', 'JJ'),
#   ('one', 'CD'),
#   ('month', 'NN'),
#   ('worth', 'IN'),
#   ('buying', 'VBG'),
#   ('compare', 'JJ'),
#   ('brand', 'NN'),
#   ('like', 'IN'),
#   ('jbl', 'NN'),
#   ('watt', 'NN'),
#   ('soundbar', 'NN'),
#   ('costed', 'VBD'),
#   ('compared', 'VBN'),
#   ('jbl', 'NN'),
#   ('bar', 'NN'),
#   ('studio', 'NN'),
#   ('cost', 'NN'),
#   ('around', 'IN'),
#   ('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('peak', 'VBP'),
#   ('sound', 'JJ'),
#   ('bit', 'NN'),
#   ('higher', 'JJR'),
#   ('device', 'NN'),
#   ('price', 'NN'),
#   ('rangeread', 'NN')],
#  [('nice', 'JJ'), ('productread', 'NN')],
#  [('hated', 'VBN'),
#   ('bcz', 'NN'),
#   ('bluetooth', 'DT'),
#   ('connection', 'NN'),
#   ('tv', 'NN'),
#   ('pairedread', 'NN')],
#  [('ok', 'JJ'),
#   ('volume', 'NN'),
#   ('low', 'JJ'),
#   ('definetly', 'RB'),
#   ('watt', 'VBP'),
#   ('rms', 'NNS'),
#   ('sound', 'VBP'),
#   ('like', 'IN'),
#   ('watt', 'NNS'),
#   ('rmsread', 'VBP')],
#  [('boat', 'NN'),
#   ('aavante', 'NN'),
#   ('bar', 'NN'),
#   ('good', 'JJ'),
#   ('read', 'NN')],
#  [('good', 'JJ'), ('music', 'NN'), ('satisfiedread', 'NN')],
#  [('nice', 'JJ'), ('prodectread', 'NN')],
#  [('best', 'JJS'), ('soundread', 'NN')],
#  [('good', 'JJ'), ('oneread', 'NN')],
#  [('good', 'JJ'), ('qualitysound', 'NN'), ('also', 'RB'), ('goodread', 'VBD')],
#  [('best', 'JJS'), ('productsread', 'NN')],
#  [('goodread', 'NN')],
#  [('average', 'JJ'), ('product', 'NN'), ('read', 'NN')],
#  [('awesome', 'JJ'),
#   ('product', 'NN'),
#   ('boat', 'NN'),
#   ('love', 'VBP'),
#   ('thanks', 'NNS'),
#   ('flipkartread', 'VBP')],
#  [('superread', 'NN')],
#  [('great', 'JJ'), ('sound', 'NN'), ('qualityread', 'NN')],
#  [('good', 'JJ'), ('qualityread', 'NN')],
#  [('owsm', 'RB'), ('sound', 'JJ'), ('qualityread', 'NN')],
#  [('awesomeread', 'NN')],
#  [('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('really', 'RB'),
#   ('awesome', 'JJ'),
#   ('builtin', 'NN'),
#   ('bass', 'NN'),
#   ('provided', 'VBD'),
#   ('read', 'NN')],
#  [('soooper', 'NN'), ('arc', 'NN'), ('missingread', 'NN')],
#  [('good', 'JJ'), ('qualityread', 'NN')],
#  [('owsm', 'RB'), ('sound', 'JJ'), ('qualityread', 'NN')],
#  [('awesomeread', 'NN')],
#  [('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('really', 'RB'),
#   ('awesome', 'JJ'),
#   ('builtin', 'NN'),
#   ('bass', 'NN'),
#   ('provided', 'VBD'),
#   ('read', 'NN')],
#  [('soooper', 'NN'), ('arc', 'NN'), ('missingread', 'NN')],
#  [('fabulousread', 'NN')],
#  [('best', 'JJS'), ('qualityread', 'NN')],
#  [('good', 'JJ'),
#   ('product', 'NN'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('excellent', 'NN'),
#   ('built', 'VBN'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('stylish', 'JJ'),
#   ('exteriorread', 'NN')],
#  [('nice', 'JJ'), ('sound', 'NN'), ('qualityread', 'NN')],
#  [('good', 'JJ'),
#   ('product', 'NN'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('best', 'JJS'),
#   ('bass', 'NN'),
#   ('also', 'RB'),
#   ('best', 'RB'),
#   ('thank', 'JJ'),
#   ('flipkartread', 'NN')],
#  [('nice', 'JJ'), ('soundbarread', 'NN')],
#  [('good', 'JJ'),
#   ('small', 'JJ'),
#   ('x', 'NNP'),
#   ('hall', 'NN'),
#   ('sound', 'NN'),
#   ('clarity', 'NN'),
#   ('goodread', 'NN')],
#  [('goodread', 'NN')],
#  [('nice', 'JJ'), ('productread', 'NN')],
#  [('sound', 'JJ'),
#   ('depth', 'JJ'),
#   ('okay', 'NN'),
#   ('like', 'IN'),
#   ('people', 'NNS'),
#   ('hyped', 'VBN'),
#   ('hereread', 'NN')],
#  [('excellentread', 'NN')],
#  [('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('awesome', 'JJ'),
#   ('best', 'RBS'),
#   ('product', 'NN'),
#   ('everreally', 'RB'),
#   ('love', 'VBZ'),
#   ('read', 'NN')],
#  [('niceread', 'NN')],
#  [('good', 'JJ'),
#   ('product', 'NN'),
#   ('connectivity', 'NN'),
#   ('problem', 'NN'),
#   ('hereread', 'NN')],
#  [('good', 'JJ'),
#   ('product', 'NN'),
#   ('n', 'JJ'),
#   ('price', 'NN'),
#   ('bestread', 'NN')],
#  [('good', 'JJ'), ('product', 'NN'), ('best', 'JJS'), ('priceread', 'NN')],
#  [('nice', 'JJ'),
#   ('product', 'NN'),
#   ('range', 'NN'),
#   ('got', 'VBD'),
#   ('read', 'JJ')],
#  [('awesome', 'JJ'), ('awesomeread', 'NN')],
#  [('goodvalue', 'NN'),
#   ('moneysound', 'NN'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('medium', 'NN'),
#   ('roomall', 'NN'),
#   ('connectivity', 'NN'),
#   ('good', 'JJ'),
#   ('equal', 'JJ'),
#   ('quality', 'NN'),
#   ('outputbut', 'NN'),
#   ('aux', 'VBP'),
#   ('cable', 'NN'),
#   ('defectedread', 'NN')],
#  [('good', 'JJ'),
#   ('product', 'NN'),
#   ('pay', 'NN'),
#   ('full', 'JJ'),
#   ('paisa', 'NN'),
#   ('hosul', 'NN'),
#   ('satisfied', 'JJ'),
#   ('item', 'NN'),
#   ('good', 'JJ'),
#   ('happyread', 'NN')],
#  [('happyread', 'NN')],
#  [('blast', 'NN'),
#   ('sound', 'NN'),
#   ('appreciated', 'VBD'),
#   ('bought', 'VBD'),
#   ('dealgreat', 'JJ'),
#   ('purchase', 'NN'),
#   ('rangemuch', 'JJ'),
#   ('batter', 'NN'),
#   ('hifi', 'NN'),
#   ('brand', 'NN'),
#   ('twice', 'RB'),
#   ('priceread', 'VBD')],
#  [('worth', 'JJ'),
#   ('every', 'DT'),
#   ('penny', 'NN'),
#   ('spent', 'VBN'),
#   ('amazing', 'VBG'),
#   ('sound', 'NN'),
#   ('bassread', 'NN')],
#  [('valu', 'NNS'), ('moneyread', 'VBP')],
#  [('good', 'JJ'),
#   ('product', 'NN'),
#   ('sometime', 'RB'),
#   ('automatically', 'RB'),
#   ('disconnect', 'JJ'),
#   ('connected', 'VBN'),
#   ('using', 'VBG'),
#   ('bluetoothread', 'NN')],
#  [('perfectread', 'NN')],
#  [('nice', 'JJ'), ('productread', 'NN')],
#  [('everything', 'NN'),
#   ('ok', 'NN'),
#   ('except', 'IN'),
#   ('bass', 'NN'),
#   ('bluetooth', 'NN'),
#   ('range', 'NN'),
#   ('price', 'NN'),
#   ('cant', 'NN'),
#   ('expect', 'VBP'),
#   ('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('like', 'IN'),
#   ('bose', 'JJ'),
#   ('overall', 'JJ'),
#   ('good', 'JJ'),
#   ('speaker', 'NN'),
#   ('tvread', 'NN')],
#  [('first', 'RB'),
#   ('check', 'VB'),
#   ('compatibility', 'NN'),
#   ('tour', 'JJ'),
#   ('tv', 'NN'),
#   ('buy', 'NN'),
#   ('technician', 'JJ'),
#   ('sent', 'VBD'),
#   ('company', 'NN'),
#   ('dont', 'NN'),
#   ('know', 'VBP'),
#   ('anything', 'NN'),
#   ('know', 'JJ'),
#   ('hang', 'NN'),
#   ('speakerread', 'NN')],
#  [('great', 'JJ'), ('productread', 'NN')],
#  [('product', 'NN'),
#   ('good', 'JJ'),
#   ('price', 'NN'),
#   ('range', 'NN'),
#   ('sound', 'NN'),
#   ('crackle', 'JJ'),
#   ('high', 'JJ'),
#   ('volume', 'NN'),
#   ('could', 'MD'),
#   ('improved', 'VB'),
#   ('upgrade', 'JJ'),
#   ('productread', 'NN')],
#  [('good', 'JJ'), ('qualityread', 'NN')],
#  [('ok', 'JJ'), ('okread', 'NN')],
#  [('good', 'JJ'), ('rsread', 'NN')],
#  [('good', 'JJ'), ('must', 'MD'), ('buyread', 'VB')],
#  [('buy', 'VB'),
#   ('room', 'NN'),
#   ('filled', 'VBN'),
#   ('boat', 'NN'),
#   ('sound', 'NN'),
#   ('bar', 'NN'),
#   ('like', 'IN'),
#   ('bass', 'NN'),
#   ('sound', 'NN'),
#   ('great', 'JJ'),
#   ('priceread', 'NN')],
#  [('okay', 'NN'),
#   ('dont', 'NN'),
#   ('expect', 'VBP'),
#   ('much', 'JJ'),
#   ('okay', 'IN'),
#   ('considering', 'VBG'),
#   ('price', 'NN'),
#   ('think', 'VBP'),
#   ('better', 'JJR'),
#   ('mi', 'NN'),
#   ('sound', 'JJ'),
#   ('bar', 'NN'),
#   ('read', 'NN')],
#  [('niceread', 'NN')],
#  [('super', 'JJ'), ('productread', 'NN')],
#  [('happy', 'JJ'),
#   ('service', 'NN'),
#   ('thank', 'VBD'),
#   ('flipcart', 'JJ'),
#   ('thanks', 'NNS'),
#   ('jeevesread', 'NN')],
#  [('niceread', 'NN')],
#  [('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('excellent', 'JJ'),
#   ('price', 'NN'),
#   ('bass', 'NN'),
#   ('really', 'RB'),
#   ('good', 'JJ'),
#   ('sound', 'NN'),
#   ('bar', 'NN'),
#   ('without', 'IN'),
#   ('subwoofer', 'NN'),
#   ('connectivity', 'NN'),
#   ('option', 'NN'),
#   ('limited', 'VBD'),
#   ('mm', 'JJ'),
#   ('audio', 'JJ'),
#   ('jack', 'NN'),
#   ('side', 'NN'),
#   ('odd', 'JJ'),
#   ('place', 'NN'),
#   ('plug', 'NN'),
#   ('backread', 'NN')],
#  [('go', 'VB'), ('simply', 'RB'), ('awesome', 'JJ'), ('read', 'NN')],
#  [('superb', 'NN'), ('qualityread', 'NN')],
#  [('lovely', 'RB'), ('productread', 'NN')],
#  [('best', 'JJS'), ('sound', 'NN'), ('barread', 'NN')],
#  [('markread', 'NN')],
#  [('quality', 'NN'),
#   ('average', 'NN'),
#   ('worst', 'VBD'),
#   ('even', 'RB'),
#   ('connected', 'VBN'),
#   ('aux', 'RP'),
#   ('cable', 'NN'),
#   ('pc', 'NN'),
#   ('would', 'MD'),
#   ('still', 'RB'),
#   ('go', 'VB'),
#   ('standby', 'JJ'),
#   ('mode', 'NN'),
#   ('matter', 'NN'),
#   ('minute', 'NN'),
#   ('nothing', 'NN'),
#   ('playing', 'VBG'),
#   ('weird', 'JJ'),
#   ('kind', 'NN'),
#   ('speaker', 'NN'),
#   ('go', 'VBP'),
#   ('standby', 'RB'),
#   ('aux', 'JJ'),
#   ('power', 'NN'),
#   ('cable', 'NN'),
#   ('like', 'IN'),
#   ('battery', 'NN'),
#   ('drain', 'NN'),
#   ('something', 'NN'),
#   ('stupid', 'JJ'),
#   ('usable', 'JJ'),
#   ('pc', 'NN'),
#   ('bought', 'VBD'),
#   ('didnt', 'NN'),
#   ('want', 'NN'),
#   ('bluetoothonly', 'RB'),
#   ('speaker', 'VBZ'),
#   ('pc', 'NN'),
#   ('needed', 'VBN'),
#   ('aux', 'JJ'),
#   ('connectivity', 'NN'),
#   ('make', 'VBP'),
#   ('sure', 'JJ'),
#   ('speaker', 'NN'),
#   ('always', 'RB'),
#   ('better', 'RBR'),
#   ('buy', 'VB'),
#   ('google', 'JJ'),
#   ('homread', 'NN')],
#  [('first', 'JJ'),
#   ('pro', 'JJ'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('best', 'RBS'),
#   ('according', 'VBG'),
#   ('w', 'NN'),
#   ('without', 'IN'),
#   ('lag', 'NN'),
#   ('use', 'NN'),
#   ('many', 'JJ'),
#   ('hour', 'NN'),
#   ('bass', 'NN'),
#   ('good', 'JJ'),
#   ('enough', 'RB'),
#   ('con', 'NN'),
#   ('played', 'VBD'),
#   ('full', 'JJ'),
#   ('volume', 'NN'),
#   ('felt', 'VBD'),
#   ('gitter', 'NN'),
#   ('sound', 'NN'),
#   ('also', 'RB'),
#   ('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('bad', 'JJ'),
#   ('even', 'RB'),
#   ('bass', 'VBP'),
#   ('laggingso', 'JJ'),
#   ('guy', 'NN'),
#   ('good', 'JJ'),
#   ('product', 'NN'),
#   ('price', 'NN'),
#   ('range', 'NN'),
#   ('w', 'IN'),
#   ('remember', 'NN'),
#   ('dont', 'NN'),
#   ('play', 'VBP'),
#   ('full', 'JJ'),
#   ('volume', 'NN'),
#   ('performance', 'NN'),
#   ('become', 'NN'),
#   ('lowread', 'NN')],
#  [('awesome', 'JJ'), ('purchase', 'NN'), ('tq', 'NN'), ('flipkartread', 'NN')],
#  [('niceread', 'NN')],
#  [('im', 'NNS'), ('happyread', 'VBP')],
#  [('goodread', 'NN')],
#  [('good', 'JJ'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('volumeno', 'JJ'),
#   ('issue', 'NN'),
#   ('good', 'JJ'),
#   ('productread', 'NN')],
#  [('nice', 'JJ'), ('soundread', 'NN')],
#  [('osmread', 'NN')],
#  [('excellent', 'JJ'),
#   ('sound', 'NN'),
#   ('fast', 'RB'),
#   ('speaker', 'NN'),
#   ('fit', 'NN'),
#   ('techniciansread', 'NN')],
#  [('awesomeread', 'NN')],
#  [('niceread', 'NN')],
#  [('sound', 'JJ'), ('quality', 'NN'), ('okread', 'NN')],
#  [('really', 'RB'),
#   ('nice', 'JJ'),
#   ('product', 'NN'),
#   ('also', 'RB'),
#   ('installation', 'NN'),
#   ('sound', 'VBD'),
#   ('bar', 'NN'),
#   ('perfectread', 'NN')],
#  [('awesome', 'JJ'),
#   ('product', 'NN'),
#   ('superb', 'NN'),
#   ('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('bass', 'NN'),
#   ('read', 'NN')],
#  [('super', 'JJ'),
#   ('quality', 'NN'),
#   ('bass', 'NN'),
#   ('super', 'FW'),
#   ('super', 'JJR'),
#   ('superread', 'NN')],
#  [('installation', 'NN'),
#   ('satisfiedinstallation', 'NN'),
#   ('person', 'NN'),
#   ('behaviour', 'CD'),
#   ('worstread', 'NN')],
#  [('awesome', 'JJ'), ('read', 'NN')],
#  [('please', 'NN'),
#   ('dont', 'VBZ'),
#   ('buy', 'VBP'),
#   ('stay', 'VB'),
#   ('away', 'RB'),
#   ('else', 'RB'),
#   ('trappedyou', 'NN'),
#   ('may', 'MD'),
#   ('face', 'VB'),
#   ('two', 'CD'),
#   ('issue', 'NN'),
#   ('buy', 'VB'),
#   ('product', 'NN'),
#   ('apart', 'JJ'),
#   ('external', 'JJ'),
#   ('appearance', 'NN'),
#   ('worst', 'JJS'),
#   ('product', 'NN'),
#   ('cant', 'NN'),
#   ('even', 'RB'),
#   ('believe', 'VB'),
#   ('product', 'NN'),
#   ('boat', 'NN'),
#   ('switch', 'VB'),
#   ('product', 'NN'),
#   ('realize', 'NN'),
#   ('cheated', 'JJ'),
#   ('second', 'JJ'),
#   ('issue', 'NN'),
#   ('start', 'VBP'),
#   ('try', 'VB'),
#   ('replace', 'VB'),
#   ('technical', 'JJ'),
#   ('support', 'NN'),
#   ('team', 'NN'),
#   ('company', 'NN'),
#   ('never', 'RB'),
#   ('accept', 'VBD'),
#   ('complaint', 'JJ'),
#   ('replacement', 'NN'),
#   ('refund', 'NN'),
#   ('never', 'RB'),
#   ('happens', 'VBZ'),
#   ('feel', 'NN'),
#   ('trapped', 'VBN'),
#   ('read', 'VB')],
#  [('good', 'JJ'),
#   ('sound', 'NN'),
#   ('experience', 'NN'),
#   ('bass', 'NN'),
#   ('reflection', 'NN'),
#   ('also', 'RB'),
#   ('good', 'JJ'),
#   ('like', 'IN'),
#   ('premium', 'JJ'),
#   ('quality', 'NN'),
#   ('soundbarread', 'NN')],
#  [('good', 'JJ'),
#   ('quality', 'NN'),
#   ('im', 'NN'),
#   ('glad', 'NN'),
#   ('seeread', 'NN')],
#  [('good', 'JJ'), ('sound', 'NN'), ('qualityread', 'NN')],
#  [('superb', 'JJ'), ('soundbar', 'NN'), ('read', 'NN')],
#  [('sound', 'JJ'), ('bass', 'NN'), ('good', 'JJ'), ('budgetread', 'NN')],
#  [('awesome', 'JJ'),
#   ('range', 'NN'),
#   ('installation', 'NN'),
#   ('hasslefree', 'CD'),
#   ('smoothread', 'NN')],
#  [('best', 'JJS'),
#   ('bass', 'NN'),
#   ('high', 'JJ'),
#   ('volume', 'NN'),
#   ('happyread', 'NN')],
#  [('goodread', 'NN')],
#  [('amazing', 'VBG'), ('soundbarread', 'NN')],
#  [('super', 'JJ'),
#   ('product', 'NN'),
#   ('thanks', 'NNS'),
#   ('flipcartread', 'VBP')],
#  [('super', 'JJ'), ('barread', 'NN')],
#  [('sound', 'JJ'), ('quality', 'NN'), ('averageread', 'NN')],
#  [('certifiedread', 'NN')],
#  [('super', 'JJ'),
#   ('product', 'NN'),
#   ('thanks', 'NNS'),
#   ('flipcartread', 'VBP')],
#  [('super', 'JJ'), ('barread', 'NN')],
#  [('sound', 'JJ'), ('quality', 'NN'), ('averageread', 'NN')],
#  [('certifiedread', 'NN')],
#  [('boat', 'NN'),
#   ('aavante', 'VBZ'),
#   ('awesome', 'JJ'),
#   ('speaker', 'NN'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('lover', 'RB'),
#   ('go', 'VBP'),
#   ('high', 'JJ'),
#   ('watt', 'NN'),
#   ('speaker', 'NN'),
#   ('ok', 'RB'),
#   ('good', 'JJ'),
#   ('product', 'NN'),
#   ('considering', 'VBG'),
#   ('price', 'NN'),
#   ('range', 'NN'),
#   ('loud', 'JJ'),
#   ('clear', 'JJ'),
#   ('sound', 'NN'),
#   ('best', 'JJS'),
#   ('choice', 'NN'),
#   ('would', 'MD'),
#   ('watt', 'VB'),
#   ('speaker', 'NN'),
#   ('sound', 'JJ'),
#   ('quality', 'JJ'),
#   ('thing', 'NN'),
#   ('wantprosstunning', 'VBG'),
#   ('designawesome', 'JJ'),
#   ('sound', 'NN'),
#   ('qualitygood', 'VBD'),
#   ('remote', 'JJ'),
#   ('control', 'NN'),
# ...
#  [('ultimateread', 'JJ')],
#  [('upto', 'JJ'), ('markread', 'NN')],
#  [('bad', 'JJ'), ('battery', 'NN'), ('backup', 'NN'), ('problemread', 'NN')],
#  [('goodread', 'NN')],
#  [('sound', 'NN'), ('superbread', 'NN')],
#  [('price', 'NN'),
#   ('best', 'JJS'),
#   ('sound', 'NN'),
#   ('bar', 'NN'),
#   ('first', 'RB'),
#   ('timer', 'VBZ'),
#   ('blindly', 'RB'),
#   ('go', 'VB'),
#   ('support', 'NN'),
#   ('pen', 'RB'),
#   ('drive', 'NN'),
#   ('also', 'RB'),
#   ('dc', 'VBZ'),
#   ('jack', 'NN'),
#   ('provided', 'VBD'),
#   ('l', 'NN'),
#   ('type', 'NN'),
#   ('better', 'RBR'),
#   ('straight', 'JJ'),
#   ('jack', 'NN'),
#   ('take', 'VB'),
#   ('space', 'NN'),
#   ('behindsound', 'IN'),
#   ('quiet', 'JJ'),
#   ('loud', 'JJ'),
#   ('home', 'NN'),
#   ('user', 'NN'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('power', 'NN'),
#   ('adapter', 'NN'),
#   ('provided', 'VBD'),
#   ('support', 'NN'),
#   ('second', 'JJ'),
#   ('power', 'NN'),
#   ('fluctuation', 'NN'),
#   ('power', 'NN'),
#   ('failread', 'NN')],
#  [('excellent', 'JJ'), ('productread', 'NN')],
#  [('ok', 'JJ'),
#   ('product', 'NN'),
#   ('expect', 'VB'),
#   ('much', 'JJ'),
#   ('pricewiseread', 'NN')],
#  [('excellent', 'JJ'),
#   ('sound', 'NN'),
#   ('bar', 'NN'),
#   ('loved', 'VBD'),
#   ('awesome', 'JJ'),
#   ('soundread', 'NN')],
#  [('excellent', 'JJ'), ('productread', 'NN')],
#  [('ok', 'JJ'),
#   ('product', 'NN'),
#   ('expect', 'VB'),
#   ('much', 'JJ'),
#   ('pricewiseread', 'NN')],
#  [('excellent', 'JJ'),
#   ('sound', 'NN'),
#   ('bar', 'NN'),
#   ('loved', 'VBD'),
#   ('awesome', 'JJ'),
#   ('soundread', 'NN')],
#  [('superread', 'NN')],
#  [('v', 'RB'),
#   ('good', 'JJ'),
#   ('set', 'NN'),
#   ('room', 'NN'),
#   ('meread', 'NN')],
#  [('awesome', 'JJ'),
#   ('built', 'VBN'),
#   ('qualitygood', 'NN'),
#   ('bassonly', 'RB'),
#   ('negative', 'JJ'),
#   ('point', 'NN'),
#   ('play', 'VBP'),
#   ('full', 'JJ'),
#   ('volume', 'NN'),
#   ('clearly', 'RB'),
#   ('audibleoverall', 'JJ'),
#   ('goodrating', 'VBG'),
#   ('read', 'NN')],
#  [('awsome', 'JJ'), ('product', 'NN'), ('small', 'JJ'), ('roomread', 'NN')],
#  [('bass', 'NN'), ('superread', 'NN')],
#  [('expected', 'VBN'),
#   ('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('availableread', 'NN')],
#  [('im', 'NN'),
#   ('writing', 'VBG'),
#   ('review', 'NN'),
#   ('using', 'VBG'),
#   ('month', 'NN'),
#   ('speaker', 'NN'),
#   ('ok', 'JJ'),
#   ('sound', 'NN'),
#   ('really', 'RB'),
#   ('bad', 'JJ'),
#   ('connect', 'NN'),
#   ('aux', 'NN'),
#   ('cable', 'NN'),
#   ('year', 'NN'),
#   ('back', 'RB'),
#   ('hve', 'VBD'),
#   ('brought', 'VBD'),
#   ('one', 'CD'),
#   ('zebronics', 'NN'),
#   ('home', 'NN'),
#   ('theater', 'NN'),
#   ('r', 'NN'),
#   ('sound', 'NN'),
#   ('better', 'RBR'),
#   ('bass', 'NN'),
#   ('also', 'RB'),
#   ('badbut', 'RB'),
#   ('connected', 'VBN'),
#   ('bluetooth', 'DT'),
#   ('sound', 'JJ'),
#   ('ok', 'JJ'),
#   ('wowread', 'NN')],
#  [('good', 'JJ'), ('qualityread', 'NN')],
#  [('awesome', 'JJ'), ('purchase', 'NN'), ('good', 'JJ'), ('soundread', 'NN')],
#  [('product', 'NN'), ('good', 'JJ'), ('bass', 'NN'), ('lowread', 'NN')],
#  [('total', 'JJ'),
#   ('okay', 'NN'),
#   ('hdmi', 'NN'),
#   ('thats', 'VBZ'),
#   ('one', 'CD'),
#   ('okread', 'NN')],
#  [('goodread', 'NN')],
#  [('excellent', 'JJ'),
#   ('product', 'NN'),
#   ('problem', 'NN'),
#   ('product', 'NN'),
#   ('connectivity', 'NN'),
#   ('option', 'NN'),
#   ('available', 'JJ'),
#   ('option', 'NN'),
#   ('bt', 'NN'),
#   ('optical', 'JJ'),
#   ('option', 'NN'),
#   ('auxiliary', 'JJ'),
#   ('auxiliary', 'JJ'),
#   ('connection', 'NN'),
#   ('horrible', 'JJ'),
#   ('use', 'NN'),
#   ('havent', 'NN'),
#   ('tried', 'VBD'),
#   ('optical', 'JJ'),
#   ('connection', 'NN'),
#   ('bt', 'NN'),
#   ('connection', 'NN'),
#   ('good', 'JJ'),
#   ('might', 'MD'),
#   ('given', 'VBN'),
#   ('hdmi', 'VB'),
#   ('connection', 'NN'),
#   ('also', 'RB'),
#   ('sound', 'VBD'),
#   ('good', 'JJ'),
#   ('bt', 'NN'),
#   ('connection', 'NN'),
#   ('though', 'IN'),
#   ('would', 'MD'),
#   ('rated', 'VBN'),
#   ('star', 'JJ'),
#   ('star', 'NN'),
#   ('le', 'NN'),
#   ('connectivity', 'NN'),
#   ('option', 'NN'),
#   ('useless', 'JJ'),
#   ('ppls', 'NN'),
#   ('doesnt', 'NN'),
#   ('bt', 'NN'),
#   ('connection', 'NN'),
#   ('television', 'NN'),
#   ('setread', 'NN')],
#  [('boat', 'NN'),
#   ('sound', 'NN'),
#   ('bar', 'NN'),
#   ('best', 'JJS'),
#   ('match', 'NN'),
#   ('room', 'NN'),
#   ('size', 'NN'),
#   ('bass', 'NN'),
#   ('decent', 'NN'),
#   ('cant', 'NN'),
#   ('expect', 'VBP'),
#   ('sub', 'NN'),
#   ('woofer', 'NN'),
#   ('kind', 'NN'),
#   ('bass', 'NN'),
#   ('module', 'NN'),
#   ('treble', 'JJ'),
#   ('seems', 'VBZ'),
#   ('crystal', 'JJ'),
#   ('clear', 'JJ'),
#   ('overall', 'JJ'),
#   ('value', 'NN'),
#   ('money', 'NN'),
#   ('one', 'CD'),
#   ('tip', 'NN'),
#   ('tv', 'NN'),
#   ('connected', 'VBN'),
#   ('set', 'VBD'),
#   ('top', 'JJ'),
#   ('box', 'NN'),
#   ('thru', 'NN'),
#   ('hdmi', 'NN'),
#   ('connection', 'NN'),
#   ('dont', 'NN'),
#   ('go', 'VBP'),
#   ('bluetooth', 'DT'),
#   ('option', 'NN'),
#   ('rather', 'RB'),
#   ('go', 'VB'),
#   ('via', 'IN'),
#   ('direct', 'JJ'),
#   ('aux', 'JJ'),
#   ('stb', 'NN'),
#   ('bsb', 'NN'),
#   ('give', 'VBP'),
#   ('best', 'JJS'),
#   ('output', 'NN'),
#   ('also', 'RB'),
#   ('great', 'JJ'),
#   ('tv', 'NN'),
#   ('viewing', 'VBG'),
#   ('experience', 'NN'),
#   ('bluetooth', 'DT'),
#   ('option', 'NN'),
#   ('work', 'NN'),
#   ('well', 'RB'),
#   ('youtube', 'RB'),
#   ('content', 'JJ'),
#   ('music', 'NN'),
#   ('listening', 'VBG'),
#   ('smartphoneread', 'NN')],
#  [('goodread', 'NN')],
#  [('excellent', 'JJ'),
#   ('product', 'NN'),
#   ('problem', 'NN'),
#   ('product', 'NN'),
#   ('connectivity', 'NN'),
#   ('option', 'NN'),
#   ('available', 'JJ'),
#   ('option', 'NN'),
#   ('bt', 'NN'),
#   ('optical', 'JJ'),
#   ('option', 'NN'),
#   ('auxiliary', 'JJ'),
#   ('auxiliary', 'JJ'),
#   ('connection', 'NN'),
#   ('horrible', 'JJ'),
#   ('use', 'NN'),
#   ('havent', 'NN'),
#   ('tried', 'VBD'),
#   ('optical', 'JJ'),
#   ('connection', 'NN'),
#   ('bt', 'NN'),
#   ('connection', 'NN'),
#   ('good', 'JJ'),
#   ('might', 'MD'),
#   ('given', 'VBN'),
#   ('hdmi', 'VB'),
#   ('connection', 'NN'),
#   ('also', 'RB'),
#   ('sound', 'VBD'),
#   ('good', 'JJ'),
#   ('bt', 'NN'),
#   ('connection', 'NN'),
#   ('though', 'IN'),
#   ('would', 'MD'),
#   ('rated', 'VBN'),
#   ('star', 'JJ'),
#   ('star', 'NN'),
#   ('le', 'NN'),
#   ('connectivity', 'NN'),
#   ('option', 'NN'),
#   ('useless', 'JJ'),
#   ('ppls', 'NN'),
#   ('doesnt', 'NN'),
#   ('bt', 'NN'),
#   ('connection', 'NN'),
#   ('television', 'NN'),
#   ('setread', 'NN')],
#  [('goodread', 'NN')],
#  [('good', 'JJ'),
#   ('product', 'NN'),
#   ('best', 'JJS'),
#   ('single', 'JJ'),
#   ('roomread', 'NN')],
#  [('nice', 'JJ'), ('experienceread', 'NN')],
#  [('nice', 'JJ'),
#   ('sound', 'NN'),
#   ('qwality', 'NN'),
#   ('enjoy', 'RB'),
#   ('low', 'JJ'),
#   ('price', 'NN'),
#   ('big', 'JJ'),
#   ('enjoy', 'NN'),
#   ('sound', 'NN'),
#   ('music', 'NN'),
#   ('qwality', 'NN'),
#   ('nice', 'JJ'),
#   ('instrumentread', 'NN')],
#  [('good', 'JJ'), ('productread', 'NN')],
#  [('option', 'NN'), ('batteryread', 'NN')],
#  [('everything', 'NN'),
#   ('good', 'JJ'),
#   ('remort', 'NN'),
#   ('sensor', 'NN'),
#   ('connectivity', 'NN'),
#   ('good', 'JJ'),
#   ('upper', 'JJ'),
#   ('volume', 'NN'),
#   ('doesnt', 'NN'),
#   ('work', 'NN'),
#   ('goodread', 'NN')],
#  [('niceread', 'NN')],
#  [('sound', 'JJ'), ('quality', 'NN'), ('awsmread', 'NN')],
#  [('goodread', 'NN')],
#  [('superb', 'NN'), ('sound', 'NN'), ('qualityread', 'NN')],
#  [('product', 'NN'), ('service', 'NN'), ('bestread', 'NN')],
#  [('good', 'JJ'), ('productread', 'NN')],
#  [('excellent', 'JJ'), ('product', 'NN'), ('priceread', 'NN')],
#  [('bad', 'JJ'), ('installationread', 'NN')],
#  [('awesome', 'JJ'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('must', 'MD'),
#   ('buy', 'VB'),
#   ('product', 'NN'),
#   ('worth', 'JJ'),
#   ('cost', 'NN'),
#   ('thanks', 'NNS'),
#   ('flipkartread', 'VBP')],
#  [('conector', 'NN'), ('workingread', 'NN')],
#  [('awesome', 'JJ'), ('sound', 'NN'), ('quality', 'NN'), ('read', 'VBP')],
#  [('really', 'RB'), ('happy', 'JJ'), ('good', 'JJ'), ('productread', 'NN')],
#  [('worst', 'RB'), ('soundbarread', 'NN')],
#  [('best', 'JJS'), ('product', 'NN'), ('low', 'JJ'), ('costread', 'NN')],
#  [('good', 'JJ'), ('hdmi', 'NN'), ('port', 'NN'), ('availableread', 'NN')],
#  [('best', 'JJS'),
#   ('one', 'CD'),
#   ('k', 'NN'),
#   ('price', 'NN'),
#   ('range', 'NN'),
#   ('amazing', 'VBG'),
#   ('product', 'NN'),
#   ('jst', 'NN'),
#   ('go', 'VBP'),
#   ('itread', 'NN')],
#  [('value', 'NN'),
#   ('money', 'NN'),
#   ('nice', 'JJ'),
#   ('product', 'NN'),
#   ('read', 'NN')],
#  [('niceread', 'NN')],
#  [('product', 'NN'),
#   ('good', 'JJ'),
#   ('connected', 'JJ'),
#   ('tv', 'NN'),
#   ('without', 'IN'),
#   ('bluetooth', 'DT'),
#   ('via', 'IN'),
#   ('optical', 'JJ'),
#   ('fiber', 'NN'),
#   ('cable', 'NN'),
#   ('converter', 'NN'),
#   ('aux', 'NN'),
#   ('cable', 'NN'),
#   ('sound', 'NN'),
#   ('superb', 'NN'),
#   ('easy', 'JJ'),
#   ('use', 'NN'),
#   ('reason', 'NN'),
#   ('giving', 'VBG'),
#   ('one', 'CD'),
#   ('star', 'NN'),
#   ('flipkart', 'NN'),
#   ('took', 'VBD'),
#   ('five', 'CD'),
#   ('day', 'NN'),
#   ('flipkart', 'VB'),
#   ('get', 'VB'),
#   ('installed', 'JJ'),
#   ('show', 'NN'),
#   ('demo', 'NN'),
#   ('made', 'VBD'),
#   ('call', 'JJ'),
#   ('flipkart', 'NN'),
#   ('continuously', 'RB'),
#   ('five', 'CD'),
#   ('day', 'NN'),
#   ('five', 'CD'),
#   ('start', 'NN'),
#   ('demo', 'NN'),
#   ('guy', 'NN'),
#   ('finally', 'RB'),
#   ('turn', 'VB'),
#   ('get', 'NN'),
#   ('sound', 'JJ'),
#   ('bar', 'NN'),
#   ('ready', 'JJ'),
#   ('useread', 'JJ')],
#  [('okay', 'NN'), ('read', 'NN')],
#  [('osmread', 'NN')],
#  [('use', 'JJ'),
#   ('tv', 'NN'),
#   ('bluetooth', 'DT'),
#   ('installation', 'NN'),
#   ('person', 'NN'),
#   ('didnt', 'JJ'),
#   ('work', 'NN'),
#   ('productread', 'NN')],
#  [('sound', 'RB'),
#   ('good', 'JJ'),
#   ('connected', 'VBN'),
#   ('phone', 'NN'),
#   ('sound', 'NN'),
#   ('le', 'RB'),
#   ('connected', 'VBN'),
#   ('ledread', 'NN')],
#  [('bought', 'JJ'),
#   ('product', 'NN'),
#   ('flipkart', 'JJ'),
#   ('sale', 'NN'),
#   ('product', 'NN'),
#   ('good', 'JJ'),
#   ('expected', 'VBN'),
#   ('bad', 'JJ'),
#   ('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('connectivity', 'NN'),
#   ('low', 'JJ'),
#   ('design', 'NN'),
#   ('good', 'JJ'),
#   ('cant', 'NN'),
#   ('recommend', 'VB'),
#   ('product', 'NN'),
#   ('everyone', 'NN'),
#   ('please', 'NN'),
#   ('explore', 'VB'),
#   ('product', 'NN'),
#   ('dont', 'JJ'),
#   ('buy', 'VB'),
#   ('chinese', 'JJ'),
#   ('one', 'CD'),
#   ('like', 'IN'),
#   ('boatread', 'NN')],
#  [('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('bass', 'NN'),
#   ('awesome', 'VBP'),
#   ('read', 'NN')],
#  [('awesomeread', 'NN')],
#  [('ok', 'JJ'), ('connection', 'NN'), ('problemsread', 'NN')],
#  [('happyread', 'NN')],
#  [('wonderful', 'JJ'),
#   ('experience', 'NN'),
#   ('recommended', 'VBD'),
#   ('everyoneread', 'NN')],
#  [('vaey', 'NN'),
#   ('bad', 'JJ'),
#   ('product', 'NN'),
#   ('dont', 'NN'),
#   ('buy', 'VBP'),
#   ('itread', 'NN')],
#  [('sound', 'JJ'),
#   ('memory', 'NN'),
#   ('switch', 'NN'),
#   ('need', 'VBP'),
#   ('increase', 'NN'),
#   ('manuallyread', 'NN')],
#  [('goodread', 'NN')],
#  [('quality', 'NN'), ('excellentread', 'NN')],
#  [('want', 'JJ'),
#   ('say', 'VBP'),
#   ('budget', 'NN'),
#   ('r', 'NN'),
#   ('best', 'JJS'),
#   ('quality', 'NN'),
#   ('sound', 'NN'),
#   ('bar', 'NN'),
#   ('get', 'VBP'),
#   ('mind', 'NNS'),
#   ('make', 'VBP'),
#   ('sure', 'JJ'),
#   ('tv', 'NN'),
#   ('device', 'NN'),
#   ('portsread', 'NN')],
#  [('nice', 'JJ'), ('productread', 'NN')],
#  [('thanks', 'NNS'), ('much', 'RB'), ('productread', 'VBP')],
#  [('goodnot', 'NN'), ('superbread', 'NN')],
#  [('awesome', 'JJ'),
#   ('look', 'NN'),
#   ('bass', 'NN'),
#   ('medium', 'NN'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('goodread', 'NN')],
#  [('sound', 'NN'),
#   ('baar', 'IN'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('connectivity', 'NN'),
#   ('baadread', 'NN')],
#  [('goodread', 'NN')],
#  [('nice', 'RB'), ('good', 'JJ'), ('conditionread', 'NN')],
#  [('design', 'NN'),
#   ('product', 'NN'),
#   ('build', 'JJ'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('pricebut', 'NN'),
#   ('soud', 'VBP'),
#   ('quality', 'NN'),
#   ('poor', 'JJ'),
#   ('bass', 'NN'),
#   ('even', 'RB'),
#   ('reduce', 'VB'),
#   ('zero', 'CD'),
#   ('get', 'VB'),
#   ('headache', 'JJ'),
#   ('watch', 'NN'),
#   ('tv', 'NN'),
#   ('half', 'NN'),
#   ('hourread', 'NN')],
#  [('aux', 'NNS'), ('workingread', 'VBP')],
#  [('superb', 'JJ'),
#   ('price', 'NN'),
#   ('little', 'JJ'),
#   ('bit', 'NN'),
#   ('highread', 'JJ')],
#  [('good', 'JJ'), ('qualityread', 'NN')],
#  [('bad', 'JJ'),
#   ('connectionnot', 'NN'),
#   ('matching', 'VBG'),
#   ('tv', 'NN'),
#   ('cableread', 'NN')],
#  [('supperb', 'NN'), ('mind', 'NN'), ('blowingread', 'NN')],
#  [('excellent', 'JJ'),
#   ('quality', 'NN'),
#   ('compared', 'VBN'),
#   ('product', 'NN'),
#   ('price', 'NN'),
#   ('bought', 'VBD'),
#   ('product', 'NN'),
#   ('offer', 'NN'),
#   ('price', 'NN'),
#   ('flipkart', 'NN'),
#   ('service', 'NN'),
#   ('best', 'JJS'),
#   ('one', 'CD'),
#   ('value', 'NN'),
#   ('moneyread', 'NN')],
#  [('good', 'JJ'),
#   ('sound', 'NN'),
#   ('value', 'NN'),
#   ('money', 'NN'),
#   ('go', 'VBP'),
#   ('guysread', 'NN')],
#  [('goodread', 'NN')],
#  [('goodread', 'NN')],
#  [('supersound', 'NN'), ('qualityread', 'NN')],
#  [('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('bass', 'NN'),
#   ('also', 'RB'),
#   ('good', 'JJ'),
#   ('lower', 'JJR'),
#   ('price', 'NN'),
#   ('sound', 'NN'),
#   ('baar', 'NN'),
#   ('best', 'JJS'),
#   ('please', 'NN'),
#   ('buy', 'VB'),
#   ('boat', 'NN'),
#   ('sound', 'NN'),
#   ('baar', 'VBD'),
#   ('technical', 'JJ'),
#   ('issue', 'NN'),
#   ('service', 'NN'),
#   ('goodread', 'NN')],
#  [('sound', 'JJ'), ('quality', 'NN'), ('goodread', 'NN')],
#  [('sound', 'JJ'), ('quality', 'NN'), ('goodread', 'NN')],
#  [('goodread', 'NN')],
#  [('good', 'JJ'), ('jobread', 'NN')],
#  [('product', 'NN'),
#   ('good', 'JJ'),
#   ('stand', 'NN'),
#   ('enough', 'JJ'),
#   ('satisfiedread', 'NN')],
#  [('tried', 'JJ'),
#   ('replacement', 'NN'),
#   ('rejected', 'VBD'),
#   ('request', 'NN'),
#   ('feel', 'NN'),
#   ('terrible', 'JJ'),
#   ('purchasing', 'VBG'),
#   ('flipkart', 'NN'),
#   ('mentioned', 'VBD'),
#   ('view', 'NN'),
#   ('regarding', 'VBG'),
#   ('flaw', 'NN'),
#   ('product', 'NN'),
#   ('ignore', 'NN'),
#   ('ever', 'RB'),
#   ('say', 'VBP'),
#   ('come', 'JJ'),
#   ('saying', 'VBG'),
#   ('arrange', 'NN'),
#   ('alternative', 'NN'),
#   ('first', 'JJ'),
#   ('flaw', 'NN'),
#   ('product', 'NN'),
#   ('u', 'JJ'),
#   ('turn', 'NN'),
#   ('speaker', 'NN'),
#   ('get', 'VB'),
#   ('voice', 'JJ'),
#   ('notification', 'NN'),
#   ('speaker', 'NN'),
#   ('notification', 'NN'),
#   ('u', 'JJ'),
#   ('connect', 'JJ'),
#   ('tv', 'NN'),
#   ('bluetooth', 'NN'),
#   ('der', 'NN'),
#   ('lag', 'NN'),
#   ('sound', 'VBD'),
#   ('reach', 'NN'),
#   ('late', 'RB'),
#   ('compare', 'JJ'),
#   ('video', 'NN'),
#   ('dont', 'NN'),
#   ('feel', 'NN'),
#   ('bread', 'NN')],
#  [('need', 'NN'), ('display', 'NN'), ('greatread', 'NN')],
#  [('sound', 'JJ'), ('quality', 'NN'), ('superread', 'NN')],
#  [('nice', 'JJ'), ('super', 'JJ'), ('qualityread', 'NN')],
#  [('best', 'JJS'), ('market', 'NN'), ('price', 'NN'), ('rangeread', 'NN')],
#  [('pam', 'JJ'),
#   ('product', 'NN'),
#   ('light', 'JJ'),
#   ('bass', 'NN'),
#   ('gud', 'NN'),
#   ('sound', 'NN'),
#   ('loversread', 'NN')],
#  [('value', 'NN'), ('moneyread', 'NN')],
#  [('good', 'JJ'),
#   ('productsand', 'NN'),
#   ('good', 'JJ'),
#   ('person', 'NN'),
#   ('instalation', 'NN'),
#   ('menread', 'NN')],
#  [('satisfiedread', 'NN')],
#  [('superread', 'NN')],
#  [('superbread', 'NN')],
#  [('second', 'JJ'),
#   ('thought', 'NN'),
#   ('best', 'JJS'),
#   ('product', 'NN'),
#   ('best', 'RBS'),
#   ('priceread', 'NN')],
#  [('niceread', 'NN')],
#  [('nice', 'JJ'), ('soundread', 'NN')],
#  [('best', 'JJS'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('bass', 'NN'),
#   ('also', 'RB'),
#   ('highread', 'VBD')],
#  [('value', 'NN'), ('moneyread', 'NN')],
#  [('best', 'JJS'), ('priceread', 'NN')],
#  [('exellent', 'JJ'), ('bass', 'NN'), ('nice', 'JJ'), ('soundread', 'NN')],
#  [('nice', 'JJ'), ('productread', 'NN')],
#  [('best', 'JJS'),
#   ('speaker', 'NN'),
#   ('small', 'JJ'),
#   ('roomthe', 'NN'),
#   ('audio', 'NN'),
#   ('clear', 'NN'),
#   ('could', 'MD'),
#   ('hear', 'VB'),
#   ('minor', 'JJ'),
#   ('detail', 'NN'),
#   ('never', 'RB'),
#   ('heard', 'VBN'),
#   ('best', 'JJS'),
#   ('speaker', 'NN'),
#   ('watch', 'NN'),
#   ('moviesread', 'NN')],
#  [('worthy', 'JJ'),
#   ('product', 'NN'),
#   ('stylish', 'JJ'),
#   ('designread', 'NN')],
#  [('overall', 'JJ'), ('product', 'NN'), ('amazingread', 'NN')],
#  [('value', 'NN'), ('money', 'NN'), ('satisfactionread', 'NN')],
#  [('good', 'JJ'), ('sound', 'NN'), ('qualitythanksread', 'NN')]]

# %%
Adjective = []
Adverb = []
CordinatingConjunction = []
SubordinatingConjuction = []
Interjection = []
Noun = []
Verb = []
PersonalPronoun = []
predeterminer = []
Determiner = []

# %%
for value in pos:
  AdjectiveCount = 0
  AdverbCount = 0
  CordinatingConjunctionCount = 0
  SubordinatingConjuctionCount = 0
  InterjectionCount = 0
  NounCount = 0
  VerbCount = 0
  PersonalPronounCount = 0
  predeterminerCount = 0
  DeterminerCount = 0
  for word,tag in value:
    if tag == 'JJ':
      AdjectiveCount = AdjectiveCount + 1
    elif tag == 'RB':
      AdverbCount = AdverbCount + 1
    elif tag == 'CC':
      CordinatingConjunctionCount = CordinatingConjunctionCount + 1
    elif tag == 'UH':
      InterjectionCount = InterjectionCount + 1
    elif tag == 'NN':
      NounCount = NounCount + 1
    elif tag == 'VR':
      VerbCount = VerbCount + 1
    elif tag == 'PRP':
      PersonalPronounCount = PersonalPronounCount + 1
    elif tag == 'PDT':
      predeterminerCount = predeterminerCount + 1
    elif tag == 'DT':
      DeterminerCount = DeterminerCount + 1
    elif tag == 'IN':
       SubordinatingConjuctionCount = SubordinatingConjuctionCount + 1
  Adjective.append(AdjectiveCount)
  Adverb.append(AdverbCount)
  CordinatingConjunction.append(CordinatingConjunctionCount)
  Interjection.append(InterjectionCount)
  Noun.append(NounCount)
  Verb.append(VerbCount)
  PersonalPronoun.append(PersonalPronounCount)
  predeterminer.append(predeterminerCount)
  Determiner.append(DeterminerCount)
  SubordinatingConjuction.append(SubordinatingConjuctionCount)

# %%
df['Number of Adjectives'] = Adjective
df['Number of Adverbs'] = Adverb
df['Number of Cordinating Conjunctions'] = CordinatingConjunction
df['Number of Interjections'] = Interjection
df['Number of Nouns'] = Noun
df['Number of Verbs'] = Verb
df['Number of Personal Pronouns'] = PersonalPronoun
df['Number of Predeterminers'] = predeterminer
df['Number of Determiners'] = Determiner
df['Number of Subordinating Conjuctions'] = SubordinatingConjuction
df
# Out:
#          Glimpse of Review  ... Number of Subordinating Conjuctions
# 0                Wonderful  ...                                   1
# 1        Worth every penny  ...                                   0
# 2                  Awesome  ...                                   0
# 3           Master Blaster  ...                                   1
# 4                Very Good  ...                                   0
# ..                     ...  ...                                 ...
# 531          Great product  ...                                   0
# 532                 Super!  ...                                   0
# 533              Fabulous!  ...                                   0
# 534  Mind-blowing purchase  ...                                   0
# 535         Simply awesome  ...                                   0
#
# [536 rows x 14 columns]
